# %% [markdown]
# # 02 — BDD100K Preparation for YOLO Training
#
# **Goal:** Convert BDD100K detection annotations to YOLO format and build the dataset structure.
#
# This notebook:
# 1. Reads BDD100K detection JSON annotations
# 2. Converts to YOLO format (`class_id x_center y_center width height`)
# 3. Creates `images/train`, `images/val`, `labels/train`, `labels/val` locally on Colab SSD
# 4. Generates the dataset YAML for training
# 5. Visualises sample annotations
# 6. Prints class mapping and distribution

# %% [markdown]
# ## 1 — Install Dependencies

# %%
# !pip install -q ultralytics opencv-python matplotlib Pillow pyyaml tqdm
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 18.2 MB/s eta 0:00:00

# %% [markdown]
# ## 2 — Mount Drive & Configure Paths

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import sys

ECOCAR_ROOT = "/content/drive/MyDrive/EcoCAR"
BDD_RAW_DIR = os.path.join(ECOCAR_ROOT, "datasets", "bdd100k_raw")
YOLO_DATASET_DIR = "/content/bdd100k_yolo"
DEBUG_LIMIT = None  # Change to 100 for fast debugging

if DEBUG_LIMIT:
    print(f"⚡ DEBUG MODE: Processing only {DEBUG_LIMIT} images")
print(f"Raw BDD dir:     {BDD_RAW_DIR}")
print(f"YOLO dataset:    {YOLO_DATASET_DIR}  (Colab Local SSD)")
# Out:
# Raw BDD dir:     /content/drive/MyDrive/EcoCAR/datasets/bdd100k_raw
# YOLO dataset:    /content/bdd100k_yolo  (Colab Local SSD)

# %% [markdown]
# ## 3 — Clone/Upload Source Utilities

# %%
# !git clone https://github.com/ChenSiyun1234/EcoCAR-Perception-Pipeline-YOLO26-BDD100K.git /content/ecocar
PROJECT_SRC = "/content/ecocar/src"
if os.path.isdir(PROJECT_SRC):
    sys.path.insert(0, os.path.dirname(PROJECT_SRC))
    print(f"✅ Added {PROJECT_SRC} to path")
else:
    print(f"⚠️ Source dir not found, using inline definitions below.")
# Out:
# Cloning into '/content/ecocar'...
# remote: Enumerating objects: 81, done.
# remote: Counting objects: 100% (81/81), done.
# remote: Compressing objects: 100% (59/59), done.
# remote: Total 81 (delta 35), reused 64 (delta 21), pack-reused 0 (from 0)
# Receiving objects: 100% (81/81), 1.20 MiB | 7.70 MiB/s, done.
# Resolving deltas: 100% (35/35), done.
# ✅ Added /content/ecocar/src to path

# %%
try:
    from src.dataset_utils import (
        BDD_CLASSES, CLASS_TO_ID, ID_TO_CLASS,
        convert_bdd100k_to_yolo, create_dataset_yaml,
        verify_dataset_structure, link_or_copy_images,
        print_class_distribution, get_bdd_class_mapping,
        find_expected_images,
    )
    print("✅ Imported from src.dataset_utils")
except ImportError:
    print("⚠️ Could not import src.dataset_utils, using inline definitions")

    import json, shutil
    from pathlib import Path
    import yaml
    from tqdm import tqdm

    BDD_CLASSES = [
        "person", "rider", "car", "truck", "bus",
        "train", "motorcycle", "bicycle", "traffic light", "traffic sign",
    ]
    CLASS_TO_ID = {name: idx for idx, name in enumerate(BDD_CLASSES)}
    ID_TO_CLASS = {idx: name for idx, name in enumerate(BDD_CLASSES)}

    def get_bdd_class_mapping():
        return BDD_CLASSES, CLASS_TO_ID, ID_TO_CLASS

    def convert_bdd100k_to_yolo(json_path, output_label_dir, img_width=1280, img_height=720, debug_limit=None):
        os.makedirs(output_label_dir, exist_ok=True)
        with open(json_path, 'r') as f:
            data = json.load(f)
        if debug_limit:
            data = data[:debug_limit]
        class_counts = {c: 0 for c in BDD_CLASSES}
        for frame in tqdm(data, desc="Converting"):
            stem = Path(frame['name']).stem
            label_path = os.path.join(output_label_dir, stem + '.txt')
            lines = []
            for label in (frame.get('labels') or []):
                cat = label.get('category', '')
                if cat not in CLASS_TO_ID: continue
                box = label.get('box2d')
                if not box: continue
                x1, y1, x2, y2 = box['x1'], box['y1'], box['x2'], box['y2']
                xc = max(0, min(1, ((x1+x2)/2) / img_width))
                yc = max(0, min(1, ((y1+y2)/2) / img_height))
                w = max(0, min(1, (x2-x1) / img_width))
                h = max(0, min(1, (y2-y1) / img_height))
                lines.append(f"{CLASS_TO_ID[cat]} {xc:.6f} {yc:.6f} {w:.6f} {h:.6f}")
                class_counts[cat] += 1
            with open(label_path, 'w') as f:
                f.write('\n'.join(lines))
        return class_counts

    def create_dataset_yaml(dataset_root, output_path, train_images='images/train', val_images='images/val'):
        config = {'path': dataset_root, 'train': train_images, 'val': val_images,
                  'nc': len(BDD_CLASSES), 'names': {i: n for i, n in enumerate(BDD_CLASSES)}}
        os.makedirs(os.path.dirname(output_path) or '.', exist_ok=True)
        with open(output_path, 'w') as f:
            yaml.dump(config, f, default_flow_style=False, sort_keys=False)
        print(f"✅ YAML written to: {output_path}")
        return os.path.abspath(output_path)

    def verify_dataset_structure(dataset_root):
        all_ok = True
        for sub in ['images/train','images/val','labels/train','labels/val']:
            full = os.path.join(dataset_root, sub)
            if not os.path.isdir(full):
                print(f"❌ Missing: {full}"); all_ok = False
            else:
                c = len(os.listdir(full))
                print(f"✅ {sub}: {c} files")
                if c == 0: all_ok = False
        return all_ok

    def link_or_copy_images(src_dir, dst_dir, use_symlinks=True, debug_limit=None, image_list=None):
        os.makedirs(dst_dir, exist_ok=True)
        if image_list is not None:
            files = image_list
        else:
            try:
                files = sorted([f for f in os.listdir(src_dir)
                                if f.lower().endswith(('.jpg', '.jpeg', '.png'))])
            except OSError:
                print(f"⚠ OSError listing {src_dir}.")
                return 0
        if debug_limit:
            files = files[:debug_limit]
        count = 0
        missing = 0
        for f in tqdm(files, desc=f"→ {os.path.basename(dst_dir)}"):
            src = os.path.join(src_dir, f)
            dst = os.path.join(dst_dir, f)
            if not os.path.exists(src):
                missing += 1; continue
            if os.path.exists(dst):
                count += 1; continue
            ok = False
            try:
                if use_symlinks:
                    os.symlink(src, dst)
                else:
                    shutil.copy2(src, dst)
                ok = True
            except OSError:
                try:
                    shutil.copy2(src, dst)
                    ok = True
                except FileNotFoundError:
                    ok = False
            if ok and os.path.exists(dst):
                count += 1
            else:
                missing += 1
        print(f"Linked/copied: {count}, Missing/skipped: {missing}")
        return count

    def find_expected_images(label_dir, image_src_dirs):
        """Find images matching labels using probe-based FUSE-safe search.

        Avoids os.listdir() on Drive dirs (crashes with ~40K files) and
        avoids blind per-file os.path.exists() x 20K (FUSE timeout).
        Instead: probe 10 files to find a working dir, then full match.
        """
        if isinstance(image_src_dirs, str):
            image_src_dirs = [image_src_dirs]

        # Deprioritize symlinks (FUSE errors on Google Drive)
        real_dirs = [d for d in image_src_dirs if os.path.isdir(d) and not os.path.islink(d)]
        link_dirs = [d for d in image_src_dirs if os.path.isdir(d) and os.path.islink(d)]
        ordered_dirs = real_dirs + link_dirs

        if not ordered_dirs:
            print(f"⚠ No valid dirs among: {image_src_dirs}")
            return [], ''

        # Get label stems from LOCAL dir (fast Colab SSD)
        label_files = sorted([f for f in os.listdir(label_dir) if f.endswith('.txt')])
        label_stems = [os.path.splitext(f)[0] for f in label_files]
        print(f"  📝 {len(label_stems)} label files to match")
        if not label_stems:
            return [], ''

        # Probe: test 10 files per dir to find one that works
        PROBE_SIZE = 10
        probe_stems = label_stems[:PROBE_SIZE]
        chosen_dir = ''
        for d in ordered_dirs:
            hits = 0
            for stem in probe_stems:
                for ext in ['.jpg', '.jpeg', '.png']:
                    if os.path.exists(os.path.join(d, stem + ext)):
                        hits += 1
                        break
            if hits > 0:
                print(f"  ✅ Probe: {hits}/{PROBE_SIZE} found in {d}")
                chosen_dir = d
                break
            else:
                print(f"  ❌ Probe: 0/{PROBE_SIZE} found in {d}")

        if not chosen_dir:
            print('⚠ No directory responded to probe.')
            return [], ''

        # Full match against the working directory
        print(f"  🔍 Full matching against: {chosen_dir}")
        expected = []
        for stem in tqdm(label_stems, desc='Matching'):
            for ext in ['.jpg', '.jpeg', '.png']:
                candidate = stem + ext
                if os.path.exists(os.path.join(chosen_dir, candidate)):
                    expected.append(candidate)
                    break
        return expected, chosen_dir

    def print_class_distribution(class_counts):
        total = sum(class_counts.values())
        print(f"\n{'Class':<20} {'Count':>8} {'Pct':>7}")
        print('─'*37)
        for name in BDD_CLASSES:
            c = class_counts.get(name, 0)
            pct = (c/total*100) if total else 0
            print(f"{name:<20} {c:>8,} {pct:>6.1f}%")
        print('─'*37)
        print(f"{'TOTAL':<20} {total:>8,}")
# Out:
# ✅ Imported from src.dataset_utils

# %% [markdown]
# ## 4 — Locate BDD100K Files

# %%
import glob, yaml

paths_cfg_path = os.path.join(ECOCAR_ROOT, 'paths_config.yaml')
TRAIN_LABEL = None
VAL_LABEL = None
BDD_IMAGES_BASE = None

if os.path.isfile(paths_cfg_path):
    with open(paths_cfg_path, 'r') as f:
        pcfg = yaml.safe_load(f)
    for key in pcfg:
        val = pcfg[key]
        if isinstance(val, str) and os.path.isfile(val):
            if 'train' in key and val.endswith('.json'):
                TRAIN_LABEL = val
            elif 'val' in key and val.endswith('.json'):
                VAL_LABEL = val
    if TRAIN_LABEL:
        print(f'✅ Loaded label paths from {paths_cfg_path}')

# Fallback: auto-detect labels
if not TRAIN_LABEL or not VAL_LABEL:
    for p in [
        os.path.join(BDD_RAW_DIR, 'labels', 'bdd100k_labels_images_train.json'),
        os.path.join(BDD_RAW_DIR, 'labels', 'bdd100k_labels_images_val.json'),
        os.path.join(BDD_RAW_DIR, 'bdd100k', 'labels', 'bdd100k_labels_images_train.json'),
        os.path.join(BDD_RAW_DIR, 'bdd100k', 'labels', 'bdd100k_labels_images_val.json'),
    ]:
        if os.path.isfile(p):
            if 'train' in os.path.basename(p) and not TRAIN_LABEL:
                TRAIN_LABEL = p
            elif 'val' in os.path.basename(p) and not VAL_LABEL:
                VAL_LABEL = p

# Auto-detect image base: prefer REAL dirs over symlinks
# 100k/ is real; bdd100k/images/100k/ may be symlinks that break FUSE
if not BDD_IMAGES_BASE:
    for p in [
        os.path.join(BDD_RAW_DIR, '100k'),
        os.path.join(BDD_RAW_DIR, 'images', '100k'),
        os.path.join(BDD_RAW_DIR, 'bdd100k', 'images', '100k'),
    ]:
        if os.path.isdir(p) and (
            os.path.isdir(os.path.join(p, 'train')) or
            os.path.isdir(os.path.join(p, 'val'))
        ):
            BDD_IMAGES_BASE = p
            break

print(f"Train labels: {TRAIN_LABEL}")
print(f"Val labels:   {VAL_LABEL}")
print(f"Images base:  {BDD_IMAGES_BASE}")
if all([TRAIN_LABEL, VAL_LABEL, BDD_IMAGES_BASE]):
    print('\n✅ All paths detected!')
else:
    print('\n❌ Could not auto-detect all paths. Set manually above.')
# Out:
# ✅ Loaded label paths from /content/drive/MyDrive/EcoCAR/paths_config.yaml
# Train labels: /content/drive/MyDrive/EcoCAR/datasets/bdd100k_raw/labels/bdd100k_labels_images_train.json
# Val labels:   /content/drive/MyDrive/EcoCAR/datasets/bdd100k_raw/labels/bdd100k_labels_images_val.json
# Images base:  /content/drive/MyDrive/EcoCAR/datasets/bdd100k_raw/100k
#
# ✅ All paths detected!

# %% [markdown]
# ## 5 — Convert Annotations to YOLO Format

# %%
for split in ['train', 'val']:
    os.makedirs(os.path.join(YOLO_DATASET_DIR, 'images', split), exist_ok=True)
    os.makedirs(os.path.join(YOLO_DATASET_DIR, 'labels', split), exist_ok=True)
print("📁 YOLO local dataset directories created")
# Out:
# 📁 YOLO local dataset directories created

# %%
print("="*50 + "\n Converting TRAIN labels\n" + "="*50)
train_counts = convert_bdd100k_to_yolo(
    json_path=TRAIN_LABEL,
    output_label_dir=os.path.join(YOLO_DATASET_DIR, 'labels', 'train'),
    debug_limit=DEBUG_LIMIT,
)
print("\nTrain class distribution:")
print_class_distribution(train_counts)
# Out:
# ==================================================
#  Converting TRAIN labels
# ==================================================
# Converting annotations: 100%|██████████| 16942/16942 [00:03<00:00, 5024.51it/s]
# ⚠ Skipped 161040 annotations with unknown categories
#
# Train class distribution:
#
# Class                   Count     Pct
# ─────────────────────────────────────
# person                 22,204    7.2%
# rider                   1,115    0.4%
# car                   173,398   56.0%
# truck                   7,245    2.3%
# bus                     2,835    0.9%
# train                      20    0.0%
# motorcycle                  0    0.0%
# bicycle                     0    0.0%
# traffic light          44,865   14.5%
# traffic sign           58,020   18.7%
# ─────────────────────────────────────
# TOTAL                 309,702

# %%
print("="*50 + "\n Converting VAL labels\n" + "="*50)
val_counts = convert_bdd100k_to_yolo(
    json_path=VAL_LABEL,
    output_label_dir=os.path.join(YOLO_DATASET_DIR, 'labels', 'val'),
    debug_limit=DEBUG_LIMIT,
)
print("\nVal class distribution:")
print_class_distribution(val_counts)
# Out:
# ==================================================
#  Converting VAL labels
# ==================================================
# Converting annotations: 100%|██████████| 2990/2990 [00:00<00:00, 5312.90it/s]
# ⚠ Skipped 28745 annotations with unknown categories
#
# Val class distribution:
#
# Class                   Count     Pct
# ─────────────────────────────────────
# person                  3,664    6.7%
# rider                     179    0.3%
# car                    30,460   56.1%
# truck                   1,266    2.3%
# bus                       480    0.9%
# train                       4    0.0%
# motorcycle                  0    0.0%
# bicycle                     0    0.0%
# traffic light           7,904   14.6%
# traffic sign           10,365   19.1%
# ─────────────────────────────────────
# TOTAL                  54,322

# %% [markdown]
# ## 6 — Link/Copy Images (FUSE-Safe)
#
# Uses a probe-based approach to avoid Google Drive FUSE crashes:
# - No `os.listdir()` on Drive directories (crashes with ~40K files)
# - Probes 10 files first to find a working directory
# - Then does full matching via direct `os.path.exists()` per label

# %%
# ── Build candidate image source directories ──────────────────────
# FUSE-safe diagnostics: probe-based, NO os.listdir() on Drive
print("=" * 60)
print(" IMAGE SOURCE DIAGNOSTICS (probe-based, FUSE-safe)")
print("=" * 60)

CANDIDATE_IMG_DIRS = []
all_candidates = []

if BDD_IMAGES_BASE:
    all_candidates.extend([
        os.path.join(BDD_IMAGES_BASE, 'train'),
        os.path.join(BDD_IMAGES_BASE, 'val'),
    ])
extra = [
    os.path.join(BDD_RAW_DIR, '100k', 'train'),
    os.path.join(BDD_RAW_DIR, '100k', 'val'),
    os.path.join(BDD_RAW_DIR, 'bdd100k', 'images', '100k', 'train'),
    os.path.join(BDD_RAW_DIR, 'bdd100k', 'images', '100k', 'val'),
]
for c in extra:
    if c not in all_candidates:
        all_candidates.append(c)

# Probe each dir with a sample file to test responsiveness
# Use a known BDD100K filename pattern for probing
for d in all_candidates:
    if not os.path.isdir(d):
        print(f"  ❌ MISSING: {d}")
        continue
    is_link = os.path.islink(d)
    tag = "SYMLINK" if is_link else "REAL DIR"
    # Quick probe: can we access a file in this dir?
    try:
        # Try os.listdir with a timeout-safe approach
        # If it hangs, we'll catch it in actual matching
        probe_ok = os.access(d, os.R_OK)
        if probe_ok:
            print(f"  {'🔗' if is_link else '✅'} {tag}: {d}  (accessible)")
            CANDIDATE_IMG_DIRS.append(d)
        else:
            print(f"  ⚠️ {tag}: {d}  (not readable)")
    except OSError as e:
        print(f"  ⚠️ {tag}: {d}  (error: {e})")

# Sort: real dirs first, symlinks last
real = [d for d in CANDIDATE_IMG_DIRS if not os.path.islink(d)]
links = [d for d in CANDIDATE_IMG_DIRS if os.path.islink(d)]
CANDIDATE_IMG_DIRS = real + links
print(f"\n📋 {len(CANDIDATE_IMG_DIRS)} candidate dirs (real dirs prioritized)")
# Out:
# ============================================================
#  IMAGE SOURCE DIAGNOSTICS (probe-based, FUSE-safe)
# ============================================================
#   ✅ REAL DIR: /content/drive/MyDrive/EcoCAR/datasets/bdd100k_raw/100k/train  (accessible)
#   ✅ REAL DIR: /content/drive/MyDrive/EcoCAR/datasets/bdd100k_raw/100k/val  (accessible)
#   🔗 SYMLINK: /content/drive/MyDrive/EcoCAR/datasets/bdd100k_raw/bdd100k/images/100k/train  (accessible)
#   🔗 SYMLINK: /content/drive/MyDrive/EcoCAR/datasets/bdd100k_raw/bdd100k/images/100k/val  (accessible)
#
# 📋 4 candidate dirs (real dirs prioritized)

# %%
# ── Link TRAIN images ──────────────────────────────────────────────
train_label_dir = os.path.join(YOLO_DATASET_DIR, 'labels', 'train')
train_img_dst = os.path.join(YOLO_DATASET_DIR, 'images', 'train')

print(f"Searching for train images in {len(CANDIDATE_IMG_DIRS)} candidate dirs...")
expected_train_imgs, train_src_dir = find_expected_images(
    train_label_dir, CANDIDATE_IMG_DIRS,
)
print(f"\n✅ Found {len(expected_train_imgs)} matching train images")
if train_src_dir:
    print(f"   Source: {train_src_dir}")

n_train = 0
if expected_train_imgs and train_src_dir:
    n_train = link_or_copy_images(
        train_src_dir, train_img_dst,
        use_symlinks=True, debug_limit=DEBUG_LIMIT,
        image_list=expected_train_imgs,
    )
print(f"✅ {n_train} train images linked")
# Out:
# Searching for train images in 4 candidate dirs...
#   📝 16942 label files to match
#   ✅ Probe: 9/10 found in /content/drive/MyDrive/EcoCAR/datasets/bdd100k_raw/100k/train
#   🔍 Full matching against: /content/drive/MyDrive/EcoCAR/datasets/bdd100k_raw/100k/train
# Matching: 100%|██████████| 16942/16942 [00:06<00:00, 2798.27it/s]
# ✅ Found 16942 matching train images
#    Source: /content/drive/MyDrive/EcoCAR/datasets/bdd100k_raw/100k/train
# Linking images → train: 100%|██████████| 16942/16942 [00:01<00:00, 16939.49it/s]
# ✅ 16942 train images linked

# %%
# ── Link VAL images ────────────────────────────────────────────────
# Val images may live in the SAME folder as train (nb01's 85/15 split)
val_label_dir = os.path.join(YOLO_DATASET_DIR, 'labels', 'val')
val_img_dst = os.path.join(YOLO_DATASET_DIR, 'images', 'val')

print(f"Searching for val images in {len(CANDIDATE_IMG_DIRS)} candidate dirs...")
expected_val_imgs, val_src_dir = find_expected_images(
    val_label_dir, CANDIDATE_IMG_DIRS,
)
print(f"\n✅ Found {len(expected_val_imgs)} matching val images")
if val_src_dir:
    print(f"   Source: {val_src_dir}")

n_val = 0
if expected_val_imgs and val_src_dir:
    n_val = link_or_copy_images(
        val_src_dir, val_img_dst,
        use_symlinks=True, debug_limit=DEBUG_LIMIT,
        image_list=expected_val_imgs,
    )
print(f"✅ {n_val} val images linked")
# Out:
# Searching for val images in 4 candidate dirs...
#   📝 2990 label files to match
#   ✅ Probe: 10/10 found in /content/drive/MyDrive/EcoCAR/datasets/bdd100k_raw/100k/train
#   🔍 Full matching against: /content/drive/MyDrive/EcoCAR/datasets/bdd100k_raw/100k/train
# Matching: 100%|██████████| 2990/2990 [00:00<00:00, 4443.69it/s]
# ✅ Found 2990 matching val images
#    Source: /content/drive/MyDrive/EcoCAR/datasets/bdd100k_raw/100k/train
# Linking images → val: 100%|██████████| 2990/2990 [00:00<00:00, 20149.18it/s]
# ✅ 2990 val images linked

# %% [markdown]
# ## 7 — Generate Dataset YAML

# %%
import shutil
yaml_path = os.path.join(YOLO_DATASET_DIR, 'bdd100k_yolo.yaml')
yaml_backup = os.path.join(ECOCAR_ROOT, 'datasets', 'bdd100k_yolo.yaml')
yaml_file = create_dataset_yaml(dataset_root=YOLO_DATASET_DIR, output_path=yaml_path)
shutil.copy2(yaml_path, yaml_backup)
print(f"✅ YAML backed up to: {yaml_backup}")
print("\nGenerated YAML:")
with open(yaml_path, 'r') as f:
    print(f.read())
# Out:
# ✅ Dataset YAML written to: /content/bdd100k_yolo/bdd100k_yolo.yaml
# ✅ YAML backed up to: /content/drive/MyDrive/EcoCAR/datasets/bdd100k_yolo.yaml
#
# Generated YAML:
# path: /content/bdd100k_yolo
# train: images/train
# val: images/val
# nc: 10
# names:
#   0: person
#   1: rider
#   2: car
#   3: truck
#   4: bus
#   5: train
#   6: motorcycle
#   7: bicycle
#   8: traffic light
#   9: traffic sign

# %%
print("="*50 + "\n DATASET VERIFICATION\n" + "="*50)
ok = verify_dataset_structure(YOLO_DATASET_DIR)
print("\n🎯 Dataset ready!" if ok else "\n⚠️ Fix issues above.")
# Out:
# ==================================================
#  DATASET VERIFICATION
# ==================================================
# ✅ images/train: 16942 files
# ✅ images/val: 2990 files
# ✅ labels/train: 16942 files
# ✅ labels/val: 2990 files
#
# 🎯 Dataset ready!

# %% [markdown]
# ## 8 — 📦 Archive to Drive (for Notebook 08)
#
# Creates a tar archive of the full YOLO dataset (images + labels + YAML)
# and uploads it to Google Drive.
#
# **Why tar?**
# - FUSE is unreliable for 20K+ individual file operations
# - Notebook 08 can restore the entire dataset in one `tar -xf` command
# - `tar -h` dereferences symlinks so the archive contains real file data
# - No gzip compression (JPEG is already compressed) → faster to create
#
# **Expected archive size:** ~2-3 GB for ~20K images

# %%
import subprocess, time

TAR_NAME = "bdd100k_yolo_nb02.tar"
TAR_LOCAL = f"/content/{TAR_NAME}"
TAR_DRIVE = os.path.join(ECOCAR_ROOT, "datasets", TAR_NAME)

print("📦 Creating tar archive (dereferences symlinks, no compression)...")
print("   This reads all images from Drive once → may take 5-15 min.")
t0 = time.time()

result = subprocess.run(
    ["tar", "-chf", TAR_LOCAL,
     "-C", YOLO_DATASET_DIR,
     "images", "labels", "bdd100k_yolo.yaml"],
    capture_output=True, text=True
)

if result.returncode == 0:
    tar_size_gb = os.path.getsize(TAR_LOCAL) / (1024**3)
    elapsed = time.time() - t0
    print(f"✅ Archive created: {TAR_LOCAL}")
    print(f"   Size: {tar_size_gb:.2f} GB | Time: {elapsed:.0f}s")
else:
    print(f"❌ tar failed: {result.stderr}")
    print("   Try running without -h flag if symlink resolution fails:")
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# tar: images/train/4fc7844c-00c2e97f.jpg: file changed as we read it
# tar: images/train/9e10ef26-3ba7ffe7.jpg: file changed as we read it
# tar: images/train/8db46927-5b4f9a60.jpg: file changed as we read it
# tar: images/train/03626025-35d58c07.jpg: file changed as we read it
# tar: images/train/5319f6b5-730a22b5.jpg: file changed as we read it
# tar: images/train/0d62200b-85aeaa3d.jpg: file changed as we read it
# tar: images/train/2e3be709-bb4257ed.jpg: file changed as we read it
# tar: images/train/05f899e8-b72038aa.jpg: file changed as we read it
# tar: images/train/83ff6477-89cb2748.jpg: file changed as we read it
# tar: images/train/1a8d12f7-a60d9f53.jpg: file changed as we read it
# tar: images/train/73d066de-ab57f2e1.jpg: file changed as we read it
# tar: images/train/ad84b0ff-a1953456.jpg: file changed as we read it
# tar: images/train/a2143bc8-b028c118.jpg: file changed as we read it
# tar: images/train/a4f580fe-a86e891d.jpg: file changed as we read it
# tar: images/train/a5c23928-7ca89884.jpg: file changed as we read it
# tar: images/train/44191a9e-5107e1db.jpg: file changed as we read it
# tar: images/train/10db12e7-c4d6b097.jpg: file changed as we read it
# tar: images/train/0d04b217-da8bf6b7.jpg: file changed as we read it
# tar: images/train/6cf7a093-29129f20.jpg: file changed as we read it
# tar: images/train/818d43d5-ac7728ec.jpg: file changed as we read it
# tar: images/train/906ca9ac-8b76cffa.jpg: file changed as we read it
# tar: images/train/159afe2c-966a348a.jpg: file changed as we read it
# tar: images/train/8d743c1c-e31fea72.jpg: file changed as we read it
# tar: images/train/4fa06b93-1f783439.jpg: file changed as we read it
# tar: images/train/ad1be482-d8ab7370.jpg: file changed as we read it
# tar: images/train/1797e2d4-f89a6266.jpg: file changed as we read it
# tar: images/train/10ef4dad-4f01ef2b.jpg: file changed as we read it
# tar: images/train/abc895a9-4b63353c.jpg: file changed as we read it
# tar: images/train/559fed19-7893646f.jpg: file changed as we read it
# tar: images/train/af11789e-c629fb40.jpg: file changed as we read it
# tar: images/train/2424fdb0-37fb632a.jpg: file changed as we read it
# tar: images/train/4495ccfd-1a46993f.jpg: file changed as we read it
# tar: images/train/2e40dcb9-6bf701e0.jpg: file changed as we read it
# tar: images/train/9fa31cf7-22338914.jpg: file changed as we read it
# tar: images/train/5cefe7ed-792c026c.jpg: file changed as we read it
# tar: images/train/90752702-563b76f8.jpg: file changed as we read it
# tar: images/train/60fd824b-fbe6b586.jpg: file changed as we read it
# tar: images/train/291f5d0d-281d2123.jpg: file changed as we read it
# tar: images/train/8cf20346-cbe42186.jpg: file changed as we read it
# tar: images/train/6afe479e-8627c059.jpg: file changed as we read it
# tar: images/train/076399f2-fb3e745b.jpg: file changed as we read it
# tar: images/train/80b3fc35-05408ee6.jpg: file changed as we read it
# tar: images/train/3bae6552-fccf9f0d.jpg: file changed as we read it
# tar: images/train/1fa530ed-db6a6975.jpg: file changed as we read it
# tar: images/train/7e567f70-f3fc488e.jpg: file changed as we read it
# tar: images/train/2ddbd226-117d7f38.jpg: file changed as we read it
# tar: images/train/87d23267-872374de.jpg: file changed as we read it
# tar: images/train/1cbd007f-d6f0e92a.jpg: file changed as we read it
# tar: images/train/9d6d7487-fe01d7f6.jpg: file changed as we read it
# tar: images/train/323a3e5f-09d270e4.jpg: file changed as we read it
# tar: images/train/3b1b6880-1e006f29.jpg: file changed as we read it
# tar: images/train/746e7a2f-e5b66273.jpg: file changed as we read it
# tar: images/train/559e9281-ffe08f59.jpg: file changed as we read it
# tar: images/train/44602a35-9e2c28ba.jpg: file changed as we read it
# tar: images/train/fe095fe7-873e1fff.jpg: file changed as we read it
# tar: images/train/860c8b2a-05709900.jpg: file changed as we read it
# tar: images/train/31b32596-e064c0bf.jpg: file changed as we read it
# tar: images/train/14d41b10-a3556c23.jpg: file changed as we read it
# tar: images/train/258b28c0-8ed080c5.jpg: file changed as we read it
# tar: images/train/195a858f-a8435fb9.jpg: file changed as we read it
# tar: images/train/a04ac524-7b9f5191.jpg: file changed as we read it
# tar: images/train/446b9b49-f4dae92c.jpg: file changed as we read it
# tar: images/train/2c86a7d0-f409b3ce.jpg: file changed as we read it
# tar: images/train/1bea510c-9cbfcefb.jpg: file changed as we read it
# tar: images/train/0555945c-a5a83e97.jpg: file changed as we read it
# tar: images/train/4b969b37-d2b9db46.jpg: file changed as we read it
# tar: images/train/4c4bed6b-4e3d07df.jpg: file changed as we read it
# tar: images/train/aaed6ab8-94f5e858.jpg: file changed as we read it
# tar: images/train/3a738d45-741ab2b5.jpg: file changed as we read it
# tar: images/train/9df859c5-0f4c818a.jpg: file changed as we read it
# tar: images/train/14461a70-657d89c8.jpg: file changed as we read it
# tar: images/train/22442774-cbd1c4e9.jpg: file changed as we read it
# tar: images/train/57368219-c7b7d3d1.jpg: file changed as we read it
# tar: images/train/6f8a1108-a8e2febb.jpg: file changed as we read it
# tar: images/train/1370e6a7-14773a34.jpg: file changed as we read it
# tar: images/train/a06d3bca-08ce4f52.jpg: file changed as we read it
# tar: images/train/4fee5fdf-f52dd83f.jpg: file changed as we read it
# tar: images/train/74078272-33626fd3.jpg: file changed as we read it
# tar: images/train/52b24374-74174bc8.jpg: file changed as we read it
# tar: images/train/9cfc316c-3d2c95b5.jpg: file changed as we read it
# tar: images/train/78c1b0bc-cedc261f.jpg: file changed as we read it
# tar: images/train/71c52c0f-1b498e99.jpg: file changed as we read it
# tar: images/train/77b08ab8-3f8be537.jpg: file changed as we read it
# tar: images/train/0cc8aed6-cfdc30ab.jpg: file changed as we read it
# tar: images/train/5bc438dd-3015d78e.jpg: file changed as we read it
# tar: images/train/13f5618b-b077154d.jpg: file changed as we read it
# tar: images/train/11b29f2e-384d3a03.jpg: file changed as we read it
# tar: images/train/7690463b-61f6da31.jpg: file changed as we read it
# tar: images/train/1c8f05f4-e020d09f.jpg: file changed as we read it
# tar: images/train/682333dc-bd90da40.jpg: file changed as we read it
# tar: images/train/13ae64c3-cdbd8774.jpg: file changed as we read it
# tar: images/train/216bbddd-1f61f211.jpg: file changed as we read it
# tar: images/train/82df0f6b-61a9a1fc.jpg: file changed as we read it
# tar: images/train/283c4da9-5583ae20.jpg: file changed as we read it
# tar: images/train/8a2a8122-20ab1fed.jpg: file changed as we read it
# tar: images/train/7f59eb14-8c7148d9.jpg: file changed as we read it
# tar: images/train/7d8b2313-6b9b94e8.jpg: file changed as we read it
# tar: images/train/28f4668c-0908fae9.jpg: file changed as we read it
# tar: images/train/6b2f2a07-3eba5f14.jpg: file changed as we read it
# tar: images/train/7d30ede8-a6b3f4cd.jpg: file changed as we read it
# tar: images/train/2677613c-c810cdf9.jpg: file changed as we read it
# tar: images/train/4bf7ecd6-4ddf6b12.jpg: file changed as we read it
# tar: images/train/334a0cdf-7f5b5ac1.jpg: file changed as we read it
# tar: images/train/5e0af549-484e64b7.jpg: file changed as we read it
# tar: images/train/73657ad4-555f581f.jpg: file changed as we read it
# tar: images/train/179c1edd-ba42fb5e.jpg: file changed as we read it
# tar: images/train/06b6c91e-f989a46e.jpg: file changed as we read it
# tar: images/train/9b9e2805-ced67764.jpg: file changed as we read it
# tar: images/train/423f7032-3c5bf22c.jpg: file changed as we read it
# tar: images/train/68153151-e5a325c5.jpg: file changed as we read it
# tar: images/train/70b5c904-de815320.jpg: file changed as we read it
# tar: images/train/5927f35b-0d08bd87.jpg: file changed as we read it
# tar: images/train/b0c6d7c2-892d9d60.jpg: file changed as we read it
# tar: images/train/691658e6-443db26d.jpg: file changed as we read it
# tar: images/train/a305c2e8-ba2a3aad.jpg: file changed as we read it
# tar: images/train/66d19f73-770edd6d.jpg: file changed as we read it
# tar: images/train/4c790f65-0e47dca1.jpg: file changed as we read it
# tar: images/train/31fbf02e-991f3950.jpg: file changed as we read it
# tar: images/train/5b1b0c34-baf6ed1b.jpg: file changed as we read it
# tar: images/train/087ad1c6-cbc445cc.jpg: file changed as we read it
# tar: images/train/2a664d12-8e2a175b.jpg: file changed as we read it
# tar: images/train/3d4c0a55-aade3d5b.jpg: file changed as we read it
# tar: images/train/86f0b407-9e1ea1e0.jpg: file changed as we read it
# tar: images/train/08854b71-31e40c79.jpg: file changed as we read it
# tar: images/train/642dcb62-96c3a754.jpg: file changed as we read it
# tar: images/train/31eb64dc-99a1c81e.jpg: file changed as we read it
# tar: images/train/4183370f-6351f12c.jpg: file changed as we read it
# tar: images/train/a6864c25-6095e08e.jpg: file changed as we read it
# tar: images/train/580262f8-9439e313.jpg: file changed as we read it
# tar: images/train/0a176daf-d509ae60.jpg: file changed as we read it
# tar: images/train/55c6dbef-00cb78ef.jpg: file changed as we read it
# tar: images/train/1f54213a-ef541dd8.jpg: file changed as we read it
# tar: images/train/295007d8-975ea171.jpg: file changed as we read it
# tar: images/train/15430558-02a7d763.jpg: file changed as we read it
# tar: images/train/1edda332-558a5e98.jpg: file changed as we read it
# tar: images/train/9f505414-4c429d03.jpg: file changed as we read it
# tar: images/train/a5a340f9-6cc4da84.jpg: file changed as we read it
# tar: images/train/9d711bfb-47f5ae4a.jpg: file changed as we read it
# tar: images/train/6e226836-7e1c8e31.jpg: file changed as we read it
# tar: images/train/8f508205-053b2565.jpg: file changed as we read it
# tar: images/train/12fee2da-5ac4c7c0.jpg: file changed as we read it
# tar: images/train/17c9136a-82083e81.jpg: file changed as we read it
# tar: images/train/94cbb1bd-4ea9c8fa.jpg: file changed as we read it
# tar: images/train/b0756f3b-a987550a.jpg: file changed as we read it
# tar: images/train/3e204481-86e0f6b4.jpg: file changed as we read it
# tar: images/train/7c161b47-4012eac5.jpg: file changed as we read it
# tar: images/train/6609f630-495aca66.jpg: file changed as we read it
# tar: images/train/5c55b26c-86edb286.jpg: file changed as we read it
# tar: images/train/abb4a069-e26c0e83.jpg: file changed as we read it
# tar: images/train/50170d78-22028e52.jpg: file changed as we read it
# tar: images/train/3508eee8-ee65f0b4.jpg: file changed as we read it
# tar: images/train/01c3e892-13e4048a.jpg: file changed as we read it
# tar: images/train/723d0650-4f4a040e.jpg: file changed as we read it
# tar: images/train/647c6812-55465775.jpg: file changed as we read it
# tar: images/train/b178ca72-cd72c569.jpg: file changed as we read it
# tar: images/train/8bf67cb6-6cd9b942.jpg: file changed as we read it
# tar: images/train/0e280165-84b9023a.jpg: file changed as we read it
# tar: images/train/a0905818-9ebac170.jpg: file changed as we read it
# tar: images/train/1d8d80f3-302c8b30.jpg: file changed as we read it
# tar: images/train/452fef8c-b53f7ecf.jpg: file changed as we read it
# tar: images/train/9c34c10c-ba8bca38.jpg: file changed as we read it
# tar: images/train/51fc50e7-92e665da.jpg: file changed as we read it
# tar: images/train/5bea83ef-3475cf4a.jpg: file changed as we read it
# tar: images/train/69e3b9ce-9abe7df3.jpg: file changed as we read it
# tar: images/train/7b908547-5cfd0f25.jpg: file changed as we read it
# tar: images/train/1b3d412f-5ff082aa.jpg: file changed as we read it
# tar: images/train/33ddc4d0-96b851cb.jpg: file changed as we read it
# tar: images/train/30c92c79-644a48aa.jpg: file changed as we read it
# tar: images/train/5d7cefeb-bb1f023a.jpg: file changed as we read it
# tar: images/train/7352ed07-0c1801fd.jpg: file changed as we read it
# tar: images/train/93d5292b-e62747cf.jpg: file changed as we read it
# tar: images/train/45ba36bc-94ac5c07.jpg: file changed as we read it
# tar: images/train/954149ed-02cb09dc.jpg: file changed as we read it
# tar: images/train/922eedf6-e26800bf.jpg: file changed as we read it
# tar: images/train/53482c46-0c1026c5.jpg: file changed as we read it
# tar: images/train/2a27ffe5-f4780aac.jpg: file changed as we read it
# tar: images/train/064aa0d6-f75ff4d5.jpg: file changed as we read it
# tar: images/train/8304141a-c3bea4b3.jpg: file changed as we read it
# tar: images/train/a5e2b88a-3fe45085.jpg: file changed as we read it
# tar: images/train/8185e299-7d95a0f7.jpg: file changed as we read it
# tar: images/train/08292c37-4c5bb6b8.jpg: file changed as we read it
# tar: images/train/6bc02d44-62cf9a2b.jpg: file changed as we read it
# tar: images/train/70383091-32e2397c.jpg: file changed as we read it
# tar: images/train/3daa42c5-a33a968d.jpg: file changed as we read it
# tar: images/train/7fba2f2b-07b3c812.jpg: file changed as we read it
# tar: images/train/5a7682ec-7715a8fb.jpg: file changed as we read it
# tar: images/train/4282002e-40ff695f.jpg: file changed as we read it
# tar: images/train/646ae7e9-5f32ce12.jpg: file changed as we read it
# tar: images/train/2aee5704-f092c6fd.jpg: file changed as we read it
# tar: images/train/92bd57a8-56c02669.jpg: file changed as we read it
# tar: images/train/05f5b887-b0db3da9.jpg: file changed as we read it
# tar: images/train/93e08b6b-e5efe3ab.jpg: file changed as we read it
# tar: images/train/2a656a7b-e49e65a3.jpg: file changed as we read it
# tar: images/train/4ddcbaad-4f3ebec0.jpg: file changed as we read it
# tar: images/train/5347b7cb-9f2a63ad.jpg: file changed as we read it
# tar: images/train/34f8336e-9b3d21fe.jpg: file changed as we read it
# tar: images/train/0d4c06d5-360c6920.jpg: file changed as we read it
# tar: images/train/3cc4b870-767d5fdd.jpg: file changed as we read it
# tar: images/train/83c9bec8-a6dee65e.jpg: file changed as we read it
# tar: images/train/50b115d6-505a012a.jpg: file changed as we read it
# tar: images/train/0d39e06d-3a1e0fa3.jpg: file changed as we read it
# tar: images/train/afbcc97f-ccbdcd44.jpg: file changed as we read it
# tar: images/train/3ddb2190-f86dbf56.jpg: file changed as we read it
# tar: images/train/a33812ad-fc671ad4.jpg: file changed as we read it
# tar: images/train/49e4aa79-fc9daa10.jpg: file changed as we read it
# tar: images/train/a284eb0e-90080ebb.jpg: file changed as we read it
# tar: images/train/8214a102-dbc90059.jpg: file changed as we read it
# tar: images/train/9521c4f3-36e30a91.jpg: file changed as we read it
# tar: images/train/adf11bb5-29d4b1ab.jpg: file changed as we read it
# tar: images/train/86a58133-b8c4504c.jpg: file changed as we read it
# tar: images/train/83261f65-d24a6d1c.jpg: file changed as we read it
# tar: images/train/7fa5aaa2-12c7561c.jpg: file changed as we read it
# tar: images/train/890db595-4b885ef0.jpg: file changed as we read it
# tar: images/train/46b59de2-a7f9e986.jpg: file changed as we read it
# tar: images/train/44836dd3-1fd39001.jpg: file changed as we read it
# tar: images/train/888724ad-573bcbaa.jpg: file changed as we read it
# tar: images/train/a489e935-f5a586b5.jpg: file changed as we read it
# tar: images/train/8c96235a-bf65fac4.jpg: file changed as we read it
# tar: images/train/44f99ac4-053ee28e.jpg: file changed as we read it
# tar: images/train/39975819-348b6294.jpg: file changed as we read it
# tar: images/train/1fd756ef-e65616cc.jpg: file changed as we read it
# tar: images/train/118ac82b-22758630.jpg: file changed as we read it
# tar: images/train/b12df0f8-191a8a0f.jpg: file changed as we read it
# tar: images/train/908545b7-8ea3ec3c.jpg: file changed as we read it
# tar: images/train/45fa63d2-b3f39a8d.jpg: file changed as we read it
# tar: images/train/6d8beed6-a56cff1d.jpg: file changed as we read it
# tar: images/train/96840ac1-00f1f069.jpg: file changed as we read it
# tar: images/train/89a866b7-0933f56b.jpg: file changed as we read it
# tar: images/train/819913b8-3e018dc0.jpg: file changed as we read it
# tar: images/train/9cb06038-9407a37f.jpg: file changed as we read it
# tar: images/train/5e315082-d13ee625.jpg: file changed as we read it
# tar: images/train/aee5e9bd-8e9ed651.jpg: file changed as we read it
# tar: images/train/1d4a2cd0-387e3cbf.jpg: file changed as we read it
# tar: images/train/67d31922-480c73ec.jpg: file changed as we read it
# tar: images/train/81d5db72-5f14bd16.jpg: file changed as we read it
# tar: images/train/3e1d58f4-8cdfb460.jpg: file changed as we read it
# tar: images/train/50ecc033-dce925f2.jpg: file changed as we read it
# tar: images/train/36dd94c3-fc616076.jpg: file changed as we read it
# tar: images/train/1f4b8e7d-82f7e836.jpg: file changed as we read it
# tar: images/train/1e8b87a9-ad66a9a2.jpg: file changed as we read it
# tar: images/train/87c1ae7e-777df460.jpg: file changed as we read it
# tar: images/train/ac63801e-b875bec7.jpg: file changed as we read it
# tar: images/train/a2b6b173-7f5895c0.jpg: file changed as we read it
# tar: images/train/8b6365f9-33df2490.jpg: file changed as we read it
# tar: images/train/1c20ca7a-8af5dea4.jpg: file changed as we read it
# tar: images/train/aa1f79fc-65466709.jpg: file changed as we read it
# tar: images/train/9c1b4928-c7239ded.jpg: file changed as we read it
# tar: images/train/63d85c31-490b8748.jpg: file changed as we read it
# tar: images/train/7c91a5fe-de49fd5d.jpg: file changed as we read it
# tar: images/train/3bdb8590-d2a9ad60.jpg: file changed as we read it
# tar: images/train/05f38f06-96293250.jpg: file changed as we read it
# tar: images/train/484cdf38-2d4010c5.jpg: file changed as we read it
# tar: images/train/ab25f06f-9e53b3a9.jpg: file changed as we read it
# tar: images/train/a7a4f4fc-798c21f1.jpg: file changed as we read it
# tar: images/train/b1552ab4-8260fcd4.jpg: file changed as we read it
# tar: images/train/0c8d4258-6f9554c0.jpg: file changed as we read it
# tar: images/train/6faabc23-e9f83fea.jpg: file changed as we read it
# tar: images/train/358597e2-e4bb4eb5.jpg: file changed as we read it
# tar: images/train/4de50802-518ec44b.jpg: file changed as we read it
# tar: images/train/a05eb1ff-eb36fb05.jpg: file changed as we read it
# tar: images/train/79e23c67-d82eb5d0.jpg: file changed as we read it
# tar: images/train/54a450b5-65ba0d9d.jpg: file changed as we read it
# tar: images/train/6919e619-193e434b.jpg: file changed as we read it
# tar: images/train/ad22a2a2-5acaee34.jpg: file changed as we read it
# tar: images/train/6fe10940-8db4f382.jpg: file changed as we read it
# tar: images/train/9adabb72-392129e3.jpg: file changed as we read it
# tar: images/train/647fbeea-81f59c62.jpg: file changed as we read it
# tar: images/train/5e620c39-f5d41ec8.jpg: file changed as we read it
# tar: images/train/2dac651d-3041691b.jpg: file changed as we read it
# tar: images/train/9abc561a-5084f2c0.jpg: file changed as we read it
# tar: images/train/975ed9ec-873cab5b.jpg: file changed as we read it
# tar: images/train/7b2e220c-553a4105.jpg: file changed as we read it
# tar: images/train/9ab9a752-c6d0af5c.jpg: file changed as we read it
# tar: images/train/50f8f5a4-7f10329b.jpg: file changed as we read it
# tar: images/train/808ff399-d8e0978b.jpg: file changed as we read it
# tar: images/train/95f4802d-e6648b8d.jpg: file changed as we read it
# tar: images/train/56316893-9de6c6a0.jpg: file changed as we read it
# tar: images/train/4b645c19-d30a8e12.jpg: file changed as we read it
# tar: images/train/6d4175f7-648dd8c0.jpg: file changed as we read it
# tar: images/train/95ebd7d6-87e7b9b2.jpg: file changed as we read it
# tar: images/train/546ff131-57c502ca.jpg: file changed as we read it
# tar: images/train/425bd1a0-6f12fa0b.jpg: file changed as we read it
# tar: images/train/10c868d4-8af68f5a.jpg: file changed as we read it
# tar: images/train/33ee65a7-b9c417e4.jpg: file changed as we read it
# tar: images/train/7ba2179d-a4deca43.jpg: file changed as we read it
# tar: images/train/1e9e8d92-69576065.jpg: file changed as we read it
# tar: images/train/0870105b-f772e964.jpg: file changed as we read it
# tar: images/train/a7f2752d-e9d362b7.jpg: file changed as we read it
# tar: images/train/a2b1ab28-cb84b273.jpg: file changed as we read it
# tar: images/train/1f75d1a8-ffae5c41.jpg: file changed as we read it
# tar: images/train/074f53a8-085ed8fa.jpg: file changed as we read it
# tar: images/train/3be9c61f-072c6301.jpg: file changed as we read it
# tar: images/train/02b3fce2-28a8c45f.jpg: file changed as we read it
# tar: images/train/5fc14564-49b1edc3.jpg: file changed as we read it
# tar: images/train/0989aa44-922b38b2.jpg: file changed as we read it
# tar: images/train/6af899e8-6eeb522b.jpg: file changed as we read it
# tar: images/train/aefd1f1c-56ec0e79.jpg: file changed as we read it
# tar: images/train/42a85f0a-2851df45.jpg: file changed as we read it
# tar: images/train/70aaa60c-f5321bef.jpg: file changed as we read it
# tar: images/train/90bbabce-29548262.jpg: file changed as we read it
# tar: images/train/10c72910-55102d2f.jpg: file changed as we read it
# tar: images/train/69916b93-0f9a49fa.jpg: file changed as we read it
# tar: images/train/a7e8be68-c406a9fe.jpg: file changed as we read it
# tar: images/train/08e3c891-51d3dce6.jpg: file changed as we read it
# tar: images/train/8495351f-facdef8b.jpg: file changed as we read it
# tar: images/train/6cf322e4-e7cdcb6f.jpg: file changed as we read it
# tar: images/train/261820d9-7e817990.jpg: file changed as we read it
# tar: images/train/56079b3c-45a1f070.jpg: file changed as we read it
# tar: images/train/72d3f610-cb6bbd68.jpg: file changed as we read it
# tar: images/train/b05b8490-9e18fccc.jpg: file changed as we read it
# tar: images/train/377ddebc-eecbad5e.jpg: file changed as we read it
# tar: images/train/238fcaba-b8deea6f.jpg: file changed as we read it
# tar: images/train/708120e0-baa63924.jpg: file changed as we read it
# tar: images/train/af9cda1a-cbca3958.jpg: file changed as we read it
# tar: images/train/5da1fb7e-40a68569.jpg: file changed as we read it
# tar: images/train/36c96705-e2bbe71a.jpg: file changed as we read it
# tar: images/train/6f8a1108-bfbf89d3.jpg: file changed as we read it
# tar: images/train/799ada26-d40fb86b.jpg: file changed as we read it
# tar: images/train/6563977e-2fad0d5f.jpg: file changed as we read it
# tar: images/train/78d880ff-a09a15ff.jpg: file changed as we read it
# tar: images/train/79cb4102-e3f167e9.jpg: file changed as we read it
# tar: images/train/175ea080-fd5f7024.jpg: file changed as we read it
# tar: images/train/8b38e147-2cf645f3.jpg: file changed as we read it
# tar: images/train/135a9651-46c92e9d.jpg: file changed as we read it
# tar: images/train/20e4809f-7470918c.jpg: file changed as we read it
# tar: images/train/97348813-5cd530fb.jpg: file changed as we read it
# tar: images/train/0977bc8b-4dc8eea6.jpg: file changed as we read it
# tar: images/train/a3a0f34f-3eb7492b.jpg: file changed as we read it
# tar: images/train/2438bf3d-eade7838.jpg: file changed as we read it
# tar: images/train/a26effb9-127b6ea1.jpg: file changed as we read it
# tar: images/train/11dc1774-e8ed82e7.jpg: file changed as we read it
# tar: images/train/658766cc-c82b9a16.jpg: file changed as we read it
# tar: images/train/5c5a6935-186f8420.jpg: file changed as we read it
# tar: images/train/95137d21-a402580b.jpg: file changed as we read it
# tar: images/train/8d57bb37-4fd462cf.jpg: file changed as we read it
# tar: images/train/9e4a1e38-084226b3.jpg: file changed as we read it
# tar: images/train/aec5f038-8e0da7af.jpg: file changed as we read it
# tar: images/train/8162921d-79b0205e.jpg: file changed as we read it
# tar: images/train/6855acc4-e3bfdddf.jpg: file changed as we read it
# tar: images/train/22ac9919-f71641d1.jpg: file changed as we read it
# tar: images/train/447e171e-4824076a.jpg: file changed as we read it
# tar: images/train/4f25f047-c3ea3d09.jpg: file changed as we read it
# tar: images/train/8de6a604-84a67f61.jpg: file changed as we read it
# tar: images/train/547aa297-d48df382.jpg: file changed as we read it
# tar: images/train/0c8d884d-33f0e078.jpg: file changed as we read it
# tar: images/train/87a9cad2-dcb74ac5.jpg: file changed as we read it
# tar: images/train/00495359-27ce9c7e.jpg: file changed as we read it
# tar: images/train/366d352a-3278a837.jpg: file changed as we read it
# tar: images/train/1538fd7e-25cb186e.jpg: file changed as we read it
# tar: images/train/2d6a0a0d-425084e9.jpg: file changed as we read it
# tar: images/train/4186a81c-39b829ce.jpg: file changed as we read it
# tar: images/train/2f81fa71-f3ce4c09.jpg: file changed as we read it
# tar: images/train/6247f776-7357862e.jpg: file changed as we read it
# tar: images/train/22dee02c-ed9fa3a5.jpg: file changed as we read it
# tar: images/train/2a174e91-f5bfd354.jpg: file changed as we read it
# tar: images/train/2c98593e-fa90786a.jpg: file changed as we read it
# tar: images/train/92542f31-fde228d3.jpg: file changed as we read it
# tar: images/train/8135481b-6f403040.jpg: file changed as we read it
# tar: images/train/5fe3454d-e026abf2.jpg: file changed as we read it
# tar: images/train/1f008ddc-eb6aa651.jpg: file changed as we read it
# tar: images/train/1781b4ed-ce48604f.jpg: file changed as we read it
# tar: images/train/4ec1bd82-25e2cad1.jpg: file changed as we read it
# tar: images/train/1fd0f6e8-8d31211d.jpg: file changed as we read it
# tar: images/train/0da39fcf-d9221d65.jpg: file changed as we read it
# tar: images/train/2577e0bf-e1619731.jpg: file changed as we read it
# tar: images/train/24b49e48-41be64d9.jpg: file changed as we read it
# tar: images/train/1e538e6d-1f3f2a5e.jpg: file changed as we read it
# tar: images/train/68068bd2-574ee2f3.jpg: file changed as we read it
# tar: images/train/1fe4bf46-a5a22ef8.jpg: file changed as we read it
# tar: images/train/27e35247-31941b74.jpg: file changed as we read it
# tar: images/train/2f34cbe7-cc62288e.jpg: file changed as we read it
# tar: images/train/101c7d35-5438f739.jpg: file changed as we read it
# tar: images/train/99816a19-340b7a1a.jpg: file changed as we read it
# tar: images/train/5cefa13c-a6234a6a.jpg: file changed as we read it
# tar: images/train/682b67b3-66795587.jpg: file changed as we read it
# tar: images/train/7c5e0dec-bd1a074b.jpg: file changed as we read it
# tar: images/train/0d53c976-ad5a9570.jpg: file changed as we read it
# tar: images/train/0375374a-c7cb24f2.jpg: file changed as we read it
# tar: images/train/8840ea56-36431cc0.jpg: file changed as we read it
# tar: images/train/02f767b2-c435cd50.jpg: file changed as we read it
# tar: images/train/6558820b-6148547e.jpg: file changed as we read it
# tar: images/train/25cc0de3-90be8f60.jpg: file changed as we read it
# tar: images/train/20b54121-ff86357c.jpg: file changed as we read it
# tar: images/train/423645cf-1ee0f0b4.jpg: file changed as we read it
# tar: images/train/7ed57d0a-6ffc8701.jpg: file changed as we read it
# tar: images/train/1f7348d3-2f73f0e5.jpg: file changed as we read it
# tar: images/train/8f9a82d7-55b5e7a3.jpg: file changed as we read it
# tar: images/train/6b38856e-6c3e33b0.jpg: file changed as we read it
# tar: images/train/184ebe9e-97de15c8.jpg: file changed as we read it
# tar: images/train/40d9ef08-47d0c1da.jpg: file changed as we read it
# tar: images/train/59eaccd9-659fc1a8.jpg: file changed as we read it
# tar: images/train/84cb906a-d6744517.jpg: file changed as we read it
# tar: images/train/9fd254fe-e138dc77.jpg: file changed as we read it
# tar: images/train/18ca8efa-e36a9015.jpg: file changed as we read it
# tar: images/train/176348dc-1b7e2024.jpg: file changed as we read it
# tar: images/train/546f40b4-43f0f669.jpg: file changed as we read it
# tar: images/train/060039d9-2ee09800.jpg: file changed as we read it
# tar: images/train/a988ff8b-bb40aa18.jpg: file changed as we read it
# tar: images/train/9f340aff-452eddd5.jpg: file changed as we read it
# tar: images/train/233ce678-c7a2185e.jpg: file changed as we read it
# tar: images/train/015fe6c9-e880c0d7.jpg: file changed as we read it
# tar: images/train/73adcdc5-04b6b8e8.jpg: file changed as we read it
# tar: images/train/ad7cc60c-f680912b.jpg: file changed as we read it
# tar: images/train/5899116e-7a805945.jpg: file changed as we read it
# tar: images/train/1270f3ab-6af5d122.jpg: file changed as we read it
# tar: images/train/940fedd2-d142163c.jpg: file changed as we read it
# tar: images/train/1819e8c8-7ed01693.jpg: file changed as we read it
# tar: images/train/79523402-a42c19df.jpg: file changed as we read it
# tar: images/train/5cc5736c-1b3b8a9b.jpg: file changed as we read it
# tar: images/train/448e2a8a-e9ee313e.jpg: file changed as we read it
# tar: images/train/65cf107a-65604012.jpg: file changed as we read it
# tar: images/train/3f580e6a-fb378f1a.jpg: file changed as we read it
# tar: images/train/038fbb3b-00346bd4.jpg: file changed as we read it
# tar: images/train/fdbffb41-a07c5660.jpg: file changed as we read it
# tar: images/train/9df0d805-203b0e27.jpg: file changed as we read it
# tar: images/train/99bfb995-b89c8e1f.jpg: file changed as we read it
# tar: images/train/46324f40-f9d6e66d.jpg: file changed as we read it
# tar: images/train/09edd9a7-c1dee87e.jpg: file changed as we read it
# tar: images/train/2414d34d-c7a4d6bd.jpg: file changed as we read it
# tar: images/train/16dd5e70-4c08081a.jpg: file changed as we read it
# tar: images/train/9b5116cc-0bdb5216.jpg: file changed as we read it
# tar: images/train/387a9c67-0577d2fa.jpg: file changed as we read it
# tar: images/train/33be4e3b-16451053.jpg: file changed as we read it
# tar: images/train/1d0333fe-453e0910.jpg: file changed as we read it
# tar: images/train/a5bffb27-c38a9650.jpg: file changed as we read it
# tar: images/train/aaa81212-1a97f6ce.jpg: file changed as we read it
# tar: images/train/7f35db1c-a83e52ba.jpg: file changed as we read it
# tar: images/train/af7dc07f-30de0a14.jpg: file changed as we read it
# tar: images/train/4f332d27-1a8edb42.jpg: file changed as we read it
# tar: images/train/a7ecf098-d95fee5f.jpg: file changed as we read it
# tar: images/train/4723cd57-6be8f936.jpg: file changed as we read it
# tar: images/train/30eab472-1c150d78.jpg: file changed as we read it
# tar: images/train/9fd02acf-2982f8d8.jpg: file changed as we read it
# tar: images/train/57fd312c-50e77e4b.jpg: file changed as we read it
# tar: images/train/9402ef41-41c95014.jpg: file changed as we read it
# tar: images/train/567b4b61-21001c03.jpg: file changed as we read it
# tar: images/train/0b91b26d-4974fb5b.jpg: file changed as we read it
# tar: images/train/59fb8317-766b509b.jpg: file changed as we read it
# tar: images/train/0a4fd219-3d34b17c.jpg: file changed as we read it
# tar: images/train/5872965e-17025153.jpg: file changed as we read it
# tar: images/train/10e622e5-1ffbe26b.jpg: file changed as we read it
# tar: images/train/370aaf15-2067530c.jpg: file changed as we read it
# tar: images/train/66b37efa-0ee4864c.jpg: file changed as we read it
# tar: images/train/83016505-489f0a0a.jpg: file changed as we read it
# tar: images/train/7814206e-287b26ef.jpg: file changed as we read it
# tar: images/train/07363609-dd3a8645.jpg: file changed as we read it
# tar: images/train/19e8c803-bf65a441.jpg: file changed as we read it
# tar: images/train/27a3bcc5-9b16d9a0.jpg: file changed as we read it
# tar: images/train/5063a945-77edf663.jpg: file changed as we read it
# tar: images/train/80558f18-79cb7171.jpg: file changed as we read it
# tar: images/train/151592af-5356a210.jpg: file changed as we read it
# tar: images/train/465106cf-72cd96ad.jpg: file changed as we read it
# tar: images/train/1af21ce1-97d4a34b.jpg: file changed as we read it
# tar: images/train/2eaca1db-0cbd9d42.jpg: file changed as we read it
# tar: images/train/045cb354-470666ec.jpg: file changed as we read it
# tar: images/train/1ef8bd83-c5816b03.jpg: file changed as we read it
# tar: images/train/90845505-432599b4.jpg: file changed as we read it
# tar: images/train/01306b58-a09ba743.jpg: file changed as we read it
# tar: images/train/46467e25-df24247e.jpg: file changed as we read it
# tar: images/train/22663f09-b6484ede.jpg: file changed as we read it
# tar: images/train/385c9137-56f99bf0.jpg: file changed as we read it
# tar: images/train/1eb2b3ca-e76a1e3c.jpg: file changed as we read it
# tar: images/train/532e74e2-0dcc182a.jpg: file changed as we read it
# tar: images/train/7d074ee8-86620c85.jpg: file changed as we read it
# tar: images/train/69703cb9-a839d556.jpg: file changed as we read it
# tar: images/train/0062298d-fd69d0ec.jpg: file changed as we read it
# tar: images/train/57ab3757-33e8f753.jpg: file changed as we read it
# tar: images/train/ae653a7e-cff6118b.jpg: file changed as we read it
# tar: images/train/4c641856-c7dd89b9.jpg: file changed as we read it
# tar: images/train/12b21211-12bc1e11.jpg: file changed as we read it
# tar: images/train/93a1bf3e-7bde9365.jpg: file changed as we read it
# tar: images/train/1125356f-edb7f7c8.jpg: file changed as we read it
# tar: images/train/08c2fe3a-5f1bfcbe.jpg: file changed as we read it
# tar: images/train/982b06fc-891d37cf.jpg: file changed as we read it
# tar: images/train/5bb9c181-c1f5f122.jpg: file changed as we read it
# tar: images/train/2dc83489-04162e69.jpg: file changed as we read it
# tar: images/train/a7c475da-15f27a8e.jpg: file changed as we read it
# tar: images/train/6fbd1f6a-d9c2c898.jpg: file changed as we read it
# tar: images/train/887c925b-c12ad561.jpg: file changed as we read it
# tar: images/train/6efc4740-e9486631.jpg: file changed as we read it
# tar: images/train/06257efc-9aba5724.jpg: file changed as we read it
# tar: images/train/aee75a65-51f4d34f.jpg: file changed as we read it
# tar: images/train/58f46fa3-f42865f7.jpg: file changed as we read it
# tar: images/train/1381568b-e7ecd0c3.jpg: file changed as we read it
# tar: images/train/78ca6b1f-d8b97e00.jpg: file changed as we read it
# tar: images/train/02cfe806-9f5dfc26.jpg: file changed as we read it
# tar: images/train/488cba8c-df676b86.jpg: file changed as we read it
# tar: images/train/a136829a-3f898009.jpg: file changed as we read it
# tar: images/train/2abf6283-e0cd2e47.jpg: file changed as we read it
# tar: images/train/47ffeb41-acf19399.jpg: file changed as we read it
# tar: images/train/12625a64-7a417d64.jpg: file changed as we read it
# tar: images/train/fdb7ff6e-bcaa5d96.jpg: file changed as we read it
# tar: images/train/6c2ba750-31d20ca1.jpg: file changed as we read it
# tar: images/train/705c3239-515a0498.jpg: file changed as we read it
# tar: images/train/431baec3-e1420dc4.jpg: file changed as we read it
# tar: images/train/19c84c85-16c38c0f.jpg: file changed as we read it
# tar: images/train/76929766-e3290c8f.jpg: file changed as we read it
# tar: images/train/4506a609-6f8eb6d0.jpg: file changed as we read it
# tar: images/train/1f018767-9b5ac614.jpg: file changed as we read it
# tar: images/train/b0a1dce9-906b6968.jpg: file changed as we read it
# tar: images/train/90df14d0-62ab3415.jpg: file changed as we read it
# tar: images/train/5e25e18e-2f2b8dab.jpg: file changed as we read it
# tar: images/train/93a17dad-afed874b.jpg: file changed as we read it
# tar: images/train/65008fda-f1101653.jpg: file changed as we read it
# tar: images/train/467ee92a-efb2885a.jpg: file changed as we read it
# tar: images/train/1db14c32-f8b290ea.jpg: file changed as we read it
# tar: images/train/4bdd2193-546f8f2c.jpg: file changed as we read it
# tar: images/train/35627f1d-2f9ee733.jpg: file changed as we read it
# tar: images/train/1c4fb740-7d8e3411.jpg: file changed as we read it
# tar: images/train/0ddab3e2-2df82223.jpg: file changed as we read it
# tar: images/train/8967b1eb-0e833d28.jpg: file changed as we read it
# tar: images/train/6f5c6a4a-c2e5ec8d.jpg: file changed as we read it
# tar: images/train/01a01af7-76f6a476.jpg: file changed as we read it
# tar: images/train/4fd29372-c3fdf321.jpg: file changed as we read it
# tar: images/train/0bf28365-6947c194.jpg: file changed as we read it
# tar: images/train/9cf29eae-ac429396.jpg: file changed as we read it
# tar: images/train/60a5a624-fbe17b41.jpg: file changed as we read it
# tar: images/train/67e241db-4211e717.jpg: file changed as we read it
# tar: images/train/67d809f9-9ac5e97c.jpg: file changed as we read it
# tar: images/train/8e4ddcfe-52905d27.jpg: file changed as we read it
# tar: images/train/21609974-d0adebba.jpg: file changed as we read it
# tar: images/train/0cc71303-062ef095.jpg: file changed as we read it
# tar: images/train/6e75b675-3c4a653d.jpg: file changed as we read it
# tar: images/train/7b2c55a4-17647e4a.jpg: file changed as we read it
# tar: images/train/26c40709-ab699ca1.jpg: file changed as we read it
# tar: images/train/00488b40-0a8cf1a0.jpg: file changed as we read it
# tar: images/train/a1855337-f03f70cf.jpg: file changed as we read it
# tar: images/train/9e87dbe5-b728be95.jpg: file changed as we read it
# tar: images/train/009215e2-e67ccfb7.jpg: file changed as we read it
# tar: images/train/17662c87-970195f4.jpg: file changed as we read it
# tar: images/train/15a74558-99228162.jpg: file changed as we read it
# tar: images/train/128094d1-b5e42b46.jpg: file changed as we read it
# tar: images/train/a01ff535-4a9ea854.jpg: file changed as we read it
# tar: images/train/58cd0eb5-17cf27b4.jpg: file changed as we read it
# tar: images/train/2776d65d-2e3dcd70.jpg: file changed as we read it
# tar: images/train/29a37546-8fad1808.jpg: file changed as we read it
# tar: images/train/1fb538e7-3bd1f763.jpg: file changed as we read it
# tar: images/train/9429cbbd-30c8bfec.jpg: file changed as we read it
# tar: images/train/b0ec08d7-fc05d15b.jpg: file changed as we read it
# tar: images/train/1971cbf3-23b2c484.jpg: file changed as we read it
# tar: images/train/9cbae107-e33595c0.jpg: file changed as we read it
# tar: images/train/923f059a-eca0b950.jpg: file changed as we read it
# tar: images/train/05391f8a-3a0f7deb.jpg: file changed as we read it
# tar: images/train/3db14e35-eaa35330.jpg: file changed as we read it
# tar: images/train/850a0f15-abff078b.jpg: file changed as we read it
# tar: images/train/2f883215-2cc688ea.jpg: file changed as we read it
# tar: images/train/3eb56456-e053aa90.jpg: file changed as we read it
# tar: images/train/73bd6aac-6f991f38.jpg: file changed as we read it
# tar: images/train/748355af-c5d47f77.jpg: file changed as we read it
# tar: images/train/0ea1c25a-f3e28278.jpg: file changed as we read it
# tar: images/train/5eefe9cc-8d55d9f2.jpg: file changed as we read it
# tar: images/train/23583802-185ff83d.jpg: file changed as we read it
# tar: images/train/239c9b7f-c427e279.jpg: file changed as we read it
# tar: images/train/0cf2b8aa-47902d5a.jpg: file changed as we read it
# tar: images/train/2bedfdc9-efe2f9e2.jpg: file changed as we read it
# tar: images/train/344e5ae8-e0288868.jpg: file changed as we read it
# tar: images/train/53b6be87-df2e640f.jpg: file changed as we read it
# tar: images/train/887a26c8-b83df212.jpg: file changed as we read it
# tar: images/train/11ed4c05-aabcc8c8.jpg: file changed as we read it
# tar: images/train/9ae127bf-3eb5a17b.jpg: file changed as we read it
# tar: images/train/72894d6e-d33ddba2.jpg: file changed as we read it
# tar: images/train/45077408-17250878.jpg: file changed as we read it
# tar: images/train/5c5dc708-719ba604.jpg: file changed as we read it
# tar: images/train/9a9fc4cb-1d17c094.jpg: file changed as we read it
# tar: images/train/7e73817b-4150b731.jpg: file changed as we read it
# tar: images/train/6f7184c4-91addfce.jpg: file changed as we read it
# tar: images/train/38e20f1a-39021a36.jpg: file changed as we read it
# tar: images/train/83e5c2da-8dd1857c.jpg: file changed as we read it
# tar: images/train/6a8e3c99-7826d1be.jpg: file changed as we read it
# tar: images/train/278f9663-033c4bae.jpg: file changed as we read it
# tar: images/train/23751644-141def73.jpg: file changed as we read it
# tar: images/train/5312f738-5639eecb.jpg: file changed as we read it
# tar: images/train/a6a94f25-d46d5488.jpg: file changed as we read it
# tar: images/train/1154eff3-8d3d8564.jpg: file changed as we read it
# tar: images/train/4ca0ef43-7425eaa5.jpg: file changed as we read it
# tar: images/train/93930096-c33b5574.jpg: file changed as we read it
# tar: images/train/35f3d50a-a13773fe.jpg: file changed as we read it
# tar: images/train/24ae7824-266f01f0.jpg: file changed as we read it
# tar: images/train/3eef0f31-9d3217e8.jpg: file changed as we read it
# tar: images/train/b0697a99-ce98bea7.jpg: file changed as we read it
# tar: images/train/07ed8f12-782730e4.jpg: file changed as we read it
# tar: images/train/6a84cd95-8fc0de40.jpg: file changed as we read it
# tar: images/train/9fb1ab32-15504950.jpg: file changed as we read it
# tar: images/train/98b6f756-42e770f5.jpg: file changed as we read it
# tar: images/train/98216e09-44b10cf6.jpg: file changed as we read it
# tar: images/train/82a0a763-d374e5a8.jpg: file changed as we read it
# tar: images/train/26e27ffb-7e865eec.jpg: file changed as we read it
# tar: images/train/4f838541-572beb99.jpg: file changed as we read it
# tar: images/train/9dfb72de-7354cd2e.jpg: file changed as we read it
# tar: images/train/32f70a95-1bae4ca3.jpg: file changed as we read it
# tar: images/train/260d06b0-a1e127ed.jpg: file changed as we read it
# tar: images/train/8bf66417-61be1ebe.jpg: file changed as we read it
# tar: images/train/8979e7c7-abb00726.jpg: file changed as we read it
# tar: images/train/7dcdccb4-0a674daa.jpg: file changed as we read it
# tar: images/train/911ecac4-d8fa3d07.jpg: file changed as we read it
# tar: images/train/5ceeac16-77dd1602.jpg: file changed as we read it
# tar: images/train/a1da107d-54efaca3.jpg: file changed as we read it
# tar: images/train/5986add7-059f0cfb.jpg: file changed as we read it
# tar: images/train/06d7ad03-a9e83211.jpg: file changed as we read it
# tar: images/train/12cf075a-b1142689.jpg: file changed as we read it
# tar: images/train/7a2e212f-70c2f79c.jpg: file changed as we read it
# tar: images/train/6e36edb9-f336742b.jpg: file changed as we read it
# tar: images/train/0bb074f1-3da7bf3f.jpg: file changed as we read it
# tar: images/train/6cc9db0e-44366e79.jpg: file changed as we read it
# tar: images/train/92754252-a43e4ac0.jpg: file changed as we read it
# tar: images/train/2b331d27-7fba42a9.jpg: file changed as we read it
# tar: images/train/231b2c4f-aa9b410d.jpg: file changed as we read it
# tar: images/train/11318349-98f9b811.jpg: file changed as we read it
# tar: images/train/6b099ca0-32ba83d9.jpg: file changed as we read it
# tar: images/train/89471eec-5aa4c910.jpg: file changed as we read it
# tar: images/train/3f9e9da1-2c4aa81e.jpg: file changed as we read it
# tar: images/train/7536586b-c9c9f4de.jpg: file changed as we read it
# tar: images/train/90b28b1b-0df7e0eb.jpg: file changed as we read it
# tar: images/train/21de8557-6920257b.jpg: file changed as we read it
# tar: images/train/3d0d2b02-a1c0ecfe.jpg: file changed as we read it
# tar: images/train/92ef76c3-0cff125f.jpg: file changed as we read it
# tar: images/train/14a77de9-4baf7d2b.jpg: file changed as we read it
# tar: images/train/a1e54786-ef44a041.jpg: file changed as we read it
# tar: images/train/3c02e9d0-a8383e2e.jpg: file changed as we read it
# tar: images/train/96db0fe0-eb3276dd.jpg: file changed as we read it
# tar: images/train/990f97bb-a6a7a459.jpg: file changed as we read it
# tar: images/train/905fc28d-7d784322.jpg: file changed as we read it
# tar: images/train/192550a2-8566e055.jpg: file changed as we read it
# tar: images/train/a452ca3e-243337be.jpg: file changed as we read it
# tar: images/train/9bc0e5c8-0cb9683d.jpg: file changed as we read it
# tar: images/train/a22f8e8d-305f93e2.jpg: file changed as we read it
# tar: images/train/0e90790e-ec3f28c0.jpg: file changed as we read it
# tar: images/train/822e368c-a16a6b9a.jpg: file changed as we read it
# tar: images/train/72f59e81-a699f977.jpg: file changed as we read it
# tar: images/train/8309180a-d573d2f1.jpg: file changed as we read it
# tar: images/train/87a5f659-f9387783.jpg: file changed as we read it
# tar: images/train/740285bf-e568f563.jpg: file changed as we read it
# tar: images/train/79bb5311-7353c2e6.jpg: file changed as we read it
# tar: images/train/a9e8fdd5-e1b6f7b3.jpg: file changed as we read it
# tar: images/train/3dd70cac-b22695dd.jpg: file changed as we read it
# tar: images/train/89d83b59-e14547c7.jpg: file changed as we read it
# tar: images/train/03370efc-c690f4d8.jpg: file changed as we read it
# tar: images/train/8e1f3e83-47cc7633.jpg: file changed as we read it
# tar: images/train/6823b579-22b1a108.jpg: file changed as we read it
# tar: images/train/4693cfad-f6bbc728.jpg: file changed as we read it
# tar: images/train/1de119a0-3668f28a.jpg: file changed as we read it
# tar: images/train/1875b775-41d60a31.jpg: file changed as we read it
# tar: images/train/1e5faa47-7927fe88.jpg: file changed as we read it
# tar: images/train/08924b6a-097f0a33.jpg: file changed as we read it
# tar: images/train/9b822992-1e1a54a9.jpg: file changed as we read it
# tar: images/train/a540f9aa-9c33dc8a.jpg: file changed as we read it
# tar: images/train/6a4fcfa7-c42a9472.jpg: file changed as we read it
# tar: images/train/8906fbf3-9c769064.jpg: file changed as we read it
# tar: images/train/3144b325-c1f560ec.jpg: file changed as we read it
# tar: images/train/a4013a81-4c85db24.jpg: file changed as we read it
# tar: images/train/6e44c83e-5a61e9e7.jpg: file changed as we read it
# tar: images/train/66838ab6-8a29d484.jpg: file changed as we read it
# tar: images/train/5c963d8e-b435ffce.jpg: file changed as we read it
# tar: images/train/86f1017c-e6954f9e.jpg: file changed as we read it
# tar: images/train/52ba66d6-cb021262.jpg: file changed as we read it
# tar: images/train/6e631f87-a0c1cf74.jpg: file changed as we read it
# tar: images/train/0d3793ff-61737d11.jpg: file changed as we read it
# tar: images/train/aedc744b-813fad99.jpg: file changed as we read it
# tar: images/train/01632f31-ab7e17e3.jpg: file changed as we read it
# tar: images/train/1e889710-0539c768.jpg: file changed as we read it
# tar: images/train/3f291ac3-1b3789c6.jpg: file changed as we read it
# tar: images/train/631e93e3-ca6528d3.jpg: file changed as we read it
# tar: images/train/1b71edc8-18a1ff2d.jpg: file changed as we read it
# tar: images/train/60c678e7-fa739438.jpg: file changed as we read it
# tar: images/train/16504799-1201d13d.jpg: file changed as we read it
# tar: images/train/8e34adc8-155218dd.jpg: file changed as we read it
# tar: images/train/2e79de98-bac5374b.jpg: file changed as we read it
# tar: images/train/535219a6-ddb3e92a.jpg: file changed as we read it
# tar: images/train/191e2dd9-b6147847.jpg: file changed as we read it
# tar: images/train/000f157f-30b30f5e.jpg: file changed as we read it
# tar: images/train/6d34f7b0-741159ba.jpg: file changed as we read it
# tar: images/train/55496a29-f2cbfccb.jpg: file changed as we read it
# tar: images/train/7a397d0e-34f17981.jpg: file changed as we read it
# tar: images/train/6b9da46d-94dae7a4.jpg: file changed as we read it
# tar: images/train/aea0ba60-69937a6f.jpg: file changed as we read it
# tar: images/train/56d5f31b-f7da8700.jpg: file changed as we read it
# tar: images/train/5fc6aaab-7c442452.jpg: file changed as we read it
# tar: images/train/4a93cba4-923e7845.jpg: file changed as we read it
# tar: images/train/3ebd63dd-73c0e162.jpg: file changed as we read it
# tar: images/train/444d56f8-24d2f861.jpg: file changed as we read it
# tar: images/train/97f24249-32f86418.jpg: file changed as we read it
# tar: images/train/0ad67e35-2b01de49.jpg: file changed as we read it
# tar: images/train/4b28b45f-082af819.jpg: file changed as we read it
# tar: images/train/850803f1-9331c434.jpg: file changed as we read it
# tar: images/train/27d61d34-d6f8e704.jpg: file changed as we read it
# tar: images/train/3f512927-79646b71.jpg: file changed as we read it
# tar: images/train/22e8f6d1-9d013efb.jpg: file changed as we read it
# tar: images/train/50c11f3a-857aa7f3.jpg: file changed as we read it
# tar: images/train/4e2f4c5e-faa2b972.jpg: file changed as we read it
# tar: images/train/66a413f1-9e31e0c6.jpg: file changed as we read it
# tar: images/train/4f9f459b-ef563593.jpg: file changed as we read it
# tar: images/train/437bc97c-96e7c98c.jpg: file changed as we read it
# tar: images/train/61e48ae3-e66debd3.jpg: file changed as we read it
# tar: images/train/701eb6dd-862795e1.jpg: file changed as we read it
# tar: images/train/217f5fb2-7b751b0f.jpg: file changed as we read it
# tar: images/train/98dc46f9-39457a90.jpg: file changed as we read it
# tar: images/train/5324744a-4d5ce47f.jpg: file changed as we read it
# tar: images/train/2fde6698-c2fb3e71.jpg: file changed as we read it
# tar: images/train/573ef4f5-b5c76105.jpg: file changed as we read it
# tar: images/train/af213ad2-a06778b1.jpg: file changed as we read it
# tar: images/train/988a1241-5e879695.jpg: file changed as we read it
# tar: images/train/85563315-07578a9d.jpg: file changed as we read it
# tar: images/train/48f4aa57-323261c1.jpg: file changed as we read it
# tar: images/train/19156e2b-3e0b1ae0.jpg: file changed as we read it
# tar: images/train/7c26fa5d-f6fff282.jpg: file changed as we read it
# ...
# tar: images/train/9922e632-c2bc7c37.jpg: file changed as we read it
# tar: images/train/55be3c59-0016d780.jpg: file changed as we read it
# tar: images/train/232cd463-20dd5a0b.jpg: file changed as we read it
# tar: images/train/495ff07e-4668f82c.jpg: file changed as we read it
# tar: images/train/a387018e-dfcd644b.jpg: file changed as we read it
# tar: images/train/838ed237-8e1d6a14.jpg: file changed as we read it
# tar: images/train/19be00b9-c681ac66.jpg: file changed as we read it
# tar: images/train/a33c329b-aaff78ce.jpg: file changed as we read it
# tar: images/train/041b8324-9ac125ac.jpg: file changed as we read it
# tar: images/train/605434f1-d6fa9870.jpg: file changed as we read it
# tar: images/train/3979fced-c09063e8.jpg: file changed as we read it
# tar: images/train/2f9eb07f-6944922c.jpg: file changed as we read it
# tar: images/train/635e9319-39273e03.jpg: file changed as we read it
# tar: images/train/0ecb74d4-da8f2282.jpg: file changed as we read it
# tar: images/train/ac284c2c-b5c1160e.jpg: file changed as we read it
# tar: images/train/23c3c91b-c0a9b443.jpg: file changed as we read it
# tar: images/train/80f0677b-f8771023.jpg: file changed as we read it
# tar: images/train/a14bedf7-40525ba2.jpg: file changed as we read it
# tar: images/train/b15497f6-ca378c2b.jpg: file changed as we read it
# tar: images/train/0b4f2e43-10a52b3e.jpg: file changed as we read it
# tar: images/train/87c7888c-1a5ff24c.jpg: file changed as we read it
# tar: images/train/608d944f-6d009a0f.jpg: file changed as we read it
# tar: images/train/08a5891b-71844499.jpg: file changed as we read it
# tar: images/train/426f3d6f-518818d5.jpg: file changed as we read it
# tar: images/train/608c58ce-09dd4066.jpg: file changed as we read it
# tar: images/train/1c8f3e12-dd87a418.jpg: file changed as we read it
# tar: images/train/60e6a1f9-8d3cff77.jpg: file changed as we read it
# tar: images/train/92201105-01878b0b.jpg: file changed as we read it
# tar: images/train/1f2ccb3c-9e06221f.jpg: file changed as we read it
# tar: images/train/08f6c5f0-65999e6c.jpg: file changed as we read it
# tar: images/train/a8d35f42-83e139d7.jpg: file changed as we read it
# tar: images/train/51b37824-1b015cfd.jpg: file changed as we read it
# tar: images/train/b0f8bdf8-9efe9ee3.jpg: file changed as we read it
# tar: images/train/76db321f-ed1d5479.jpg: file changed as we read it
# tar: images/train/3bc58539-09258aca.jpg: file changed as we read it
# tar: images/train/0d13ae3d-3ac8a40d.jpg: file changed as we read it
# tar: images/train/989e4f27-f92174c0.jpg: file changed as we read it
# tar: images/train/3edb2cb8-ccb5ca6c.jpg: file changed as we read it
# tar: images/train/0e60d39e-5898275d.jpg: file changed as we read it
# tar: images/train/69435b06-232ebe01.jpg: file changed as we read it
# tar: images/train/033ae54d-46760e92.jpg: file changed as we read it
# tar: images/train/23d12210-313ea2b1.jpg: file changed as we read it
# tar: images/train/0ca74451-808a5064.jpg: file changed as we read it
# tar: images/train/8d11b847-fc2f1c6e.jpg: file changed as we read it
# tar: images/train/62b92adb-fc2e3111.jpg: file changed as we read it
# tar: images/train/2081ca78-89ca7e40.jpg: file changed as we read it
# tar: images/train/34166df0-bad79d14.jpg: file changed as we read it
# tar: images/train/3cdbef52-02968e10.jpg: file changed as we read it
# tar: images/train/0ef40952-9eb26d4c.jpg: file changed as we read it
# tar: images/train/8bce845c-718bf647.jpg: file changed as we read it
# tar: images/train/92f58b21-715a3e32.jpg: file changed as we read it
# tar: images/train/5201c25e-e3127a43.jpg: file changed as we read it
# tar: images/train/771df318-2b01b8ea.jpg: file changed as we read it
# tar: images/train/12ab42b4-6587f97e.jpg: file changed as we read it
# tar: images/train/21f018b3-f106433b.jpg: file changed as we read it
# tar: images/train/55fdb5bd-a8b60076.jpg: file changed as we read it
# tar: images/train/6d565c3a-392dd003.jpg: file changed as we read it
# tar: images/train/a09bfc5a-283eecdd.jpg: file changed as we read it
# tar: images/train/7237f7d6-dd8443e1.jpg: file changed as we read it
# tar: images/train/2a38eef1-b81ccd82.jpg: file changed as we read it
# tar: images/train/07fad9ad-aaae2bf1.jpg: file changed as we read it
# tar: images/train/999dbb65-0a34c98c.jpg: file changed as we read it
# tar: images/train/742e0a3d-acff6b2e.jpg: file changed as we read it
# tar: images/train/374a9f09-a91dbfe0.jpg: file changed as we read it
# tar: images/train/6f016ef8-a2c94270.jpg: file changed as we read it
# tar: images/train/ab5df019-f9205bb1.jpg: file changed as we read it
# tar: images/train/9fd65ab6-d4a72421.jpg: file changed as we read it
# tar: images/train/05f57917-064b95b6.jpg: file changed as we read it
# tar: images/train/071dce5a-1fe5dfad.jpg: file changed as we read it
# tar: images/train/342b816d-6e7547ee.jpg: file changed as we read it
# tar: images/train/38a8a37d-a9aee10e.jpg: file changed as we read it
# tar: images/train/2f49cdcb-1b0d1856.jpg: file changed as we read it
# tar: images/train/0d05c79c-0b211e08.jpg: file changed as we read it
# tar: images/train/13f5f66f-af4e9d41.jpg: file changed as we read it
# tar: images/train/435c7d57-2c7fdab3.jpg: file changed as we read it
# tar: images/train/4625ded5-360e78aa.jpg: file changed as we read it
# tar: images/train/82124e5e-932ea529.jpg: file changed as we read it
# tar: images/train/79a79919-3c0f4e60.jpg: file changed as we read it
# tar: images/train/22e039a4-b92fe28b.jpg: file changed as we read it
# tar: images/train/7690463b-bafa470e.jpg: file changed as we read it
# tar: images/train/5589def1-f752cadf.jpg: file changed as we read it
# tar: images/train/5250cae5-dd08b350.jpg: file changed as we read it
# tar: images/train/2214f53a-9adbf271.jpg: file changed as we read it
# tar: images/train/8e9ea4fe-9d734f42.jpg: file changed as we read it
# tar: images/train/62ef8eb2-51726e72.jpg: file changed as we read it
# tar: images/train/38f8c2d4-01971edb.jpg: file changed as we read it
# tar: images/train/36ebf488-d07b0d29.jpg: file changed as we read it
# tar: images/train/0711ab13-698c82be.jpg: file changed as we read it
# tar: images/train/0128cdde-1f72dcf1.jpg: file changed as we read it
# tar: images/train/296f2b7b-07739e93.jpg: file changed as we read it
# tar: images/train/510d67db-b00ef32e.jpg: file changed as we read it
# tar: images/train/0f1359f1-203c30d4.jpg: file changed as we read it
# tar: images/train/9a7ea68a-5c6fc0ec.jpg: file changed as we read it
# tar: images/train/afd35d01-38f98552.jpg: file changed as we read it
# tar: images/train/083ce411-c3a120b6.jpg: file changed as we read it
# tar: images/train/a32543af-32050dc0.jpg: file changed as we read it
# tar: images/train/77e0a5d6-8051bd18.jpg: file changed as we read it
# tar: images/train/610f6205-7c7927a5.jpg: file changed as we read it
# tar: images/train/47095345-9a1ddf42.jpg: file changed as we read it
# tar: images/train/7e6a2889-8903ca96.jpg: file changed as we read it
# tar: images/train/4f77aa44-04f68874.jpg: file changed as we read it
# tar: images/train/57c4b923-8f810ce4.jpg: file changed as we read it
# tar: images/train/10903606-c6c54402.jpg: file changed as we read it
# tar: images/train/5295295e-afca4f40.jpg: file changed as we read it
# tar: images/train/506305fc-60465440.jpg: file changed as we read it
# tar: images/train/31b7487a-0271ab86.jpg: file changed as we read it
# tar: images/train/a1d82b67-85d9ac13.jpg: file changed as we read it
# tar: images/train/435412f2-56fef841.jpg: file changed as we read it
# tar: images/train/43c111b3-10250b48.jpg: file changed as we read it
# tar: images/train/12800db3-0c020c6e.jpg: file changed as we read it
# tar: images/train/a61393cf-06d81ef4.jpg: file changed as we read it
# tar: images/train/977178f4-d7c1e20a.jpg: file changed as we read it
# tar: images/train/55fcd90a-2e1c370b.jpg: file changed as we read it
# tar: images/train/4bee32fa-15767c0d.jpg: file changed as we read it
# tar: images/train/9ab127bf-c865d6ed.jpg: file changed as we read it
# tar: images/train/0989aa44-2bdedd9e.jpg: file changed as we read it
# tar: images/train/602a10e7-4ef0a891.jpg: file changed as we read it
# tar: images/train/33164552-8fc4b11c.jpg: file changed as we read it
# tar: images/train/1103db68-3155e40e.jpg: file changed as we read it
# tar: images/train/551e5e34-b7bfc47e.jpg: file changed as we read it
# tar: images/train/2d02a6f6-9d5faba9.jpg: file changed as we read it
# tar: images/train/84fd068d-f0863ad2.jpg: file changed as we read it
# tar: images/train/68c29514-3c867490.jpg: file changed as we read it
# tar: images/train/1404988a-0d295cff.jpg: file changed as we read it
# tar: images/train/0c6f945c-0a9fc70f.jpg: file changed as we read it
# tar: images/train/55e55f0f-7317f98e.jpg: file changed as we read it
# tar: images/train/73147a84-19ebf167.jpg: file changed as we read it
# tar: images/train/a2a82331-1962812a.jpg: file changed as we read it
# tar: images/train/27f4eeca-94b287b7.jpg: file changed as we read it
# tar: images/train/05b06a04-5d7141e0.jpg: file changed as we read it
# tar: images/train/151db5e5-a93f50de.jpg: file changed as we read it
# tar: images/train/2e9f5b16-40965200.jpg: file changed as we read it
# tar: images/train/4251964f-9216bc41.jpg: file changed as we read it
# tar: images/train/3eec0a14-c6561f5f.jpg: file changed as we read it
# tar: images/train/0d56a2c2-c244cb4c.jpg: file changed as we read it
# tar: images/train/8d7e6423-6e48e84c.jpg: file changed as we read it
# tar: images/train/150a973a-6772fd20.jpg: file changed as we read it
# tar: images/train/931adcf0-23c761d0.jpg: file changed as we read it
# tar: images/train/06641cdd-225c6990.jpg: file changed as we read it
# tar: images/train/5f13314c-5b5e2ac5.jpg: file changed as we read it
# tar: images/train/90752702-82a83e60.jpg: file changed as we read it
# tar: images/train/09409126-324e3880.jpg: file changed as we read it
# tar: images/train/4ca144ae-45d888ef.jpg: file changed as we read it
# tar: images/train/65ebd4ae-307a6c9b.jpg: file changed as we read it
# tar: images/train/9ee3d04d-bc042a0e.jpg: file changed as we read it
# tar: images/train/5ddee8eb-5b60213e.jpg: file changed as we read it
# tar: images/train/7848bf90-86286583.jpg: file changed as we read it
# tar: images/train/1daa0af5-a19a1273.jpg: file changed as we read it
# tar: images/train/84fc2db8-a550e4fa.jpg: file changed as we read it
# tar: images/train/49d22340-6e3532a7.jpg: file changed as we read it
# tar: images/train/8a067c4a-f0c2e166.jpg: file changed as we read it
# tar: images/train/22885a31-cf89dc99.jpg: file changed as we read it
# tar: images/train/1fb82715-39400da9.jpg: file changed as we read it
# tar: images/train/8c4aa33b-5e0a838c.jpg: file changed as we read it
# tar: images/train/a12c8a97-33f2d038.jpg: file changed as we read it
# tar: images/train/07116ae0-e9b4fa4a.jpg: file changed as we read it
# tar: images/train/06ca4b52-6fc89b9d.jpg: file changed as we read it
# tar: images/train/3d2cfdb6-12a6e2be.jpg: file changed as we read it
# tar: images/train/62491a7b-914efdd8.jpg: file changed as we read it
# tar: images/train/2b116403-bac8c9f8.jpg: file changed as we read it
# tar: images/train/ac3e8b3c-dcf8c84e.jpg: file changed as we read it
# tar: images/train/a596c628-a1fcac70.jpg: file changed as we read it
# tar: images/train/6431b3a1-888d4983.jpg: file changed as we read it
# tar: images/train/56e53981-3001f2f5.jpg: file changed as we read it
# tar: images/train/20652cf8-289d594c.jpg: file changed as we read it
# tar: images/train/a84a47c0-a3c59359.jpg: file changed as we read it
# tar: images/train/0fe831f2-d3180400.jpg: file changed as we read it
# tar: images/train/9a5cc2dc-3b0e2241.jpg: file changed as we read it
# tar: images/train/0cc07488-08863628.jpg: file changed as we read it
# tar: images/train/a91d0723-b457c245.jpg: file changed as we read it
# tar: images/train/a9acd883-54218cf7.jpg: file changed as we read it
# tar: images/train/6b0f986c-b7a5a96a.jpg: file changed as we read it
# tar: images/train/4bad8c45-04d805d5.jpg: file changed as we read it
# tar: images/train/930d648a-f2b79e81.jpg: file changed as we read it
# tar: images/train/23eca14f-41a4fdb1.jpg: file changed as we read it
# tar: images/train/53f57c2b-60b79e05.jpg: file changed as we read it
# tar: images/train/43d65cac-16fa5bfe.jpg: file changed as we read it
# tar: images/train/a1ee3390-f92b85a4.jpg: file changed as we read it
# tar: images/train/ad0a9b41-2c50cf44.jpg: file changed as we read it
# tar: images/train/7793f745-d7ad006f.jpg: file changed as we read it
# tar: images/train/1f9f7605-3a9945bb.jpg: file changed as we read it
# tar: images/train/7ac1aa52-e93fbe0c.jpg: file changed as we read it
# tar: images/train/02b7b9ee-a2aba88b.jpg: file changed as we read it
# tar: images/train/1a606fce-a896339b.jpg: file changed as we read it
# tar: images/train/2e191297-620e1f3a.jpg: file changed as we read it
# tar: images/train/49e4aa79-c1bdc545.jpg: file changed as we read it
# tar: images/train/1f1933c6-a9f2d713.jpg: file changed as we read it
# tar: images/train/9e935862-8d1bd833.jpg: file changed as we read it
# tar: images/train/1db63adc-c16afa64.jpg: file changed as we read it
# tar: images/train/35b6ed07-f31278c0.jpg: file changed as we read it
# tar: images/train/7ab9b228-ff0b8ddc.jpg: file changed as we read it
# tar: images/train/2f5feaf5-8e4f329d.jpg: file changed as we read it
# tar: images/train/55bd9a88-418e6c58.jpg: file changed as we read it
# tar: images/train/0f7ca0a4-934b6cf1.jpg: file changed as we read it
# tar: images/train/1deff035-ab1c94cf.jpg: file changed as we read it
# tar: images/train/4d52c454-2924bc87.jpg: file changed as we read it
# tar: images/train/31a912d2-3f3d12ba.jpg: file changed as we read it
# tar: images/train/8fe5f34e-308d17ee.jpg: file changed as we read it
# tar: images/train/97873579-981347a6.jpg: file changed as we read it
# tar: images/train/03f8899f-64fdaa9d.jpg: file changed as we read it
# tar: images/train/a5f6a8c9-5e9e2db6.jpg: file changed as we read it
# tar: images/train/3d8bc844-c8254279.jpg: file changed as we read it
# tar: images/train/31185dd1-fe0d4322.jpg: file changed as we read it
# tar: images/train/91104422-7f18552a.jpg: file changed as we read it
# tar: images/train/0e83f4cf-cf7a4f06.jpg: file changed as we read it
# tar: images/train/8e044333-647dd166.jpg: file changed as we read it
# tar: images/train/7b8a90c2-2f0bfd7f.jpg: file changed as we read it
# tar: images/train/a3bf3224-2b481a3a.jpg: file changed as we read it
# tar: images/train/81cb4333-e0d99c8f.jpg: file changed as we read it
# tar: images/train/3e65e36b-d51a5f2b.jpg: file changed as we read it
# tar: images/train/ab647b20-91eb5195.jpg: file changed as we read it
# tar: images/train/3842e612-85b8cd30.jpg: file changed as we read it
# tar: images/train/62001c5b-d6a2e54c.jpg: file changed as we read it
# tar: images/train/5f4102ef-73d5fe85.jpg: file changed as we read it
# tar: images/train/83f0c978-efa623db.jpg: file changed as we read it
# tar: images/train/a0be3324-6612aa0f.jpg: file changed as we read it
# tar: images/train/0b53476e-3559f162.jpg: file changed as we read it
# tar: images/train/767aec7f-2e776921.jpg: file changed as we read it
# tar: images/train/6feede64-1a876fd7.jpg: file changed as we read it
# tar: images/train/76640b18-bd0a0023.jpg: file changed as we read it
# tar: images/train/0a98248b-822653de.jpg: file changed as we read it
# tar: images/train/7c0920af-223860db.jpg: file changed as we read it
# tar: images/train/9d644427-94b1a994.jpg: file changed as we read it
# tar: images/train/2b923350-c22307af.jpg: file changed as we read it
# tar: images/train/665dfaf1-cca6e924.jpg: file changed as we read it
# tar: images/train/b02523c1-71b12b30.jpg: file changed as we read it
# tar: images/train/17662c87-9476da54.jpg: file changed as we read it
# tar: images/train/afefaf4b-c2829f99.jpg: file changed as we read it
# tar: images/train/29d4cc65-225d5180.jpg: file changed as we read it
# tar: images/train/70603b9c-567aa996.jpg: file changed as we read it
# tar: images/train/a3d1d710-8d12d02e.jpg: file changed as we read it
# tar: images/train/6e81b440-969633db.jpg: file changed as we read it
# tar: images/train/4ca144ae-22f966b6.jpg: file changed as we read it
# tar: images/train/6e9854b4-eec15cd4.jpg: file changed as we read it
#
#    Try running without -h flag if symlink resolution fails:

# %%
# Upload tar to Drive
if os.path.isfile(TAR_LOCAL):
    print(f"☁️ Uploading {TAR_NAME} to Drive...")
    print(f"   From: {TAR_LOCAL}")
    print(f"   To:   {TAR_DRIVE}")
    t0 = time.time()
    shutil.copy2(TAR_LOCAL, TAR_DRIVE)
    elapsed = time.time() - t0
    print(f"✅ Uploaded in {elapsed:.0f}s")
    print(f"\n🎯 Notebook 08 can now restore with:")
    print(f"   !mkdir -p /content/bdd100k_yolo")
    print(f"   !tar -xf '{TAR_DRIVE}' -C /content/bdd100k_yolo")
else:
    print("⚠️ No tar file found. Archive creation may have failed.")
# Out:
# ☁️ Uploading bdd100k_yolo_nb02.tar to Drive...
#    From: /content/bdd100k_yolo_nb02.tar
#    To:   /content/drive/MyDrive/EcoCAR/datasets/bdd100k_yolo_nb02.tar
# ✅ Uploaded in 14s
#
# 🎯 Notebook 08 can now restore with:
#    !mkdir -p /content/bdd100k_yolo
#    !tar -xf '/content/drive/MyDrive/EcoCAR/datasets/bdd100k_yolo_nb02.tar' -C /content/bdd100k_yolo

# %% [markdown]
# ## 9 — Visualise Sample Annotations

# %%
import cv2, matplotlib.pyplot as plt, random

train_labels_dir = os.path.join(YOLO_DATASET_DIR, 'labels', 'train')
train_images_dir = os.path.join(YOLO_DATASET_DIR, 'images', 'train')
label_files = [f for f in os.listdir(train_labels_dir) if f.endswith('.txt')]
sample_labels = random.sample(label_files, min(4, len(label_files)))

fig, axes = plt.subplots(2, 2, figsize=(16, 10))
axes = axes.flatten()
colors = [(255,80,80),(255,160,60),(60,180,255),(100,100,255),(255,220,60),
          (180,100,255),(100,255,100),(255,100,200),(0,255,200),(200,200,0)]

for idx, lf in enumerate(sample_labels):
    img_path = os.path.join(train_images_dir, lf.replace('.txt', '.jpg'))
    img = cv2.imread(img_path)
    if img is None:
        img = cv2.imread(img_path.replace('.jpg', '.png'))
    if img is None:
        axes[idx].set_title(f"Could not load"); continue
    h, w = img.shape[:2]
    with open(os.path.join(train_labels_dir, lf), 'r') as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) < 5: continue
            cls_id = int(parts[0])
            xc,yc,bw,bh = [float(v) for v in parts[1:5]]
            x1,y1 = int((xc-bw/2)*w), int((yc-bh/2)*h)
            x2,y2 = int((xc+bw/2)*w), int((yc+bh/2)*h)
            color = colors[cls_id % len(colors)]
            cv2.rectangle(img,(x1,y1),(x2,y2),color,2)
            cv2.putText(img,BDD_CLASSES[cls_id],(x1,y1-5),cv2.FONT_HERSHEY_SIMPLEX,0.5,color,1)
    axes[idx].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    axes[idx].set_title(lf.replace('.txt',''), fontsize=9)
    axes[idx].axis('off')
plt.suptitle('Sample BDD100K Annotations (YOLO format)', fontsize=13)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10 — Summary

# %%
print("\n" + "="*60)
print(" BDD100K PREPARATION — COMPLETE")
print("="*60)
print(f" YOLO dataset dir:  {YOLO_DATASET_DIR}")
print(f" Dataset YAML:      {yaml_path}")
print(f" Train images:      {n_train}")
print(f" Val images:        {n_val}")
print(f" Classes:           {len(BDD_CLASSES)}")
print("="*60)
print("\n🎯 Proceed to notebook 03!")
# Out:
# ============================================================
#  BDD100K PREPARATION — COMPLETE
# ============================================================
#  YOLO dataset dir:  /content/bdd100k_yolo
#  Dataset YAML:      /content/bdd100k_yolo/bdd100k_yolo.yaml
#  Train images:      16942
#  Val images:        2990
#  Classes:           10
# ============================================================
#
# 🎯 Proceed to notebook 03!
