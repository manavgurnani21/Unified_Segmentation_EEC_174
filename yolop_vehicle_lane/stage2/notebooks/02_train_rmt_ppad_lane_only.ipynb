# %% [markdown]
# # Stage 2 - train RMT-PPAD lane-only replica

# %% [markdown]
# This is the strict RMT-PPAD lane-only baseline. It keeps the RT-DETR-L multi-task structure and removes only the drivable-area segmentation target.

# %%
from pathlib import Path
from google.colab import drive
drive.mount('/content/drive')

PROJECT_ROOT = Path("/content/drive/MyDrive/EcoCAR/yolop_vehicle_lane")
# %cd {PROJECT_ROOT}
# !python stage2/scripts/01_train_rmt_ppad_lane_only.py \
  --project-root {PROJECT_ROOT} \
  --epochs 250 \
  --batch 16 \
  --lr0 0.0001 \
  --workers 8 \
  --device 0 \
  --val-period 1 \
  --save-period 1
