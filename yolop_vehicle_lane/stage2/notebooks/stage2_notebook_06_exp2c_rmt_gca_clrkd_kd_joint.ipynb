# %% [markdown]
# # Stage 2 joint experiment notebook
#
# Run order after Exp2 refactor: 00 prepare dataset → 01 Exp2A baseline → 02 Exp2B GCA baseline → 03 Exp2D lane detail neck → 04 Exp2E matched lane loss → 05 Exp2F detail + matching. Run 06 KD only if the teacher checkpoint exists. Run Exp3 notebooks only after Exp2F improves lane geometry. Every notebook re-extracts the Drive tar into `/content`; never assume files from a previous Colab runtime still exist. Training logs are printed in this notebook cell and mirrored to `/content/drive/MyDrive/EcoCAR/training_runs/notebook_logs/`.

# %% [markdown]
# # Stage 2 Notebook 03 - Exp2C RMT GCA + CLRKD KD joint fusion

# %%
import os, sys, subprocess, textwrap
from google.colab import drive
os.environ['PYTHONUNBUFFERED'] = '1'
drive.mount('/content/drive')

REPO_ROOT = '/content/drive/MyDrive/EcoCAR/yolop_vehicle_lane'
if not os.path.isdir(REPO_ROOT):
    raise FileNotFoundError(f'Missing project root: {REPO_ROOT}')
os.chdir(REPO_ROOT)
if REPO_ROOT not in sys.path:
    sys.path.insert(0, REPO_ROOT)

subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', 'pyyaml', 'scipy', 'opencv-python-headless', 'tqdm', 'matplotlib'])
print('repo:', REPO_ROOT)

from stage2.scripts.notebook_utils import run_streaming
LOG_DIR = '/content/drive/MyDrive/EcoCAR/training_runs/notebook_logs'
os.makedirs(LOG_DIR, exist_ok=True)
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_3581/3876868301.py in <cell line: 0>()
#       2 from google.colab import drive
#       3 os.environ['PYTHONUNBUFFERED'] = '1'
# ----> 4 drive.mount('/content/drive')
#       5
#       6 REPO_ROOT = '/content/drive/MyDrive/EcoCAR/yolop_vehicle_lane'
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.12/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
from pathlib import Path
import subprocess, sys
CONFIG = 'stage2/configs/exp03_rmt_gca_clrkd_kd_joint.yaml'
run_streaming([sys.executable, '-u', 'stage2/scripts/smoke_test_joint_models.py', CONFIG], log_path=os.path.join(LOG_DIR, f'{Path(CONFIG).stem}_smoke.log'))

# %%
from pathlib import Path
import os, subprocess, sys
CONFIG = 'stage2/configs/exp03_rmt_gca_clrkd_kd_joint.yaml'
CURVE_TAR = '/content/drive/MyDrive/EcoCAR/datasets/bdd100k_clrkd_curve.tar'
CURVE_ROOT = '/content/bdd100k_clrkd_curve'
TEACHER_CKPT = '/content/drive/MyDrive/EcoCAR/training_runs/clrkd_lane_teacher_best.pt'
print('teacher checkpoint:', TEACHER_CKPT, 'exists=', os.path.exists(TEACHER_CKPT))
if not os.path.exists(TEACHER_CKPT):
    raise FileNotFoundError('Exp2C/KD needs a frozen CLRKD lane teacher checkpoint first. Train or copy clrkd_lane_teacher_best.pt before running this notebook.')

cmd = [
    sys.executable, '-u', 'stage2/scripts/train_joint_model_experiment.py',
    '--config', CONFIG,
    '--curve-tar', CURVE_TAR,
    '--curve-root', CURVE_ROOT,
    '--force-extract',
    '--print-every', '50',
]
print(' '.join(cmd), flush=True)
run_streaming(cmd, log_path=os.path.join(LOG_DIR, f'{Path(CONFIG).stem}_train.log'))
