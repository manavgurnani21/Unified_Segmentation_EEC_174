# %% [markdown]
# ### Run mode
# This notebook now defaults to a short debug run so logs appear quickly in the cell output.
#
# 1. Keep `DEBUG_MODE = True` for the first run.
# 2. After the smoke/debug run succeeds, change it to `False` for the 10-epoch short run.
# 3. The same output is printed in the notebook cell, Colab runtime log, and the Drive log file under `stage2/logs/`.

# %% [markdown]
# # Stage 2 joint experiment notebook
#
# Run order after Exp2 refactor: 00 prepare dataset → 01 Exp2A baseline → 02 Exp2B GCA baseline → 03 Exp2D lane detail neck → 04 Exp2E matched lane loss → 05 Exp2F detail + matching. Run 06 KD only if the teacher checkpoint exists. Run Exp3 notebooks only after Exp2F improves lane geometry. Every notebook re-extracts the Drive tar into `/content`; never assume files from a previous Colab runtime still exist. Training logs are printed in this notebook cell and mirrored to `/content/drive/MyDrive/EcoCAR/training_runs/notebook_logs/`.

# %% [markdown]
# # Stage 2 Notebook 04 - Exp2E RMT-GCA + matched lane loss
#
# This isolates the target-assignment problem. It keeps the Exp2B architecture, but changes lane supervision from fixed slot order to Hungarian-style matching between predicted lane priors and GT lanes.
#
# This notebook prints training output directly in the cell and mirrors the same text to Drive logs under `/content/drive/MyDrive/EcoCAR/training_runs/notebook_logs/`.

# %%
import os, sys, subprocess, textwrap
from google.colab import drive
os.environ['PYTHONUNBUFFERED'] = '1'
drive.mount('/content/drive')

REPO_ROOT = '/content/drive/MyDrive/EcoCAR/yolop_vehicle_lane'
if not os.path.isdir(REPO_ROOT):
    raise FileNotFoundError(f'Missing project root: {REPO_ROOT}')
os.chdir(REPO_ROOT)
if REPO_ROOT not in sys.path:
    sys.path.insert(0, REPO_ROOT)

subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', 'pyyaml', 'scipy', 'opencv-python-headless', 'tqdm', 'matplotlib'])
print('repo:', REPO_ROOT)

from stage2.scripts.notebook_utils import run_streaming
LOG_DIR = '/content/drive/MyDrive/EcoCAR/training_runs/notebook_logs'
os.makedirs(LOG_DIR, exist_ok=True)
# Out:
# Mounted at /content/drive
# repo: /content/drive/MyDrive/EcoCAR/yolop_vehicle_lane

# %%
from pathlib import Path
import os, sys
CONFIG = 'stage2/configs/exp04_rmt_gca_lane_matching_joint.yaml'
LOG_FILE = os.path.join(LOG_DIR, f'{Path(CONFIG).stem}_smoke.log')
run_streaming([sys.executable, '-u', 'stage2/scripts/smoke_test_joint_models.py', CONFIG], log_path=LOG_FILE)
# Out:
# ================================================================================
# [run_streaming] command: /usr/bin/python3 -u stage2/scripts/smoke_test_joint_models.py stage2/configs/exp04_rmt_gca_lane_matching_joint.yaml
# [run_streaming] log file: /content/drive/MyDrive/EcoCAR/training_runs/notebook_logs/exp04_rmt_gca_lane_matching_joint_smoke.log
# ================================================================================
# OK exp04_rmt_gca_lane_matching_joint.yaml
#   lane_shape=(1, 2, 72, 2) det_shape=(1, 4, 4)
#   lane_loss=2.9557 det_loss=3.5915 grad_cos=0.1443 lambda_lane=0.0813
#   gate_stats={'gate/det_mean': 0.49999043345451355, 'gate/lane_mean': 0.5007238984107971, 'gate/det_sat_low': 0.0, 'gate/det_sat_high': 0.0, 'gate/lane_sat_low': 0.0, 'gate/lane_sat_high': 0.0}
# [run_streaming] return_code=0
# 0

# %%
from pathlib import Path
import os, sys

CONFIG = 'stage2/configs/exp04_rmt_gca_lane_matching_joint.yaml'
CURVE_TAR = '/content/drive/MyDrive/EcoCAR/datasets/bdd100k_clrkd_curve.tar'
CURVE_ROOT = '/content/bdd100k_clrkd_curve'

# First run should be a small debug run. Change to False only after logs,
# smoke test, and metrics look normal.
DEBUG_MODE = True

if DEBUG_MODE:
    RUN_TAG = 'debug'
    EPOCHS = 2
    BATCH_SIZE = 4
    LIMIT_TRAIN = 512
    LIMIT_VAL = 256
    PRINT_EVERY = 5
else:
    RUN_TAG = 'short10'
    EPOCHS = 10
    BATCH_SIZE = 8
    LIMIT_TRAIN = 3000
    LIMIT_VAL = 1000
    PRINT_EVERY = 5

run_stem = Path(CONFIG).stem + '_' + RUN_TAG
WORK_DIR = f'/content/{run_stem}'
OUTPUT_TAR = f'/content/drive/MyDrive/EcoCAR/training_runs/{run_stem}.tar'
LOG_FILE = os.path.join(LOG_DIR, f'{run_stem}_train.log')

cmd = [
    sys.executable, '-u', 'stage2/scripts/train_joint_model_experiment.py',
    '--config', CONFIG,
    '--curve-tar', CURVE_TAR,
    '--curve-root', CURVE_ROOT,
    '--work-dir', WORK_DIR,
    '--output-tar', OUTPUT_TAR,
    '--epochs', str(EPOCHS),
    '--batch-size', str(BATCH_SIZE),
    '--limit-train', str(LIMIT_TRAIN),
    '--limit-val', str(LIMIT_VAL),
    '--force-extract',
    '--print-every', str(PRINT_EVERY),
]

print('DEBUG_MODE:', DEBUG_MODE, flush=True)
print('About to run:', ' '.join(cmd), flush=True)
print('Output tar:', OUTPUT_TAR, flush=True)
print('Visible log file:', LOG_FILE, flush=True)
run_streaming(cmd, log_path=LOG_FILE)
# Out:
# DEBUG_MODE: False
# About to run: /usr/bin/python3 -u stage2/scripts/train_joint_model_experiment.py --config stage2/configs/exp04_rmt_gca_lane_matching_joint.yaml --curve-tar /content/drive/MyDrive/EcoCAR/datasets/bdd100k_clrkd_curve.tar --curve-root /content/bdd100k_clrkd_curve --work-dir /content/exp04_rmt_gca_lane_matching_joint_short10 --output-tar /content/drive/MyDrive/EcoCAR/training_runs/exp04_rmt_gca_lane_matching_joint_short10.tar --epochs 10 --batch-size 8 --limit-train 3000 --limit-val 1000 --force-extract --print-every 5
# Output tar: /content/drive/MyDrive/EcoCAR/training_runs/exp04_rmt_gca_lane_matching_joint_short10.tar
# Visible log file: /content/drive/MyDrive/EcoCAR/training_runs/notebook_logs/exp04_rmt_gca_lane_matching_joint_short10_train.log
# ================================================================================
# [run_streaming] command: /usr/bin/python3 -u stage2/scripts/train_joint_model_experiment.py --config stage2/configs/exp04_rmt_gca_lane_matching_joint.yaml --curve-tar /content/drive/MyDrive/EcoCAR/datasets/bdd100k_clrkd_curve.tar --curve-root /content/bdd100k_clrkd_curve --work-dir /content/exp04_rmt_gca_lane_matching_joint_short10 --output-tar /content/drive/MyDrive/EcoCAR/training_runs/exp04_rmt_gca_lane_matching_joint_short10.tar --epochs 10 --batch-size 8 --limit-train 3000 --limit-val 1000 --force-extract --print-every 5
# [run_streaming] log file: /content/drive/MyDrive/EcoCAR/training_runs/notebook_logs/exp04_rmt_gca_lane_matching_joint_short10_train.log
# ================================================================================
# ==== Stage 2 Joint Training Preflight ====
# run_name=exp04_rmt_gca_lane_matching_joint
# config=stage2/configs/exp04_rmt_gca_lane_matching_joint.yaml
# curve_tar=/content/drive/MyDrive/EcoCAR/datasets/bdd100k_clrkd_curve.tar
# curve_root=/content/bdd100k_clrkd_curve
# work_dir=/content/exp04_rmt_gca_lane_matching_joint_short10
# output_tar=/content/drive/MyDrive/EcoCAR/training_runs/exp04_rmt_gca_lane_matching_joint_short10.tar
# backbone=exp2b_rmt_gca detection_head=detr lane_head=CLRKD-style curve head
# epochs=10 batch_size=8 print_every=5 limit_train=3000 limit_val=1000
# loss=lambda_mode:grad_norm_calibration lambda_lane:0.5 use_uncertainty:False
# Extracting dataset tar: /content/drive/MyDrive/EcoCAR/datasets/bdd100k_clrkd_curve.tar -> /content/bdd100k_clrkd_curve
# [run_streaming] still running; no child output yet. This usually means the first dataloader/model step is still working.
# device=cuda
# gpu=NVIDIA RTX PRO 6000 Blackwell Server Edition
# [dataset] split=train samples=3000 nonempty_det_labels=2977 label_dir=/content/bdd100k_clrkd_curve/labels/train
# [dataset] split=val samples=1000 nonempty_det_labels=996 label_dir=/content/bdd100k_clrkd_curve/labels/val
# [loader] train_batches=375 val_batches=125 workers=2
# [model] class=FusionModel params=8,123,284 trainable_initial=8,123,284
# [model] feature_channels=[128, 128, 128]
# [metric_sources] {
#   "rmt_metric_sources": [
#     "/content/drive/MyDrive/EcoCAR/yolop_vehicle_lane/stage2/vendor/RMT-PPAD/ultralytics/models/mtdetr/val.py",
#     "/content/drive/MyDrive/EcoCAR/yolop_vehicle_lane/stage2/vendor/RMT-PPAD/ultralytics/utils/metrics.py",
#     "/content/drive/MyDrive/EcoCAR/yolop_vehicle_lane/stage2/vendor/RMT-PPAD/ultralytics/models/rtdetr/val.py"
#   ],
#   "clrkd_metric_sources": [
#     "/content/drive/MyDrive/EcoCAR/yolop_vehicle_lane/stage2/vendor/CLRKDNet/clrkd/datasets/bdd100k_curve.py",
#     "/content/drive/MyDrive/EcoCAR/yolop_vehicle_lane/stage2/vendor/CLRKDNet/clrkd/models/utils/dynamic_assign.py"
#   ],
#   "rmt_sources_missing": [],
#   "clrkd_sources_missing": []
# }
# epoch=1 phase=head_warmup batches=375 lane_matching=True geom_scale=0.333
# epoch=1 waiting_for_first_batch...
# epoch=1 step=1/375 total=6.4426 det=4.6545 lane=1.7881 lambda_lane=1.0000 cls=0.0868 reg=0.2552 iou=0.9382 grad_cos=nan speed=0.20step/s eta_min=30.5
# epoch=1 step=5/375 total=5.3464 det=3.5739 lane=1.7725 lambda_lane=1.0000 cls=0.0873 reg=0.3054 iou=0.9731 grad_cos=nan speed=0.98step/s eta_min=6.3
# epoch=1 step=10/375 total=4.4923 det=2.8070 lane=1.6853 lambda_lane=1.0000 cls=0.0875 reg=0.2551 iou=0.9712 grad_cos=nan speed=1.73step/s eta_min=3.5
# epoch=1 step=15/375 total=4.4120 det=2.7541 lane=1.6580 lambda_lane=1.0000 cls=0.0837 reg=0.2478 iou=0.9627 grad_cos=nan speed=2.35step/s eta_min=2.6
# epoch=1 step=20/375 total=4.0491 det=2.4017 lane=1.6474 lambda_lane=1.0000 cls=0.0869 reg=0.2574 iou=0.9782 grad_cos=nan speed=2.84step/s eta_min=2.1
# epoch=1 step=25/375 total=4.0708 det=2.4339 lane=1.6369 lambda_lane=1.0000 cls=0.0840 reg=0.2214 iou=0.9427 grad_cos=nan speed=3.22step/s eta_min=1.8
# epoch=1 step=30/375 total=4.3337 det=2.6761 lane=1.6576 lambda_lane=1.0000 cls=0.0849 reg=0.2497 iou=0.9795 grad_cos=nan speed=3.57step/s eta_min=1.6
# epoch=1 step=35/375 total=3.8502 det=2.2115 lane=1.6387 lambda_lane=1.0000 cls=0.0859 reg=0.2151 iou=0.9818 grad_cos=nan speed=3.85step/s eta_min=1.5
# epoch=1 step=40/375 total=3.9761 det=2.3292 lane=1.6468 lambda_lane=1.0000 cls=0.0866 reg=0.2609 iou=0.9782 grad_cos=nan speed=4.14step/s eta_min=1.3
# epoch=1 step=45/375 total=4.0511 det=2.4218 lane=1.6293 lambda_lane=1.0000 cls=0.0875 reg=0.2262 iou=0.9872 grad_cos=nan speed=4.30step/s eta_min=1.3
# epoch=1 step=50/375 total=4.1218 det=2.5271 lane=1.5947 lambda_lane=1.0000 cls=0.0854 reg=0.2262 iou=0.9566 grad_cos=nan speed=4.50step/s eta_min=1.2
# epoch=1 step=55/375 total=3.9351 det=2.3096 lane=1.6254 lambda_lane=1.0000 cls=0.0853 reg=0.2719 iou=0.9872 grad_cos=nan speed=4.61step/s eta_min=1.2
# epoch=1 step=60/375 total=4.4209 det=2.8163 lane=1.6046 lambda_lane=1.0000 cls=0.0857 reg=0.2302 iou=0.9642 grad_cos=nan speed=4.85step/s eta_min=1.1
# epoch=1 step=65/375 total=4.0686 det=2.4403 lane=1.6282 lambda_lane=1.0000 cls=0.0975 reg=0.2274 iou=0.9825 grad_cos=nan speed=4.96step/s eta_min=1.0
# epoch=1 step=70/375 total=3.9280 det=2.3206 lane=1.6074 lambda_lane=1.0000 cls=0.0872 reg=0.2425 iou=0.9680 grad_cos=nan speed=5.09step/s eta_min=1.0
# epoch=1 step=75/375 total=3.6158 det=2.0299 lane=1.5859 lambda_lane=1.0000 cls=0.0866 reg=0.2522 iou=0.9294 grad_cos=nan speed=5.21step/s eta_min=1.0
# epoch=1 step=80/375 total=4.0965 det=2.5060 lane=1.5905 lambda_lane=1.0000 cls=0.0862 reg=0.2371 iou=0.9803 grad_cos=nan speed=5.34step/s eta_min=0.9
# epoch=1 step=85/375 total=4.2880 det=2.6966 lane=1.5914 lambda_lane=1.0000 cls=0.0855 reg=0.2545 iou=0.9927 grad_cos=nan speed=5.43step/s eta_min=0.9
# epoch=1 step=90/375 total=4.1126 det=2.5413 lane=1.5713 lambda_lane=1.0000 cls=0.0867 reg=0.2384 iou=0.9639 grad_cos=nan speed=5.53step/s eta_min=0.9
# epoch=1 step=95/375 total=3.7999 det=2.2235 lane=1.5765 lambda_lane=1.0000 cls=0.0892 reg=0.2301 iou=0.9586 grad_cos=nan speed=5.62step/s eta_min=0.8
# epoch=1 step=100/375 total=3.9146 det=2.3421 lane=1.5725 lambda_lane=1.0000 cls=0.0851 reg=0.2269 iou=0.9643 grad_cos=nan speed=5.70step/s eta_min=0.8
# epoch=1 step=105/375 total=4.0622 det=2.4979 lane=1.5643 lambda_lane=1.0000 cls=0.0917 reg=0.2427 iou=0.9335 grad_cos=nan speed=5.79step/s eta_min=0.8
# epoch=1 step=110/375 total=4.2124 det=2.6828 lane=1.5296 lambda_lane=1.0000 cls=0.0861 reg=0.2236 iou=0.9423 grad_cos=nan speed=5.82step/s eta_min=0.8
# epoch=1 step=115/375 total=4.0515 det=2.4819 lane=1.5696 lambda_lane=1.0000 cls=0.0871 reg=0.2305 iou=0.9780 grad_cos=nan speed=5.90step/s eta_min=0.7
# epoch=1 step=120/375 total=3.9348 det=2.4131 lane=1.5218 lambda_lane=1.0000 cls=0.0821 reg=0.2142 iou=0.9494 grad_cos=nan speed=5.94step/s eta_min=0.7
# epoch=1 step=125/375 total=3.9410 det=2.4142 lane=1.5268 lambda_lane=1.0000 cls=0.0858 reg=0.2078 iou=0.9316 grad_cos=nan speed=5.97step/s eta_min=0.7
# epoch=1 step=130/375 total=3.7283 det=2.1710 lane=1.5573 lambda_lane=1.0000 cls=0.0864 reg=0.2406 iou=0.9746 grad_cos=nan speed=6.01step/s eta_min=0.7
# epoch=1 step=135/375 total=4.0490 det=2.5163 lane=1.5326 lambda_lane=1.0000 cls=0.0843 reg=0.2193 iou=0.9673 grad_cos=nan speed=6.08step/s eta_min=0.7
# epoch=1 step=140/375 total=3.7190 det=2.1345 lane=1.5845 lambda_lane=1.0000 cls=0.0889 reg=0.2560 iou=0.9937 grad_cos=nan speed=6.12step/s eta_min=0.6
# epoch=1 step=145/375 total=3.8376 det=2.3219 lane=1.5157 lambda_lane=1.0000 cls=0.0810 reg=0.2335 iou=0.9521 grad_cos=nan speed=6.15step/s eta_min=0.6
# epoch=1 step=150/375 total=3.7356 det=2.1926 lane=1.5430 lambda_lane=1.0000 cls=0.0884 reg=0.1991 iou=0.9651 grad_cos=nan speed=6.18step/s eta_min=0.6
# epoch=1 step=155/375 total=3.7356 det=2.2413 lane=1.4943 lambda_lane=1.0000 cls=0.0850 reg=0.2203 iou=0.9389 grad_cos=nan speed=6.24step/s eta_min=0.6
# epoch=1 step=160/375 total=3.4991 det=1.9568 lane=1.5423 lambda_lane=1.0000 cls=0.0880 reg=0.2361 iou=0.9843 grad_cos=nan speed=6.28step/s eta_min=0.6
# epoch=1 step=165/375 total=3.3929 det=1.8629 lane=1.5300 lambda_lane=1.0000 cls=0.0886 reg=0.2467 iou=0.9723 grad_cos=nan speed=6.33step/s eta_min=0.6
# epoch=1 step=170/375 total=3.4828 det=1.9843 lane=1.4985 lambda_lane=1.0000 cls=0.0887 reg=0.2370 iou=0.9078 grad_cos=nan speed=6.36step/s eta_min=0.5
# epoch=1 step=175/375 total=3.7265 det=2.1932 lane=1.5333 lambda_lane=1.0000 cls=0.0866 reg=0.2409 iou=0.9611 grad_cos=nan speed=6.41step/s eta_min=0.5
# epoch=1 step=180/375 total=4.0322 det=2.5349 lane=1.4973 lambda_lane=1.0000 cls=0.0866 reg=0.2468 iou=0.9561 grad_cos=nan speed=6.42step/s eta_min=0.5
# epoch=1 step=185/375 total=4.4082 det=2.8708 lane=1.5374 lambda_lane=1.0000 cls=0.0897 reg=0.2462 iou=0.9787 grad_cos=nan speed=6.46step/s eta_min=0.5
# epoch=1 step=190/375 total=4.1828 det=2.6756 lane=1.5072 lambda_lane=1.0000 cls=0.0846 reg=0.2665 iou=0.9659 grad_cos=nan speed=6.49step/s eta_min=0.5
# epoch=1 step=195/375 total=3.6998 det=2.1927 lane=1.5070 lambda_lane=1.0000 cls=0.0877 reg=0.2462 iou=0.9390 grad_cos=nan speed=6.55step/s eta_min=0.5
# epoch=1 step=200/375 total=3.7948 det=2.2986 lane=1.4961 lambda_lane=1.0000 cls=0.0857 reg=0.2257 iou=0.9453 grad_cos=nan speed=6.54step/s eta_min=0.4
# epoch=1 step=205/375 total=3.6296 det=2.1221 lane=1.5075 lambda_lane=1.0000 cls=0.0892 reg=0.2083 iou=0.9704 grad_cos=nan speed=6.56step/s eta_min=0.4
# epoch=1 step=210/375 total=3.5221 det=2.0169 lane=1.5053 lambda_lane=1.0000 cls=0.0891 reg=0.2061 iou=0.9641 grad_cos=nan speed=6.58step/s eta_min=0.4
# epoch=1 step=215/375 total=3.7308 det=2.2104 lane=1.5204 lambda_lane=1.0000 cls=0.0864 reg=0.2306 iou=0.9867 grad_cos=nan speed=6.64step/s eta_min=0.4
# epoch=1 step=220/375 total=3.7134 det=2.1781 lane=1.5353 lambda_lane=1.0000 cls=0.0876 reg=0.2447 iou=0.9808 grad_cos=nan speed=6.61step/s eta_min=0.4
# epoch=1 step=225/375 total=3.5846 det=2.1109 lane=1.4737 lambda_lane=1.0000 cls=0.0841 reg=0.2047 iou=0.9447 grad_cos=nan speed=6.66step/s eta_min=0.4
# epoch=1 step=230/375 total=3.7627 det=2.2701 lane=1.4926 lambda_lane=1.0000 cls=0.0911 reg=0.2164 iou=0.9584 grad_cos=nan speed=6.64step/s eta_min=0.4
# epoch=1 step=235/375 total=4.2279 det=2.7481 lane=1.4797 lambda_lane=1.0000 cls=0.0888 reg=0.2313 iou=0.9428 grad_cos=nan speed=6.68step/s eta_min=0.3
# epoch=1 step=240/375 total=3.6754 det=2.1774 lane=1.4980 lambda_lane=1.0000 cls=0.0883 reg=0.2144 iou=0.9430 grad_cos=nan speed=6.68step/s eta_min=0.3
# epoch=1 step=245/375 total=3.7506 det=2.2458 lane=1.5048 lambda_lane=1.0000 cls=0.0856 reg=0.2248 iou=0.9520 grad_cos=nan speed=6.72step/s eta_min=0.3
# epoch=1 step=250/375 total=3.5310 det=2.0346 lane=1.4964 lambda_lane=1.0000 cls=0.0868 reg=0.2221 iou=0.9754 grad_cos=nan speed=6.72step/s eta_min=0.3
# epoch=1 step=255/375 total=3.8107 det=2.3371 lane=1.4736 lambda_lane=1.0000 cls=0.0869 reg=0.2146 iou=0.9537 grad_cos=nan speed=6.76step/s eta_min=0.3
# epoch=1 step=260/375 total=3.7142 det=2.2437 lane=1.4705 lambda_lane=1.0000 cls=0.0859 reg=0.2084 iou=0.9698 grad_cos=nan speed=6.76step/s eta_min=0.3
# epoch=1 step=265/375 total=3.8022 det=2.3454 lane=1.4568 lambda_lane=1.0000 cls=0.0853 reg=0.2259 iou=0.9592 grad_cos=nan speed=6.79step/s eta_min=0.3
# epoch=1 step=270/375 total=4.1190 det=2.6342 lane=1.4848 lambda_lane=1.0000 cls=0.0865 reg=0.2453 iou=0.9455 grad_cos=nan speed=6.81step/s eta_min=0.3
# epoch=1 step=275/375 total=4.0438 det=2.5468 lane=1.4970 lambda_lane=1.0000 cls=0.0849 reg=0.2016 iou=0.9829 grad_cos=nan speed=6.83step/s eta_min=0.2
# epoch=1 step=280/375 total=3.6110 det=2.1467 lane=1.4643 lambda_lane=1.0000 cls=0.0862 reg=0.2462 iou=0.9403 grad_cos=nan speed=6.83step/s eta_min=0.2
# epoch=1 step=285/375 total=3.4583 det=2.0013 lane=1.4569 lambda_lane=1.0000 cls=0.0868 reg=0.2138 iou=0.9594 grad_cos=nan speed=6.84step/s eta_min=0.2
# epoch=1 step=290/375 total=3.6841 det=2.2108 lane=1.4733 lambda_lane=1.0000 cls=0.0844 reg=0.2089 iou=0.9577 grad_cos=nan speed=6.86step/s eta_min=0.2
# epoch=1 step=295/375 total=3.6682 det=2.2053 lane=1.4629 lambda_lane=1.0000 cls=0.0875 reg=0.2026 iou=0.9205 grad_cos=nan speed=6.88step/s eta_min=0.2
# epoch=1 step=300/375 total=3.6725 det=2.2041 lane=1.4684 lambda_lane=1.0000 cls=0.0881 reg=0.2149 iou=0.9767 grad_cos=nan speed=6.88step/s eta_min=0.2
# epoch=1 step=305/375 total=3.7617 det=2.2611 lane=1.5005 lambda_lane=1.0000 cls=0.0935 reg=0.2347 iou=0.9462 grad_cos=nan speed=6.91step/s eta_min=0.2
# epoch=1 step=310/375 total=3.5493 det=2.0663 lane=1.4829 lambda_lane=1.0000 cls=0.0849 reg=0.2167 iou=0.9759 grad_cos=nan speed=6.92step/s eta_min=0.2
# epoch=1 step=315/375 total=3.5594 det=2.0835 lane=1.4759 lambda_lane=1.0000 cls=0.0850 reg=0.2103 iou=0.9581 grad_cos=nan speed=6.95step/s eta_min=0.1
# epoch=1 step=320/375 total=3.7681 det=2.2867 lane=1.4814 lambda_lane=1.0000 cls=0.0872 reg=0.2016 iou=0.9530 grad_cos=nan speed=6.95step/s eta_min=0.1
# epoch=1 step=325/375 total=3.8249 det=2.3578 lane=1.4671 lambda_lane=1.0000 cls=0.0879 reg=0.2161 iou=0.9690 grad_cos=nan speed=6.96step/s eta_min=0.1
# epoch=1 step=330/375 total=3.5976 det=2.1335 lane=1.4641 lambda_lane=1.0000 cls=0.0877 reg=0.2146 iou=0.9821 grad_cos=nan speed=6.98step/s eta_min=0.1
# epoch=1 step=335/375 total=3.7598 det=2.3097 lane=1.4501 lambda_lane=1.0000 cls=0.0844 reg=0.2220 iou=0.9550 grad_cos=nan speed=6.99step/s eta_min=0.1
# epoch=1 step=340/375 total=3.7821 det=2.3224 lane=1.4596 lambda_lane=1.0000 cls=0.0857 reg=0.1986 iou=0.9513 grad_cos=nan speed=7.00step/s eta_min=0.1
# epoch=1 step=345/375 total=3.8665 det=2.3781 lane=1.4884 lambda_lane=1.0000 cls=0.0857 reg=0.2344 iou=0.9698 grad_cos=nan speed=7.03step/s eta_min=0.1
# epoch=1 step=350/375 total=3.7864 det=2.3143 lane=1.4721 lambda_lane=1.0000 cls=0.0857 reg=0.2164 iou=0.9529 grad_cos=nan speed=7.04step/s eta_min=0.1
# epoch=1 step=355/375 total=3.4761 det=1.9895 lane=1.4866 lambda_lane=1.0000 cls=0.0847 reg=0.2119 iou=0.9478 grad_cos=nan speed=7.04step/s eta_min=0.0
# epoch=1 step=360/375 total=3.6600 det=2.1700 lane=1.4901 lambda_lane=1.0000 cls=0.0834 reg=0.2027 iou=0.9669 grad_cos=nan speed=7.05step/s eta_min=0.0
# epoch=1 step=365/375 total=3.8963 det=2.4439 lane=1.4524 lambda_lane=1.0000 cls=0.0882 reg=0.2097 iou=0.9312 grad_cos=nan speed=7.06step/s eta_min=0.0
# epoch=1 step=370/375 total=3.6100 det=2.1601 lane=1.4499 lambda_lane=1.0000 cls=0.0856 reg=0.2393 iou=0.9469 grad_cos=nan speed=7.08step/s eta_min=0.0
# epoch=1 step=375/375 total=3.4640 det=1.9954 lane=1.4686 lambda_lane=1.0000 cls=0.0871 reg=0.1927 iou=0.9692 grad_cos=nan speed=7.09step/s eta_min=0.0
# epoch=1 validation_start batches=40
# epoch=1 validation_done
# {
#   "train/total": 3.8772995370229086,
#   "train/phase_id": 1.0,
#   "train/mtl/lambda_lane_epoch": 1.0,
#   "train/lane/geometry_scale": 0.3333333432674408,
#   "train/lane/cls": 0.08673805445432663,
#   "train/lane/cls_pos": 0.0867769646247228,
#   "train/lane/cls_neg": 0.08669914448261261,
#   "train/lane/reg": 0.22903992823759714,
#   "train/lane/xytl": 0.16892780343691507,
#   "train/lane/line_iou": 0.9601993789672851,
#   "train/lane/mask_aux": 0.588948252360026,
#   "train/lane/smooth": 0.0034771937460949024,
#   "train/lane/distill": 0.0,
#   "train/lane/geometry_raw": 1.3616443026860554,
#   "train/lane/geometry_weighted": 0.7277993919054667,
#   "train/lane/unweighted_total": 2.0373306182225543,
#   "train/lane/weighted_total": 1.533592782974243,
#   "train/lane/total": 1.533592782974243,
#   "train/det/obj": 0.19392967609564463,
#   "train/det/cls": 0.0044222807701056206,
#   "train/det/bbox_l1": 0.061686651329199475,
#   "train/det/giou": 0.9184594984054566,
#   "train/det/dn": 0.0,
#   "train/det/total": 2.3437042083740236,
#   "train/det/positives": 86.456,
#   "train/mtl/lambda_lane_runtime": 1.0,
#   "train/mtl/grad_norm_ratio": 0.0026666666666666666,
#   "train/mtl/gate_reg": 0.002555690875897805,
#   "train/gate/det_mean": 0.499725239833196,
#   "train/gate/lane_mean": 0.5005627865791321,
#   "train/gate/det_sat_low": 0.0,
#   "train/gate/det_sat_high": 0.0,
#   "train/gate/lane_sat_low": 0.0,
#   "train/gate/lane_sat_high": 0.0,
#   "epoch": 1.0,
#   "val/lane_loss": 1.455260807275772,
#   "val/lane_loss_scaled": 1.455260807275772,
#   "val/det_loss": 2.2365195512771607,
#   "val/lane_exist_acc": 0.5575000025331974,
#   "val/lane_exist_precision": 0.5575000025331974,
#   "val/lane_exist_recall": 0.9999999940395355,
#   "val/lane_exist_f1": 0.7092854797840118,
#   "val/lane_exist_best_f1": 0.7196618735790252,
#   "val/lane_exist_best_threshold": 0.11750000063329935,
#   "val/lane_exist_pos_score_mean": 0.49936746507883073,
#   "val/lane_exist_neg_score_mean": 0.49631059914827347,
#   "val/lane_point_mae": 0.4716174237430096,
#   "val/matched_lane_point_mae": 0.4716174237430096,
#   "val/matched_line_iou": 0.05147895705886185,
#   "val/num_gt_lanes": 44.6,
#   "val/num_pred_lanes": 80.0,
#   "val/num_matched_lanes": 44.6,
#   "val/false_positive_lane_slots": 35.4,
#   "val/false_negative_lane_slots": 0.0,
#   "val/lane/clrkd_style_f1": 0.011396461818367242,
#   "val/lane/clrkd_style_precision": 0.009062500158324837,
#   "val/lane/clrkd_style_recall": 0.015621083183214068,
#   "val/lane/clrkd_style_tp": 0.725,
#   "val/lane/clrkd_style_fp": 79.275,
#   "val/lane/clrkd_style_fn": 43.875,
#   "val/det/metric_map50": 0.002055779653164791,
#   "val/det/metric_precision50": 0.0119316186173819,
#   "val/det/metric_recall50": 0.09908319776877761,
#   "val/det/metric_num_gt": 85.65,
#   "val/det/metric_num_pred": 695.85,
#   "val/lane/cls": 0.08588621802628041,
#   "val/lane/cls_pos": 0.08715435732156038,
#   "val/lane/cls_neg": 0.08461807928979397,
#   "val/lane/reg": 0.21261124014854432,
#   "val/lane/xytl": 0.12181971967220306,
#   "val/lane/line_iou": 0.9485210448503494,
#   "val/lane/mask_aux": 0.529162073880434,
#   "val/lane/smooth": 0.0026443989481776953,
#   "val/lane/distill": 0.0,
#   "val/lane/geometry_raw": 1.2855964034795762,
#   "val/lane/geometry_weighted": 0.7113831907510757,
#   "val/lane/unweighted_total": 1.900644689798355,
#   "val/lane/weighted_total": 1.455260807275772,
#   "val/lane/total": 1.455260807275772,
#   "val/det/obj": 0.18704109750688075,
#   "val/det/cls": 0.0005508248468686361,
#   "val/det/bbox_l1": 0.05736325243487954,
#   "val/det/giou": 0.881055673956871,
#   "val/det/dn": 0.0,
#   "val/det/total": 2.2365195512771607,
#   "val/det/positives": 85.65
# }
# [epoch_summary] epoch=1 phase=head_warmup train_total=3.8773 train_det=2.3437 train_lane=1.5336 val_det=2.2365 val_lane_scaled=1.4553 val_lane_unweighted=1.9006 val_lane_exist_acc=0.5575 val_lane_f1=0.7093 val_lane_best_f1=0.7197 best_thr=0.12 val_lane_precision=0.5575 val_lane_recall=1.0000 val_lane_point_mae=0.4716 val_matched_line_iou=0.0515 val_clrkd_f1=0.0114 val_map50=0.0021 best_score=-2.9641 elapsed_s=58.9 peak_mem_mb=4592
# epoch=2 phase=adapter_warmup batches=375 lane_matching=True geom_scale=0.667
# epoch=2 waiting_for_first_batch...
# epoch=2 step=1/375 total=6.3688 det=2.0938 lane=2.1375 lambda_lane=2.0000 cls=0.0860 reg=0.2061 iou=0.9432 grad_cos=-0.0894 speed=1.16step/s eta_min=5.4
# epoch=2 step=5/375 total=6.5203 det=2.1153 lane=2.2025 lambda_lane=2.0000 cls=0.0866 reg=0.2224 iou=0.9728 grad_cos=nan speed=4.38step/s eta_min=1.4
# epoch=2 step=10/375 total=6.3132 det=2.0282 lane=2.1425 lambda_lane=2.0000 cls=0.0860 reg=0.2172 iou=0.9316 grad_cos=nan speed=5.21step/s eta_min=1.2
# epoch=2 step=15/375 total=6.8488 det=2.5967 lane=2.1260 lambda_lane=2.0000 cls=0.0858 reg=0.2062 iou=0.9375 grad_cos=nan speed=6.02step/s eta_min=1.0
# epoch=2 step=20/375 total=6.4349 det=2.1543 lane=2.1403 lambda_lane=2.0000 cls=0.0871 reg=0.2136 iou=0.9489 grad_cos=nan speed=6.49step/s eta_min=0.9
# epoch=2 step=25/375 total=6.4469 det=2.2031 lane=2.1219 lambda_lane=2.0000 cls=0.0846 reg=0.1931 iou=0.9482 grad_cos=nan speed=6.73step/s eta_min=0.9
# epoch=2 step=30/375 total=6.4734 det=2.2387 lane=2.1173 lambda_lane=2.0000 cls=0.0839 reg=0.2028 iou=0.9365 grad_cos=nan speed=6.73step/s eta_min=0.9
# epoch=2 step=35/375 total=6.3476 det=2.0970 lane=2.1253 lambda_lane=2.0000 cls=0.0872 reg=0.2147 iou=0.9301 grad_cos=nan speed=6.91step/s eta_min=0.8
# epoch=2 step=40/375 total=6.4660 det=2.1700 lane=2.1480 lambda_lane=2.0000 cls=0.0886 reg=0.2159 iou=0.9443 grad_cos=nan speed=6.85step/s eta_min=0.8
# epoch=2 step=45/375 total=6.6525 det=2.2658 lane=2.1933 lambda_lane=2.0000 cls=0.0891 reg=0.2244 iou=0.9658 grad_cos=nan speed=7.14step/s eta_min=0.8
# epoch=2 step=50/375 total=6.5241 det=2.2823 lane=2.1209 lambda_lane=2.0000 cls=0.0874 reg=0.2066 iou=0.9256 grad_cos=nan speed=7.23step/s eta_min=0.7
# epoch=2 step=55/375 total=6.4289 det=2.1295 lane=2.1497 lambda_lane=2.0000 cls=0.0856 reg=0.2229 iou=0.9371 grad_cos=nan speed=7.32step/s eta_min=0.7
# epoch=2 step=60/375 total=6.2814 det=2.0670 lane=2.1072 lambda_lane=2.0000 cls=0.0863 reg=0.1753 iou=0.9166 grad_cos=nan speed=7.39step/s eta_min=0.7
# epoch=2 step=65/375 total=6.4331 det=2.2380 lane=2.0975 lambda_lane=2.0000 cls=0.0846 reg=0.1985 iou=0.9056 grad_cos=nan speed=7.47step/s eta_min=0.7
# epoch=2 step=70/375 total=6.2119 det=2.0158 lane=2.0980 lambda_lane=2.0000 cls=0.0859 reg=0.1896 iou=0.9067 grad_cos=nan speed=7.53step/s eta_min=0.7
# epoch=2 step=75/375 total=6.6782 det=2.3400 lane=2.1691 lambda_lane=2.0000 cls=0.0835 reg=0.2164 iou=0.9487 grad_cos=nan speed=7.46step/s eta_min=0.7
# epoch=2 step=80/375 total=6.3967 det=2.1194 lane=2.1387 lambda_lane=2.0000 cls=0.0842 reg=0.2002 iou=0.9388 grad_cos=nan speed=7.42step/s eta_min=0.7
# epoch=2 step=85/375 total=6.2121 det=2.0208 lane=2.0957 lambda_lane=2.0000 cls=0.0892 reg=0.1812 iou=0.9100 grad_cos=nan speed=7.40step/s eta_min=0.7
# epoch=2 step=90/375 total=6.2909 det=2.0579 lane=2.1165 lambda_lane=2.0000 cls=0.0801 reg=0.2228 iou=0.9568 grad_cos=nan speed=7.31step/s eta_min=0.6
# epoch=2 step=95/375 total=6.3595 det=2.0790 lane=2.1403 lambda_lane=2.0000 cls=0.0817 reg=0.2170 iou=0.9504 grad_cos=nan speed=7.37step/s eta_min=0.6
# epoch=2 step=100/375 total=6.4282 det=2.0864 lane=2.1709 lambda_lane=2.0000 cls=0.0890 reg=0.2026 iou=0.9630 grad_cos=nan speed=7.37step/s eta_min=0.6
# epoch=2 step=105/375 total=6.4808 det=2.1647 lane=2.1581 lambda_lane=2.0000 cls=0.0892 reg=0.2048 iou=0.9422 grad_cos=nan speed=7.33step/s eta_min=0.6
# epoch=2 step=110/375 total=6.2104 det=2.0416 lane=2.0844 lambda_lane=2.0000 cls=0.0835 reg=0.2213 iou=0.9239 grad_cos=nan speed=7.29step/s eta_min=0.6
# epoch=2 step=115/375 total=6.4908 det=2.1999 lane=2.1454 lambda_lane=2.0000 cls=0.0863 reg=0.2287 iou=0.9199 grad_cos=nan speed=7.35step/s eta_min=0.6
# epoch=2 step=120/375 total=6.4025 det=2.1523 lane=2.1251 lambda_lane=2.0000 cls=0.0881 reg=0.2127 iou=0.9236 grad_cos=nan speed=7.37step/s eta_min=0.6
# epoch=2 step=125/375 total=6.4346 det=2.1808 lane=2.1269 lambda_lane=2.0000 cls=0.0867 reg=0.1967 iou=0.9367 grad_cos=nan speed=7.43step/s eta_min=0.6
# epoch=2 step=130/375 total=6.6078 det=2.4271 lane=2.0903 lambda_lane=2.0000 cls=0.0879 reg=0.2016 iou=0.9494 grad_cos=nan speed=7.43step/s eta_min=0.5
# epoch=2 step=135/375 total=6.6278 det=2.3670 lane=2.1304 lambda_lane=2.0000 cls=0.0900 reg=0.1716 iou=0.9411 grad_cos=nan speed=7.48step/s eta_min=0.5
# epoch=2 step=140/375 total=6.3444 det=2.0204 lane=2.1620 lambda_lane=2.0000 cls=0.0906 reg=0.2133 iou=0.9376 grad_cos=nan speed=7.46step/s eta_min=0.5
# epoch=2 step=145/375 total=6.5321 det=2.2652 lane=2.1334 lambda_lane=2.0000 cls=0.0874 reg=0.2173 iou=0.9425 grad_cos=nan speed=7.48step/s eta_min=0.5
# epoch=2 step=150/375 total=6.7807 det=2.3980 lane=2.1913 lambda_lane=2.0000 cls=0.0884 reg=0.2212 iou=0.9656 grad_cos=nan speed=7.51step/s eta_min=0.5
# epoch=2 step=155/375 total=6.6822 det=2.5380 lane=2.0721 lambda_lane=2.0000 cls=0.0851 reg=0.1846 iou=0.9267 grad_cos=nan speed=7.54step/s eta_min=0.5
# epoch=2 step=160/375 total=6.4731 det=2.3274 lane=2.0729 lambda_lane=2.0000 cls=0.0850 reg=0.1708 iou=0.9210 grad_cos=nan speed=7.50step/s eta_min=0.5
# epoch=2 step=165/375 total=6.1029 det=2.0053 lane=2.0488 lambda_lane=2.0000 cls=0.0810 reg=0.1723 iou=0.9234 grad_cos=nan speed=7.51step/s eta_min=0.5
# epoch=2 step=170/375 total=6.4060 det=2.2145 lane=2.0957 lambda_lane=2.0000 cls=0.0802 reg=0.1910 iou=0.9381 grad_cos=nan speed=7.49step/s eta_min=0.5
# epoch=2 step=175/375 total=6.3655 det=2.1041 lane=2.1307 lambda_lane=2.0000 cls=0.0934 reg=0.1939 iou=0.9226 grad_cos=nan speed=7.51step/s eta_min=0.4
# epoch=2 step=180/375 total=6.5458 det=2.3543 lane=2.0957 lambda_lane=2.0000 cls=0.0844 reg=0.1944 iou=0.9475 grad_cos=nan speed=7.47step/s eta_min=0.4
# epoch=2 step=185/375 total=6.3028 det=2.1103 lane=2.0963 lambda_lane=2.0000 cls=0.0859 reg=0.1899 iou=0.9416 grad_cos=nan speed=7.48step/s eta_min=0.4
# epoch=2 step=190/375 total=6.4844 det=2.1522 lane=2.1661 lambda_lane=2.0000 cls=0.0857 reg=0.2031 iou=0.9589 grad_cos=nan speed=7.45step/s eta_min=0.4
# epoch=2 step=195/375 total=6.2608 det=1.9315 lane=2.1646 lambda_lane=2.0000 cls=0.0898 reg=0.2033 iou=0.9458 grad_cos=nan speed=7.44step/s eta_min=0.4
# epoch=2 step=200/375 total=6.0132 det=1.8860 lane=2.0636 lambda_lane=2.0000 cls=0.0863 reg=0.1817 iou=0.8983 grad_cos=nan speed=7.44step/s eta_min=0.4
# epoch=2 step=205/375 total=6.5740 det=2.3079 lane=2.1331 lambda_lane=2.0000 cls=0.0889 reg=0.1938 iou=0.9593 grad_cos=nan speed=7.45step/s eta_min=0.4
# epoch=2 step=210/375 total=6.1025 det=1.8968 lane=2.1028 lambda_lane=2.0000 cls=0.0877 reg=0.1816 iou=0.9243 grad_cos=nan speed=7.46step/s eta_min=0.4
# epoch=2 step=215/375 total=6.2963 det=2.0766 lane=2.1098 lambda_lane=2.0000 cls=0.0801 reg=0.1931 iou=0.9514 grad_cos=nan speed=7.48step/s eta_min=0.4
# epoch=2 step=220/375 total=6.2897 det=2.0574 lane=2.1162 lambda_lane=2.0000 cls=0.0825 reg=0.2089 iou=0.9581 grad_cos=nan speed=7.48step/s eta_min=0.3
# epoch=2 step=225/375 total=6.3401 det=2.1766 lane=2.0817 lambda_lane=2.0000 cls=0.0860 reg=0.1911 iou=0.9103 grad_cos=nan speed=7.49step/s eta_min=0.3
# epoch=2 step=230/375 total=6.6701 det=2.3628 lane=2.1536 lambda_lane=2.0000 cls=0.0935 reg=0.2005 iou=0.9331 grad_cos=nan speed=7.48step/s eta_min=0.3
# epoch=2 step=235/375 total=6.5480 det=2.3697 lane=2.0892 lambda_lane=2.0000 cls=0.0863 reg=0.1688 iou=0.9390 grad_cos=nan speed=7.47step/s eta_min=0.3
# epoch=2 step=240/375 total=6.1140 det=1.9950 lane=2.0595 lambda_lane=2.0000 cls=0.0889 reg=0.1907 iou=0.9088 grad_cos=nan speed=7.46step/s eta_min=0.3
# epoch=2 step=245/375 total=6.4221 det=2.0813 lane=2.1704 lambda_lane=2.0000 cls=0.0864 reg=0.2318 iou=0.9466 grad_cos=nan speed=7.49step/s eta_min=0.3
# epoch=2 step=250/375 total=6.3387 det=2.1189 lane=2.1099 lambda_lane=2.0000 cls=0.0856 reg=0.1976 iou=0.9144 grad_cos=nan speed=7.51step/s eta_min=0.3
# epoch=2 step=255/375 total=6.2960 det=1.9076 lane=2.1942 lambda_lane=2.0000 cls=0.0860 reg=0.2316 iou=0.9241 grad_cos=nan speed=7.54step/s eta_min=0.3
# epoch=2 step=260/375 total=6.3847 det=2.1016 lane=2.1415 lambda_lane=2.0000 cls=0.0855 reg=0.2085 iou=0.9533 grad_cos=nan speed=7.52step/s eta_min=0.3
# epoch=2 step=265/375 total=6.3216 det=2.1482 lane=2.0867 lambda_lane=2.0000 cls=0.0846 reg=0.1981 iou=0.9087 grad_cos=nan speed=7.53step/s eta_min=0.2
# epoch=2 step=270/375 total=5.8752 det=1.7339 lane=2.0706 lambda_lane=2.0000 cls=0.0853 reg=0.1831 iou=0.9187 grad_cos=nan speed=7.52step/s eta_min=0.2
# epoch=2 step=275/375 total=6.4712 det=2.3283 lane=2.0715 lambda_lane=2.0000 cls=0.0869 reg=0.1861 iou=0.9022 grad_cos=nan speed=7.53step/s eta_min=0.2
# epoch=2 step=280/375 total=6.4707 det=2.0148 lane=2.2280 lambda_lane=2.0000 cls=0.0915 reg=0.2140 iou=0.9562 grad_cos=nan speed=7.49step/s eta_min=0.2
# epoch=2 step=285/375 total=6.8731 det=2.6562 lane=2.1085 lambda_lane=2.0000 cls=0.0852 reg=0.2258 iou=0.9427 grad_cos=nan speed=7.53step/s eta_min=0.2
# epoch=2 step=290/375 total=6.1686 det=1.9549 lane=2.1069 lambda_lane=2.0000 cls=0.0830 reg=0.2014 iou=0.9386 grad_cos=nan speed=7.54step/s eta_min=0.2
# epoch=2 step=295/375 total=6.3686 det=2.1757 lane=2.0964 lambda_lane=2.0000 cls=0.0918 reg=0.1790 iou=0.9457 grad_cos=nan speed=7.55step/s eta_min=0.2
# epoch=2 step=300/375 total=6.3411 det=2.2179 lane=2.0616 lambda_lane=2.0000 cls=0.0860 reg=0.1661 iou=0.9122 grad_cos=nan speed=7.53step/s eta_min=0.2
# epoch=2 step=305/375 total=6.1520 det=1.9759 lane=2.0881 lambda_lane=2.0000 cls=0.0870 reg=0.2112 iou=0.9193 grad_cos=nan speed=7.55step/s eta_min=0.2
# epoch=2 step=310/375 total=6.5179 det=2.3477 lane=2.0851 lambda_lane=2.0000 cls=0.0859 reg=0.2048 iou=0.9333 grad_cos=nan speed=7.56step/s eta_min=0.1
# epoch=2 step=315/375 total=6.5033 det=2.2481 lane=2.1276 lambda_lane=2.0000 cls=0.0846 reg=0.2054 iou=0.9567 grad_cos=nan speed=7.56step/s eta_min=0.1
# epoch=2 step=320/375 total=6.3014 det=2.1796 lane=2.0609 lambda_lane=2.0000 cls=0.0837 reg=0.1936 iou=0.9304 grad_cos=nan speed=7.56step/s eta_min=0.1
# epoch=2 step=325/375 total=6.3462 det=2.1309 lane=2.1077 lambda_lane=2.0000 cls=0.0838 reg=0.1671 iou=0.9405 grad_cos=nan speed=7.57step/s eta_min=0.1
# epoch=2 step=330/375 total=6.3351 det=2.1180 lane=2.1086 lambda_lane=2.0000 cls=0.0859 reg=0.1745 iou=0.9343 grad_cos=nan speed=7.56step/s eta_min=0.1
# epoch=2 step=335/375 total=6.2029 det=2.0701 lane=2.0664 lambda_lane=2.0000 cls=0.0845 reg=0.1819 iou=0.9307 grad_cos=nan speed=7.59step/s eta_min=0.1
# epoch=2 step=340/375 total=6.4498 det=2.1854 lane=2.1322 lambda_lane=2.0000 cls=0.0886 reg=0.1991 iou=0.9530 grad_cos=nan speed=7.58step/s eta_min=0.1
# epoch=2 step=345/375 total=6.5030 det=2.2644 lane=2.1193 lambda_lane=2.0000 cls=0.0865 reg=0.1708 iou=0.9646 grad_cos=nan speed=7.59step/s eta_min=0.1
# epoch=2 step=350/375 total=6.5594 det=2.4330 lane=2.0632 lambda_lane=2.0000 cls=0.0889 reg=0.1854 iou=0.8937 grad_cos=nan speed=7.59step/s eta_min=0.1
# epoch=2 step=355/375 total=6.2836 det=2.0379 lane=2.1229 lambda_lane=2.0000 cls=0.0855 reg=0.2066 iou=0.9622 grad_cos=nan speed=7.60step/s eta_min=0.0
# epoch=2 step=360/375 total=6.6881 det=2.3612 lane=2.1634 lambda_lane=2.0000 cls=0.0845 reg=0.2094 iou=0.9363 grad_cos=nan speed=7.57step/s eta_min=0.0
# epoch=2 step=365/375 total=6.3393 det=2.1053 lane=2.1170 lambda_lane=2.0000 cls=0.0830 reg=0.2029 iou=0.9405 grad_cos=nan speed=7.59step/s eta_min=0.0
# epoch=2 step=370/375 total=6.2037 det=2.0064 lane=2.0986 lambda_lane=2.0000 cls=0.0845 reg=0.1895 iou=0.9200 grad_cos=nan speed=7.59step/s eta_min=0.0
# epoch=2 step=375/375 total=6.3485 det=1.9819 lane=2.1833 lambda_lane=2.0000 cls=0.0855 reg=0.2124 iou=0.9613 grad_cos=nan speed=7.60step/s eta_min=0.0
# epoch=2 validation_start batches=40
# epoch=2 validation_done
# {
#   "train/total": 6.4252874984741215,
#   "train/grad_cosine": -0.0002382858395576477,
#   "train/phase_id": 2.0,
#   "train/mtl/lambda_lane_epoch": 2.0,
#   "train/lane/geometry_scale": 0.6666666865348816,
#   "train/lane/cls": 0.08606774920225144,
#   "train/lane/cls_pos": 0.0860821322798729,
#   "train/lane/cls_neg": 0.08605336614449818,
#   "train/lane/reg": 0.20180246158440907,
#   "train/lane/xytl": 0.12604311289389927,
#   "train/lane/line_iou": 0.9343785481452942,
#   "train/lane/mask_aux": 0.5045871977011362,
#   "train/lane/smooth": 0.0021560606214528284,
#   "train/lane/distill": 0.0,
#   "train/lane/geometry_raw": 1.264380179087321,
#   "train/lane/geometry_weighted": 1.397250698407491,
#   "train/lane/unweighted_total": 1.8550351295471192,
#   "train/lane/weighted_total": 2.117007267634074,
#   "train/lane/total": 2.117007267634074,
#   "train/det/obj": 0.19179107407728832,
#   "train/det/cls": 0.00039023897824032853,
#   "train/det/bbox_l1": 0.049373997420072556,
#   "train/det/giou": 0.8761096048355103,
#   "train/det/dn": 0.0,
#   "train/det/total": 2.1912705132166543,
#   "train/det/positives": 86.456,
#   "train/mtl/lambda_lane_runtime": 2.0,
#   "train/mtl/grad_norm_ratio": 0.005333333333333333,
#   "train/mtl/gate_reg": 0.0025693970092882713,
#   "train/gate/det_mean": 0.4994987463951111,
#   "train/gate/lane_mean": 0.5004384783109029,
#   "train/gate/det_sat_low": 0.0,
#   "train/gate/det_sat_high": 0.0,
#   "train/gate/lane_sat_low": 0.0,
#   "train/gate/lane_sat_high": 0.0,
#   "epoch": 2.0,
#   "val/lane_loss": 2.1432680189609528,
#   "val/lane_loss_scaled": 2.1432680189609528,
#   "val/det_loss": 2.140754225850105,
#   "val/lane_exist_acc": 0.5575000025331974,
#   "val/lane_exist_precision": 0.5575000025331974,
#   "val/lane_exist_recall": 0.9999999940395355,
#   "val/lane_exist_f1": 0.7092854797840118,
#   "val/lane_exist_best_f1": 0.7216304466128349,
#   "val/lane_exist_best_threshold": 0.153749998472631,
#   "val/lane_exist_pos_score_mean": 0.5087285004556179,
#   "val/lane_exist_neg_score_mean": 0.5012865610420704,
#   "val/lane_point_mae": 0.5122367903590203,
#   "val/matched_lane_point_mae": 0.5122367903590203,
#   "val/matched_line_iou": 0.0597110774833709,
#   "val/num_gt_lanes": 44.6,
#   "val/num_pred_lanes": 80.0,
#   "val/num_matched_lanes": 44.6,
#   "val/false_positive_lane_slots": 35.4,
#   "val/false_negative_lane_slots": 0.0,
#   "val/lane/clrkd_style_f1": 0.013841598364524543,
#   "val/lane/clrkd_style_precision": 0.010937500232830643,
#   "val/lane/clrkd_style_recall": 0.019415421038866044,
#   "val/lane/clrkd_style_tp": 0.875,
#   "val/lane/clrkd_style_fp": 79.125,
#   "val/lane/clrkd_style_fn": 43.725,
#   "val/det/metric_map50": 0.0027098374353954568,
#   "val/det/metric_precision50": 0.013406250055413692,
#   "val/det/metric_recall50": 0.12717264872044326,
#   "val/det/metric_num_gt": 85.65,
#   "val/det/metric_num_pred": 800.0,
#   "val/lane/cls": 0.08529548924416304,
#   "val/lane/cls_pos": 0.08222845811396837,
#   "val/lane/cls_neg": 0.08836252111941575,
#   "val/lane/reg": 0.2330627016723156,
#   "val/lane/xytl": 0.13753681648522614,
#   "val/lane/line_iou": 0.940288907289505,
#   "val/lane/mask_aux": 0.502530837059021,
#   "val/lane/smooth": 0.0019945392559748143,
#   "val/lane/distill": 0.0,
#   "val/lane/geometry_raw": 1.3128829628229142,
#   "val/lane/geometry_weighted": 1.42749844789505,
#   "val/lane/unweighted_total": 1.9007092773914338,
#   "val/lane/weighted_total": 2.1432680189609528,
#   "val/lane/total": 2.1432680189609528,
#   "val/det/obj": 0.19082522839307786,
#   "val/det/cls": 0.00025699645666463764,
#   "val/det/bbox_l1": 0.04725326420739293,
#   "val/det/giou": 0.856702844798565,
#   "val/det/dn": 0.0,
#   "val/det/total": 2.140754225850105,
#   "val/det/positives": 85.65
# }
# [epoch_summary] epoch=2 phase=adapter_warmup train_total=6.4253 train_det=2.1913 train_lane=2.1170 val_det=2.1408 val_lane_scaled=2.1433 val_lane_unweighted=1.9007 val_lane_exist_acc=0.5575 val_lane_f1=0.7093 val_lane_best_f1=0.7216 best_thr=0.15 val_lane_precision=0.5575 val_lane_recall=1.0000 val_lane_point_mae=0.5122 val_matched_line_iou=0.0597 val_clrkd_f1=0.0138 val_map50=0.0027 best_score=-2.9641 elapsed_s=55.4 peak_mem_mb=4592
# epoch=3 phase=adapter_warmup batches=375 lane_matching=True geom_scale=1.000
# epoch=3 waiting_for_first_batch...
# epoch=3 step=1/375 total=2.9318 det=2.3681 lane=2.8185 lambda_lane=0.2000 cls=0.0844 reg=0.2116 iou=0.9593 grad_cos=-0.0076 speed=1.55step/s eta_min=4.0
# epoch=3 step=5/375 total=2.4339 det=1.8627 lane=2.8558 lambda_lane=0.2000 cls=0.0834 reg=0.2267 iou=0.9530 grad_cos=nan speed=4.32step/s eta_min=1.4
# epoch=3 step=10/375 total=2.7663 det=2.2044 lane=2.8093 lambda_lane=0.2000 cls=0.0863 reg=0.1896 iou=0.9261 grad_cos=nan speed=5.67step/s eta_min=1.1
# epoch=3 step=15/375 total=2.6687 det=2.1015 lane=2.8363 lambda_lane=0.2000 cls=0.0885 reg=0.1978 iou=0.9347 grad_cos=nan speed=5.80step/s eta_min=1.0
# epoch=3 step=20/375 total=2.8090 det=2.2387 lane=2.8512 lambda_lane=0.2000 cls=0.0842 reg=0.2459 iou=0.9230 grad_cos=nan speed=6.50step/s eta_min=0.9
# epoch=3 step=25/375 total=2.3909 det=1.8431 lane=2.7391 lambda_lane=0.2000 cls=0.0890 reg=0.1659 iou=0.9200 grad_cos=nan speed=6.53step/s eta_min=0.9
# epoch=3 step=30/375 total=2.6585 det=2.0944 lane=2.8206 lambda_lane=0.2000 cls=0.0826 reg=0.2021 iou=0.9671 grad_cos=nan speed=6.77step/s eta_min=0.8
# epoch=3 step=35/375 total=2.6215 det=2.0567 lane=2.8244 lambda_lane=0.2000 cls=0.0927 reg=0.2068 iou=0.9292 grad_cos=nan speed=6.69step/s eta_min=0.8
# epoch=3 step=40/375 total=2.8678 det=2.3222 lane=2.7280 lambda_lane=0.2000 cls=0.0894 reg=0.1941 iou=0.8991 grad_cos=nan speed=6.93step/s eta_min=0.8
# epoch=3 step=45/375 total=2.9991 det=2.4536 lane=2.7278 lambda_lane=0.2000 cls=0.0846 reg=0.2399 iou=0.8886 grad_cos=nan speed=7.13step/s eta_min=0.8
# epoch=3 step=50/375 total=2.6861 det=2.1327 lane=2.7667 lambda_lane=0.2000 cls=0.0862 reg=0.1744 iou=0.9348 grad_cos=nan speed=7.23step/s eta_min=0.7
# epoch=3 step=55/375 total=2.9416 det=2.3685 lane=2.8657 lambda_lane=0.2000 cls=0.0842 reg=0.2299 iou=0.9459 grad_cos=nan speed=7.32step/s eta_min=0.7
# epoch=3 step=60/375 total=2.8094 det=2.2619 lane=2.7376 lambda_lane=0.2000 cls=0.0900 reg=0.2168 iou=0.8948 grad_cos=nan speed=7.39step/s eta_min=0.7
# epoch=3 step=65/375 total=2.7331 det=2.1792 lane=2.7697 lambda_lane=0.2000 cls=0.0876 reg=0.1772 iou=0.9045 grad_cos=nan speed=7.37step/s eta_min=0.7
# epoch=3 step=70/375 total=2.8642 det=2.2957 lane=2.8423 lambda_lane=0.2000 cls=0.0806 reg=0.2279 iou=0.9505 grad_cos=nan speed=7.44step/s eta_min=0.7
# epoch=3 step=75/375 total=2.7578 det=2.1884 lane=2.8471 lambda_lane=0.2000 cls=0.0894 reg=0.2042 iou=0.9528 grad_cos=nan speed=7.33step/s eta_min=0.7
# epoch=3 step=80/375 total=2.8136 det=2.2610 lane=2.7631 lambda_lane=0.2000 cls=0.0873 reg=0.1762 iou=0.9312 grad_cos=nan speed=7.38step/s eta_min=0.7
# epoch=3 step=85/375 total=2.7095 det=2.1494 lane=2.8006 lambda_lane=0.2000 cls=0.0861 reg=0.2228 iou=0.9236 grad_cos=nan speed=7.43step/s eta_min=0.7
# epoch=3 step=90/375 total=2.7782 det=2.2361 lane=2.7104 lambda_lane=0.2000 cls=0.0854 reg=0.1679 iou=0.9050 grad_cos=nan speed=7.43step/s eta_min=0.6
# epoch=3 step=95/375 total=3.0068 det=2.4549 lane=2.7595 lambda_lane=0.2000 cls=0.0836 reg=0.1748 iou=0.9470 grad_cos=nan speed=7.48step/s eta_min=0.6
# epoch=3 step=100/375 total=2.8240 det=2.2626 lane=2.8071 lambda_lane=0.2000 cls=0.0882 reg=0.2008 iou=0.9445 grad_cos=nan speed=7.51step/s eta_min=0.6
# epoch=3 step=105/375 total=2.7155 det=2.1602 lane=2.7769 lambda_lane=0.2000 cls=0.0852 reg=0.2019 iou=0.9235 grad_cos=nan speed=7.52step/s eta_min=0.6
# epoch=3 step=110/375 total=2.7562 det=2.2171 lane=2.6953 lambda_lane=0.2000 cls=0.0851 reg=0.1733 iou=0.9148 grad_cos=nan speed=7.51step/s eta_min=0.6
# epoch=3 step=115/375 total=2.9050 det=2.3427 lane=2.8111 lambda_lane=0.2000 cls=0.0868 reg=0.1836 iou=0.9492 grad_cos=nan speed=7.52step/s eta_min=0.6
# epoch=3 step=120/375 total=2.5976 det=2.0663 lane=2.6566 lambda_lane=0.2000 cls=0.0858 reg=0.1786 iou=0.8773 grad_cos=nan speed=7.55step/s eta_min=0.6
# epoch=3 step=125/375 total=2.6074 det=2.0526 lane=2.7738 lambda_lane=0.2000 cls=0.0867 reg=0.1969 iou=0.9225 grad_cos=nan speed=7.53step/s eta_min=0.6
# epoch=3 step=130/375 total=2.7845 det=2.2526 lane=2.6592 lambda_lane=0.2000 cls=0.0860 reg=0.1848 iou=0.8985 grad_cos=nan speed=7.58step/s eta_min=0.5
# epoch=3 step=135/375 total=3.1699 det=2.6020 lane=2.8392 lambda_lane=0.2000 cls=0.0883 reg=0.2207 iou=0.9346 grad_cos=nan speed=7.58step/s eta_min=0.5
# epoch=3 step=140/375 total=2.9484 det=2.3812 lane=2.8363 lambda_lane=0.2000 cls=0.0869 reg=0.2062 iou=0.9242 grad_cos=nan speed=7.59step/s eta_min=0.5
# epoch=3 step=145/375 total=2.8048 det=2.2628 lane=2.7102 lambda_lane=0.2000 cls=0.0871 reg=0.1839 iou=0.9118 grad_cos=nan speed=7.50step/s eta_min=0.5
# epoch=3 step=150/375 total=2.8309 det=2.2756 lane=2.7767 lambda_lane=0.2000 cls=0.0850 reg=0.2032 iou=0.9402 grad_cos=nan speed=7.50step/s eta_min=0.5
# epoch=3 step=155/375 total=3.0118 det=2.4573 lane=2.7727 lambda_lane=0.2000 cls=0.0851 reg=0.2098 iou=0.9207 grad_cos=nan speed=7.49step/s eta_min=0.5
# epoch=3 step=160/375 total=2.7276 det=2.1681 lane=2.7975 lambda_lane=0.2000 cls=0.0870 reg=0.1984 iou=0.9525 grad_cos=nan speed=7.56step/s eta_min=0.5
# epoch=3 step=165/375 total=2.8265 det=2.2802 lane=2.7317 lambda_lane=0.2000 cls=0.0857 reg=0.2024 iou=0.8985 grad_cos=nan speed=7.54step/s eta_min=0.5
# epoch=3 step=170/375 total=2.7156 det=2.1683 lane=2.7366 lambda_lane=0.2000 cls=0.0898 reg=0.1881 iou=0.8993 grad_cos=nan speed=7.60step/s eta_min=0.4
# epoch=3 step=175/375 total=2.9452 det=2.4002 lane=2.7251 lambda_lane=0.2000 cls=0.0867 reg=0.1892 iou=0.8998 grad_cos=nan speed=7.59step/s eta_min=0.4
# epoch=3 step=180/375 total=2.6058 det=2.0508 lane=2.7749 lambda_lane=0.2000 cls=0.0847 reg=0.1850 iou=0.9441 grad_cos=nan speed=7.59step/s eta_min=0.4
# epoch=3 step=185/375 total=2.8263 det=2.2853 lane=2.7053 lambda_lane=0.2000 cls=0.0861 reg=0.1737 iou=0.9125 grad_cos=nan speed=7.55step/s eta_min=0.4
# epoch=3 step=190/375 total=2.8396 det=2.3140 lane=2.6279 lambda_lane=0.2000 cls=0.0831 reg=0.1767 iou=0.8824 grad_cos=nan speed=7.58step/s eta_min=0.4
# epoch=3 step=195/375 total=2.6404 det=2.0748 lane=2.8276 lambda_lane=0.2000 cls=0.0860 reg=0.1936 iou=0.9509 grad_cos=nan speed=7.56step/s eta_min=0.4
# epoch=3 step=200/375 total=2.5670 det=2.0035 lane=2.8175 lambda_lane=0.2000 cls=0.0868 reg=0.2001 iou=0.9275 grad_cos=nan speed=7.58step/s eta_min=0.4
# epoch=3 step=205/375 total=2.6123 det=2.0575 lane=2.7738 lambda_lane=0.2000 cls=0.0895 reg=0.2008 iou=0.9158 grad_cos=nan speed=7.55step/s eta_min=0.4
# epoch=3 step=210/375 total=2.8518 det=2.3021 lane=2.7483 lambda_lane=0.2000 cls=0.0887 reg=0.1986 iou=0.9081 grad_cos=nan speed=7.55step/s eta_min=0.4
# epoch=3 step=215/375 total=3.0217 det=2.4615 lane=2.8009 lambda_lane=0.2000 cls=0.0859 reg=0.2070 iou=0.9367 grad_cos=nan speed=7.52step/s eta_min=0.4
# epoch=3 step=220/375 total=2.7991 det=2.2452 lane=2.7694 lambda_lane=0.2000 cls=0.0880 reg=0.1919 iou=0.9222 grad_cos=nan speed=7.52step/s eta_min=0.3
# epoch=3 step=225/375 total=2.8026 det=2.2674 lane=2.6763 lambda_lane=0.2000 cls=0.0837 reg=0.1918 iou=0.9051 grad_cos=nan speed=7.49step/s eta_min=0.3
# epoch=3 step=230/375 total=2.7596 det=2.2248 lane=2.6740 lambda_lane=0.2000 cls=0.0836 reg=0.1701 iou=0.8814 grad_cos=nan speed=7.50step/s eta_min=0.3
# epoch=3 step=235/375 total=2.7286 det=2.1896 lane=2.6954 lambda_lane=0.2000 cls=0.0870 reg=0.1798 iou=0.8962 grad_cos=nan speed=7.49step/s eta_min=0.3
# epoch=3 step=240/375 total=2.6326 det=2.0833 lane=2.7465 lambda_lane=0.2000 cls=0.0888 reg=0.1737 iou=0.9073 grad_cos=nan speed=7.51step/s eta_min=0.3
# epoch=3 step=245/375 total=2.5904 det=2.0251 lane=2.8263 lambda_lane=0.2000 cls=0.0856 reg=0.1896 iou=0.9487 grad_cos=nan speed=7.53step/s eta_min=0.3
# epoch=3 step=250/375 total=2.8233 det=2.2587 lane=2.8229 lambda_lane=0.2000 cls=0.0834 reg=0.2107 iou=0.9590 grad_cos=nan speed=7.56step/s eta_min=0.3
# epoch=3 step=255/375 total=2.9775 det=2.4350 lane=2.7124 lambda_lane=0.2000 cls=0.0830 reg=0.1801 iou=0.9298 grad_cos=nan speed=7.58step/s eta_min=0.3
# epoch=3 step=260/375 total=2.5215 det=1.9633 lane=2.7910 lambda_lane=0.2000 cls=0.0871 reg=0.2018 iou=0.9392 grad_cos=nan speed=7.57step/s eta_min=0.3
# epoch=3 step=265/375 total=2.7660 det=2.2376 lane=2.6420 lambda_lane=0.2000 cls=0.0829 reg=0.1648 iou=0.8886 grad_cos=nan speed=7.60step/s eta_min=0.2
# epoch=3 step=270/375 total=2.8983 det=2.3583 lane=2.6998 lambda_lane=0.2000 cls=0.0854 reg=0.1949 iou=0.8951 grad_cos=nan speed=7.60step/s eta_min=0.2
# epoch=3 step=275/375 total=2.5031 det=1.9588 lane=2.7217 lambda_lane=0.2000 cls=0.0861 reg=0.1722 iou=0.9092 grad_cos=nan speed=7.59step/s eta_min=0.2
# epoch=3 step=280/375 total=2.9246 det=2.3704 lane=2.7709 lambda_lane=0.2000 cls=0.0828 reg=0.1930 iou=0.9455 grad_cos=nan speed=7.55step/s eta_min=0.2
# epoch=3 step=285/375 total=2.7390 det=2.1791 lane=2.7997 lambda_lane=0.2000 cls=0.0858 reg=0.1860 iou=0.9374 grad_cos=nan speed=7.57step/s eta_min=0.2
# epoch=3 step=290/375 total=2.6107 det=2.0357 lane=2.8750 lambda_lane=0.2000 cls=0.0882 reg=0.1851 iou=0.9688 grad_cos=nan speed=7.59step/s eta_min=0.2
# epoch=3 step=295/375 total=2.7847 det=2.2195 lane=2.8263 lambda_lane=0.2000 cls=0.0854 reg=0.1965 iou=0.9347 grad_cos=nan speed=7.59step/s eta_min=0.2
# epoch=3 step=300/375 total=2.6758 det=2.1250 lane=2.7538 lambda_lane=0.2000 cls=0.0884 reg=0.1997 iou=0.9185 grad_cos=nan speed=7.60step/s eta_min=0.2
# epoch=3 step=305/375 total=2.7556 det=2.1979 lane=2.7883 lambda_lane=0.2000 cls=0.0861 reg=0.1931 iou=0.9352 grad_cos=nan speed=7.59step/s eta_min=0.2
# epoch=3 step=310/375 total=2.9669 det=2.4141 lane=2.7637 lambda_lane=0.2000 cls=0.0878 reg=0.1965 iou=0.9281 grad_cos=nan speed=7.59step/s eta_min=0.1
# epoch=3 step=315/375 total=2.6955 det=2.1436 lane=2.7595 lambda_lane=0.2000 cls=0.0873 reg=0.1756 iou=0.9162 grad_cos=nan speed=7.61step/s eta_min=0.1
# epoch=3 step=320/375 total=2.8452 det=2.2838 lane=2.8069 lambda_lane=0.2000 cls=0.0862 reg=0.2068 iou=0.9476 grad_cos=nan speed=7.56step/s eta_min=0.1
# epoch=3 step=325/375 total=2.9259 det=2.3610 lane=2.8244 lambda_lane=0.2000 cls=0.0869 reg=0.1880 iou=0.9336 grad_cos=nan speed=7.56step/s eta_min=0.1
# epoch=3 step=330/375 total=2.8300 det=2.2803 lane=2.7480 lambda_lane=0.2000 cls=0.0842 reg=0.1948 iou=0.9328 grad_cos=nan speed=7.57step/s eta_min=0.1
# epoch=3 step=335/375 total=2.8420 det=2.2868 lane=2.7764 lambda_lane=0.2000 cls=0.0866 reg=0.1802 iou=0.9302 grad_cos=nan speed=7.57step/s eta_min=0.1
# epoch=3 step=340/375 total=2.7606 det=2.2178 lane=2.7139 lambda_lane=0.2000 cls=0.0831 reg=0.1822 iou=0.9327 grad_cos=nan speed=7.56step/s eta_min=0.1
# epoch=3 step=345/375 total=2.7224 det=2.1691 lane=2.7664 lambda_lane=0.2000 cls=0.0837 reg=0.1741 iou=0.9322 grad_cos=nan speed=7.58step/s eta_min=0.1
# epoch=3 step=350/375 total=2.5125 det=1.9659 lane=2.7332 lambda_lane=0.2000 cls=0.0863 reg=0.1657 iou=0.9223 grad_cos=nan speed=7.58step/s eta_min=0.1
# epoch=3 step=355/375 total=2.8067 det=2.2410 lane=2.8284 lambda_lane=0.2000 cls=0.0864 reg=0.1829 iou=0.9566 grad_cos=nan speed=7.60step/s eta_min=0.0
# epoch=3 step=360/375 total=2.4681 det=1.9133 lane=2.7741 lambda_lane=0.2000 cls=0.0867 reg=0.1793 iou=0.9492 grad_cos=nan speed=7.58step/s eta_min=0.0
# epoch=3 step=365/375 total=2.9096 det=2.3589 lane=2.7536 lambda_lane=0.2000 cls=0.0869 reg=0.1692 iou=0.9264 grad_cos=nan speed=7.59step/s eta_min=0.0
# epoch=3 step=370/375 total=2.7940 det=2.2551 lane=2.6944 lambda_lane=0.2000 cls=0.0867 reg=0.1784 iou=0.9029 grad_cos=nan speed=7.58step/s eta_min=0.0
# epoch=3 step=375/375 total=2.9876 det=2.4229 lane=2.8237 lambda_lane=0.2000 cls=0.0887 reg=0.1919 iou=0.9502 grad_cos=nan speed=7.60step/s eta_min=0.0
# epoch=3 validation_start batches=40
# epoch=3 validation_done
# {
#   "train/total": 2.7713398812611896,
#   "train/grad_cosine": -2.015005424618721e-05,
#   "train/phase_id": 3.0,
#   "train/mtl/lambda_lane_epoch": 0.20000000298023224,
#   "train/lane/geometry_scale": 1.0,
#   "train/lane/cls": 0.08634116429090499,
#   "train/lane/cls_pos": 0.08605718755722046,
#   "train/lane/cls_neg": 0.08662514074643453,
#   "train/lane/reg": 0.19046139204502105,
#   "train/lane/xytl": 0.11980003470182418,
#   "train/lane/line_iou": 0.9236626993815105,
#   "train/lane/mask_aux": 0.48250039863586425,
#   "train/lane/smooth": 0.001205483534373343,
#   "train/lane/distill": 0.0,
#   "train/lane/geometry_raw": 1.2351296087900798,
#   "train/lane/geometry_weighted": 2.061807070414225,
#   "train/lane/unweighted_total": 1.8039711688359579,
#   "train/lane/weighted_total": 2.7601603711446128,
#   "train/lane/total": 2.7601603711446128,
#   "train/det/obj": 0.19252934579054515,
#   "train/det/cls": 0.00022276598416889708,
#   "train/det/bbox_l1": 0.050766591956218084,
#   "train/det/giou": 0.8863600519498189,
#   "train/det/dn": 0.0,
#   "train/det/total": 2.21930517800649,
#   "train/det/positives": 86.456,
#   "train/mtl/lambda_lane_runtime": 0.20000000298023224,
#   "train/mtl/grad_norm_ratio": 0.0005333333412806193,
#   "train/mtl/gate_reg": 0.00259278019455572,
#   "train/gate/det_mean": 0.49909959014256794,
#   "train/gate/lane_mean": 0.5002428409258525,
#   "train/gate/det_sat_low": 0.0,
# ...
# epoch=10 waiting_for_first_batch...
# epoch=10 step=1/375 total=4.9655 det=1.9633 lane=2.7176 lambda_lane=1.1047 cls=0.0814 reg=0.1675 iou=0.9471 grad_cos=0.0314 speed=1.89step/s eta_min=3.3
# epoch=10 step=5/375 total=4.9609 det=2.0871 lane=2.6014 lambda_lane=1.1047 cls=0.0822 reg=0.1687 iou=0.8823 grad_cos=nan speed=5.36step/s eta_min=1.2
# epoch=10 step=10/375 total=4.8596 det=1.8784 lane=2.6986 lambda_lane=1.1047 cls=0.0842 reg=0.1757 iou=0.9205 grad_cos=nan speed=6.86step/s eta_min=0.9
# epoch=10 step=15/375 total=5.0227 det=2.0428 lane=2.6974 lambda_lane=1.1047 cls=0.0860 reg=0.1733 iou=0.9064 grad_cos=nan speed=7.34step/s eta_min=0.8
# epoch=10 step=20/375 total=4.8253 det=1.8658 lane=2.6790 lambda_lane=1.1047 cls=0.0874 reg=0.1813 iou=0.9209 grad_cos=nan speed=7.44step/s eta_min=0.8
# epoch=10 step=25/375 total=4.7210 det=1.7655 lane=2.6753 lambda_lane=1.1047 cls=0.0815 reg=0.1754 iou=0.9339 grad_cos=nan speed=7.59step/s eta_min=0.8
# epoch=10 step=30/375 total=4.7464 det=1.8344 lane=2.6360 lambda_lane=1.1047 cls=0.0831 reg=0.1630 iou=0.9109 grad_cos=nan speed=7.49step/s eta_min=0.8
# epoch=10 step=35/375 total=5.1146 det=2.0919 lane=2.7362 lambda_lane=1.1047 cls=0.0789 reg=0.1761 iou=0.9503 grad_cos=nan speed=7.72step/s eta_min=0.7
# epoch=10 step=40/375 total=4.9659 det=2.0171 lane=2.6693 lambda_lane=1.1047 cls=0.0870 reg=0.1819 iou=0.9133 grad_cos=nan speed=7.87step/s eta_min=0.7
# epoch=10 step=45/375 total=4.7790 det=1.8878 lane=2.6171 lambda_lane=1.1047 cls=0.0867 reg=0.1873 iou=0.8990 grad_cos=nan speed=7.80step/s eta_min=0.7
# epoch=10 step=50/375 total=5.0888 det=2.0617 lane=2.7401 lambda_lane=1.1047 cls=0.0803 reg=0.1695 iou=0.9329 grad_cos=nan speed=7.85step/s eta_min=0.7
# epoch=10 step=55/375 total=5.0091 det=2.0669 lane=2.6633 lambda_lane=1.1047 cls=0.0818 reg=0.1826 iou=0.9072 grad_cos=nan speed=7.77step/s eta_min=0.7
# epoch=10 step=60/375 total=5.0113 det=1.9649 lane=2.7576 lambda_lane=1.1047 cls=0.0852 reg=0.1854 iou=0.9351 grad_cos=nan speed=7.75step/s eta_min=0.7
# epoch=10 step=65/375 total=4.9660 det=1.9667 lane=2.7150 lambda_lane=1.1047 cls=0.0838 reg=0.1818 iou=0.9354 grad_cos=nan speed=7.60step/s eta_min=0.7
# epoch=10 step=70/375 total=5.4379 det=2.3702 lane=2.7769 lambda_lane=1.1047 cls=0.0881 reg=0.1907 iou=0.9374 grad_cos=nan speed=7.79step/s eta_min=0.7
# epoch=10 step=75/375 total=5.0192 det=1.9945 lane=2.7380 lambda_lane=1.1047 cls=0.0835 reg=0.1923 iou=0.9401 grad_cos=nan speed=7.72step/s eta_min=0.6
# epoch=10 step=80/375 total=5.2194 det=2.1527 lane=2.7760 lambda_lane=1.1047 cls=0.0887 reg=0.1935 iou=0.9358 grad_cos=nan speed=7.75step/s eta_min=0.6
# epoch=10 step=85/375 total=4.9245 det=2.0079 lane=2.6402 lambda_lane=1.1047 cls=0.0776 reg=0.1945 iou=0.9235 grad_cos=nan speed=7.66step/s eta_min=0.6
# epoch=10 step=90/375 total=5.1930 det=2.2693 lane=2.6466 lambda_lane=1.1047 cls=0.0900 reg=0.1770 iou=0.8920 grad_cos=nan speed=7.68step/s eta_min=0.6
# epoch=10 step=95/375 total=5.1105 det=2.1187 lane=2.7082 lambda_lane=1.1047 cls=0.0913 reg=0.1941 iou=0.9125 grad_cos=nan speed=7.64step/s eta_min=0.6
# epoch=10 step=100/375 total=5.2489 det=2.2225 lane=2.7395 lambda_lane=1.1047 cls=0.0867 reg=0.1924 iou=0.9257 grad_cos=nan speed=7.70step/s eta_min=0.6
# epoch=10 step=105/375 total=5.3710 det=2.4018 lane=2.6877 lambda_lane=1.1047 cls=0.0885 reg=0.1816 iou=0.9147 grad_cos=nan speed=7.62step/s eta_min=0.6
# epoch=10 step=110/375 total=5.3789 det=2.3907 lane=2.7050 lambda_lane=1.1047 cls=0.0852 reg=0.1714 iou=0.9285 grad_cos=nan speed=7.71step/s eta_min=0.6
# epoch=10 step=115/375 total=5.2462 det=2.2787 lane=2.6862 lambda_lane=1.1047 cls=0.0777 reg=0.1812 iou=0.9420 grad_cos=nan speed=7.71step/s eta_min=0.6
# epoch=10 step=120/375 total=5.0302 det=2.0919 lane=2.6598 lambda_lane=1.1047 cls=0.0812 reg=0.1761 iou=0.9153 grad_cos=nan speed=7.69step/s eta_min=0.6
# epoch=10 step=125/375 total=5.1233 det=2.1109 lane=2.7268 lambda_lane=1.1047 cls=0.0874 reg=0.1814 iou=0.9459 grad_cos=nan speed=7.69step/s eta_min=0.5
# epoch=10 step=130/375 total=5.2124 det=2.2022 lane=2.7249 lambda_lane=1.1047 cls=0.0828 reg=0.2017 iou=0.9287 grad_cos=nan speed=7.70step/s eta_min=0.5
# epoch=10 step=135/375 total=4.7588 det=1.8874 lane=2.5993 lambda_lane=1.1047 cls=0.0769 reg=0.1786 iou=0.9036 grad_cos=nan speed=7.69step/s eta_min=0.5
# epoch=10 step=140/375 total=4.9287 det=1.9036 lane=2.7383 lambda_lane=1.1047 cls=0.0817 reg=0.1798 iou=0.9507 grad_cos=nan speed=7.71step/s eta_min=0.5
# epoch=10 step=145/375 total=5.0862 det=2.1759 lane=2.6344 lambda_lane=1.1047 cls=0.0880 reg=0.1753 iou=0.8951 grad_cos=nan speed=7.71step/s eta_min=0.5
# epoch=10 step=150/375 total=5.0073 det=2.0754 lane=2.6540 lambda_lane=1.1047 cls=0.0897 reg=0.1597 iou=0.9230 grad_cos=nan speed=7.72step/s eta_min=0.5
# epoch=10 step=155/375 total=5.2805 det=2.2414 lane=2.7510 lambda_lane=1.1047 cls=0.0927 reg=0.1818 iou=0.9427 grad_cos=nan speed=7.72step/s eta_min=0.5
# epoch=10 step=160/375 total=5.0384 det=2.0731 lane=2.6842 lambda_lane=1.1047 cls=0.0867 reg=0.1786 iou=0.9118 grad_cos=nan speed=7.66step/s eta_min=0.5
# epoch=10 step=165/375 total=5.3218 det=2.3136 lane=2.7231 lambda_lane=1.1047 cls=0.0781 reg=0.1806 iou=0.9272 grad_cos=nan speed=7.65step/s eta_min=0.5
# epoch=10 step=170/375 total=5.1071 det=2.0979 lane=2.7239 lambda_lane=1.1047 cls=0.0813 reg=0.1967 iou=0.9334 grad_cos=nan speed=7.58step/s eta_min=0.5
# epoch=10 step=175/375 total=5.0269 det=2.0724 lane=2.6744 lambda_lane=1.1047 cls=0.0827 reg=0.1803 iou=0.9193 grad_cos=nan speed=7.58step/s eta_min=0.4
# epoch=10 step=180/375 total=5.1633 det=2.2507 lane=2.6365 lambda_lane=1.1047 cls=0.0895 reg=0.1725 iou=0.8970 grad_cos=nan speed=7.53step/s eta_min=0.4
# epoch=10 step=185/375 total=5.0105 det=2.1003 lane=2.6343 lambda_lane=1.1047 cls=0.0804 reg=0.1691 iou=0.9166 grad_cos=nan speed=7.57step/s eta_min=0.4
# epoch=10 step=190/375 total=4.9361 det=1.9961 lane=2.6613 lambda_lane=1.1047 cls=0.0786 reg=0.1943 iou=0.9207 grad_cos=nan speed=7.59step/s eta_min=0.4
# epoch=10 step=195/375 total=5.2266 det=2.1840 lane=2.7542 lambda_lane=1.1047 cls=0.0882 reg=0.1844 iou=0.9286 grad_cos=nan speed=7.61step/s eta_min=0.4
# epoch=10 step=200/375 total=4.8867 det=1.9458 lane=2.6621 lambda_lane=1.1047 cls=0.0849 reg=0.1795 iou=0.8874 grad_cos=nan speed=7.60step/s eta_min=0.4
# epoch=10 step=205/375 total=5.0588 det=1.9599 lane=2.8051 lambda_lane=1.1047 cls=0.0899 reg=0.1969 iou=0.9545 grad_cos=nan speed=7.61step/s eta_min=0.4
# epoch=10 step=210/375 total=4.9925 det=2.0410 lane=2.6717 lambda_lane=1.1047 cls=0.0849 reg=0.1711 iou=0.9011 grad_cos=nan speed=7.64step/s eta_min=0.4
# epoch=10 step=215/375 total=4.9904 det=1.9996 lane=2.7073 lambda_lane=1.1047 cls=0.0866 reg=0.1847 iou=0.9226 grad_cos=nan speed=7.64step/s eta_min=0.3
# epoch=10 step=220/375 total=4.9534 det=2.0212 lane=2.6543 lambda_lane=1.1047 cls=0.0809 reg=0.1629 iou=0.9277 grad_cos=nan speed=7.66step/s eta_min=0.3
# epoch=10 step=225/375 total=5.1536 det=2.1889 lane=2.6837 lambda_lane=1.1047 cls=0.0873 reg=0.1698 iou=0.9272 grad_cos=nan speed=7.64step/s eta_min=0.3
# epoch=10 step=230/375 total=4.9900 det=2.1998 lane=2.5257 lambda_lane=1.1047 cls=0.0846 reg=0.1741 iou=0.8549 grad_cos=nan speed=7.63step/s eta_min=0.3
# epoch=10 step=235/375 total=4.8032 det=1.8962 lane=2.6315 lambda_lane=1.1047 cls=0.0834 reg=0.1655 iou=0.8983 grad_cos=nan speed=7.68step/s eta_min=0.3
# epoch=10 step=240/375 total=5.2160 det=2.2494 lane=2.6854 lambda_lane=1.1047 cls=0.0835 reg=0.1652 iou=0.9194 grad_cos=nan speed=7.68step/s eta_min=0.3
# epoch=10 step=245/375 total=4.9859 det=2.1110 lane=2.6024 lambda_lane=1.1047 cls=0.0810 reg=0.1642 iou=0.8878 grad_cos=nan speed=7.69step/s eta_min=0.3
# epoch=10 step=250/375 total=4.9078 det=1.9405 lane=2.6860 lambda_lane=1.1047 cls=0.0908 reg=0.1751 iou=0.9267 grad_cos=nan speed=7.69step/s eta_min=0.3
# epoch=10 step=255/375 total=5.0176 det=2.0758 lane=2.6629 lambda_lane=1.1047 cls=0.0797 reg=0.1896 iou=0.9130 grad_cos=nan speed=7.68step/s eta_min=0.3
# epoch=10 step=260/375 total=5.1302 det=2.0932 lane=2.7491 lambda_lane=1.1047 cls=0.0859 reg=0.2119 iou=0.9207 grad_cos=nan speed=7.68step/s eta_min=0.2
# epoch=10 step=265/375 total=5.0335 det=2.1017 lane=2.6539 lambda_lane=1.1047 cls=0.0798 reg=0.1947 iou=0.9125 grad_cos=nan speed=7.69step/s eta_min=0.2
# epoch=10 step=270/375 total=5.0380 det=1.9916 lane=2.7577 lambda_lane=1.1047 cls=0.0862 reg=0.1789 iou=0.9345 grad_cos=nan speed=7.71step/s eta_min=0.2
# epoch=10 step=275/375 total=4.9721 det=1.9817 lane=2.7069 lambda_lane=1.1047 cls=0.0836 reg=0.1782 iou=0.9318 grad_cos=nan speed=7.72step/s eta_min=0.2
# epoch=10 step=280/375 total=4.9164 det=1.9284 lane=2.7048 lambda_lane=1.1047 cls=0.0830 reg=0.1710 iou=0.9287 grad_cos=nan speed=7.70step/s eta_min=0.2
# epoch=10 step=285/375 total=4.7487 det=1.8243 lane=2.6472 lambda_lane=1.1047 cls=0.0870 reg=0.1780 iou=0.9199 grad_cos=nan speed=7.70step/s eta_min=0.2
# epoch=10 step=290/375 total=4.9268 det=1.9496 lane=2.6950 lambda_lane=1.1047 cls=0.0904 reg=0.1705 iou=0.9110 grad_cos=nan speed=7.72step/s eta_min=0.2
# epoch=10 step=295/375 total=5.0347 det=2.0189 lane=2.7300 lambda_lane=1.1047 cls=0.0898 reg=0.1732 iou=0.9209 grad_cos=nan speed=7.69step/s eta_min=0.2
# epoch=10 step=300/375 total=5.1575 det=2.1701 lane=2.7042 lambda_lane=1.1047 cls=0.0836 reg=0.1857 iou=0.9219 grad_cos=nan speed=7.70step/s eta_min=0.2
# epoch=10 step=305/375 total=5.1661 det=2.2333 lane=2.6548 lambda_lane=1.1047 cls=0.0811 reg=0.1886 iou=0.8995 grad_cos=nan speed=7.70step/s eta_min=0.2
# epoch=10 step=310/375 total=5.3657 det=2.3186 lane=2.7582 lambda_lane=1.1047 cls=0.0907 reg=0.1877 iou=0.9310 grad_cos=nan speed=7.68step/s eta_min=0.1
# epoch=10 step=315/375 total=4.8408 det=1.8772 lane=2.6827 lambda_lane=1.1047 cls=0.0833 reg=0.1787 iou=0.9230 grad_cos=nan speed=7.68step/s eta_min=0.1
# epoch=10 step=320/375 total=5.0023 det=2.0198 lane=2.6998 lambda_lane=1.1047 cls=0.0856 reg=0.1981 iou=0.9389 grad_cos=nan speed=7.67step/s eta_min=0.1
# epoch=10 step=325/375 total=5.2010 det=2.1911 lane=2.7246 lambda_lane=1.1047 cls=0.0808 reg=0.2141 iou=0.9341 grad_cos=nan speed=7.68step/s eta_min=0.1
# epoch=10 step=330/375 total=4.9304 det=2.0004 lane=2.6522 lambda_lane=1.1047 cls=0.0818 reg=0.1688 iou=0.9101 grad_cos=nan speed=7.64step/s eta_min=0.1
# epoch=10 step=335/375 total=5.0336 det=2.0344 lane=2.7148 lambda_lane=1.1047 cls=0.0811 reg=0.1773 iou=0.9337 grad_cos=nan speed=7.66step/s eta_min=0.1
# epoch=10 step=340/375 total=5.0807 det=2.0935 lane=2.7040 lambda_lane=1.1047 cls=0.0894 reg=0.1991 iou=0.9043 grad_cos=nan speed=7.65step/s eta_min=0.1
# epoch=10 step=345/375 total=4.9054 det=1.9185 lane=2.7037 lambda_lane=1.1047 cls=0.0861 reg=0.1737 iou=0.9348 grad_cos=nan speed=7.67step/s eta_min=0.1
# epoch=10 step=350/375 total=4.8579 det=1.8992 lane=2.6782 lambda_lane=1.1047 cls=0.0745 reg=0.1823 iou=0.9362 grad_cos=nan speed=7.69step/s eta_min=0.1
# epoch=10 step=355/375 total=4.9184 det=1.9371 lane=2.6987 lambda_lane=1.1047 cls=0.0891 reg=0.1766 iou=0.9205 grad_cos=nan speed=7.68step/s eta_min=0.0
# epoch=10 step=360/375 total=5.0523 det=2.0846 lane=2.6864 lambda_lane=1.1047 cls=0.0908 reg=0.1671 iou=0.9275 grad_cos=nan speed=7.66step/s eta_min=0.0
# epoch=10 step=365/375 total=4.7364 det=1.8155 lane=2.6440 lambda_lane=1.1047 cls=0.0818 reg=0.1758 iou=0.8924 grad_cos=nan speed=7.65step/s eta_min=0.0
# epoch=10 step=370/375 total=4.9327 det=2.1017 lane=2.5626 lambda_lane=1.1047 cls=0.0826 reg=0.1627 iou=0.8683 grad_cos=nan speed=7.66step/s eta_min=0.0
# epoch=10 step=375/375 total=5.1917 det=2.1707 lane=2.7346 lambda_lane=1.1047 cls=0.0834 reg=0.1841 iou=0.9290 grad_cos=nan speed=7.65step/s eta_min=0.0
# epoch=10 validation_start batches=40
# epoch=10 validation_done
# {
#   "train/total": 5.026134955088297,
#   "train/grad_cosine": 8.373017112414042e-05,
#   "train/phase_id": 10.0,
#   "train/mtl/lambda_lane_epoch": 1.1047208309173584,
#   "train/lane/geometry_scale": 1.0,
#   "train/lane/cls": 0.08446032265822093,
#   "train/lane/cls_pos": 0.08441149606307348,
#   "train/lane/cls_neg": 0.08450914921363195,
#   "train/lane/reg": 0.18181074730555216,
#   "train/lane/xytl": 0.11579011398553848,
#   "train/lane/line_iou": 0.9179133448600769,
#   "train/lane/mask_aux": 0.4396158995628357,
#   "train/lane/smooth": 0.0009621851424065729,
#   "train/lane/distill": 0.0,
#   "train/lane/geometry_raw": 1.21647638575236,
#   "train/lane/geometry_weighted": 2.0408435684839885,
#   "train/lane/unweighted_total": 1.7405526167551677,
#   "train/lane/weighted_total": 2.6916102670033775,
#   "train/lane/total": 2.6916102670033775,
#   "train/det/obj": 0.19489927629629772,
#   "train/det/cls": 6.730180328304414e-05,
#   "train/det/bbox_l1": 0.03922690716385841,
#   "train/det/giou": 0.8307766051292419,
#   "train/det/dn": 0.0,
#   "train/det/total": 2.0526543216705324,
#   "train/det/positives": 86.456,
#   "train/mtl/lambda_lane_runtime": 1.1047208309173584,
#   "train/mtl/grad_norm_ratio": 0.0029459222157796226,
#   "train/mtl/gate_reg": 0.002644458613047997,
#   "train/gate/det_mean": 0.49808752091725667,
#   "train/gate/lane_mean": 0.5005398286183675,
#   "train/gate/det_sat_low": 0.0,
#   "train/gate/det_sat_high": 0.0,
#   "train/gate/lane_sat_low": 0.0,
#   "train/gate/lane_sat_high": 0.0,
#   "epoch": 10.0,
#   "val/lane_loss": 2.6942040741443636,
#   "val/lane_loss_scaled": 2.6942040741443636,
#   "val/det_loss": 2.0230245292186737,
#   "val/lane_exist_acc": 0.5578125022351742,
#   "val/lane_exist_precision": 0.5577136091887951,
#   "val/lane_exist_recall": 0.9999999940395355,
#   "val/lane_exist_f1": 0.7094369769096375,
#   "val/lane_exist_best_f1": 0.7242389932274819,
#   "val/lane_exist_best_threshold": 0.21749999476596713,
#   "val/lane_exist_pos_score_mean": 0.5061494551599026,
#   "val/lane_exist_neg_score_mean": 0.491165042668581,
#   "val/lane_point_mae": 0.41027835458517076,
#   "val/matched_lane_point_mae": 0.41027835458517076,
#   "val/matched_line_iou": 0.08314560763537884,
#   "val/num_gt_lanes": 44.6,
#   "val/num_pred_lanes": 79.975,
#   "val/num_matched_lanes": 44.6,
#   "val/false_positive_lane_slots": 35.375,
#   "val/false_negative_lane_slots": 0.0,
#   "val/lane/clrkd_style_f1": 0.02020992701873183,
#   "val/lane/clrkd_style_precision": 0.015957278828136624,
#   "val/lane/clrkd_style_recall": 0.02844091821461916,
#   "val/lane/clrkd_style_tp": 1.275,
#   "val/lane/clrkd_style_fp": 78.7,
#   "val/lane/clrkd_style_fn": 43.325,
#   "val/det/metric_map50": 0.004557456189650111,
#   "val/det/metric_precision50": 0.01728125000372529,
#   "val/det/metric_recall50": 0.1613832950592041,
#   "val/det/metric_num_gt": 85.65,
#   "val/det/metric_num_pred": 800.0,
#   "val/lane/cls": 0.08504290599375963,
#   "val/lane/cls_pos": 0.08601937200874091,
#   "val/lane/cls_neg": 0.08406644016504287,
#   "val/lane/reg": 0.18266775980591773,
#   "val/lane/xytl": 0.11399375107139349,
#   "val/lane/line_iou": 0.9168543860316276,
#   "val/lane/mask_aux": 0.4423712998628616,
#   "val/lane/smooth": 0.0010048743366496637,
#   "val/lane/distill": 0.0,
#   "val/lane/geometry_raw": 1.2145207613706588,
#   "val/lane/geometry_weighted": 2.039225533604622,
#   "val/lane/unweighted_total": 1.7419349700212479,
#   "val/lane/weighted_total": 2.6942040741443636,
#   "val/lane/total": 2.6942040741443636,
#   "val/det/obj": 0.1930849641561508,
#   "val/det/cls": 7.177189627327607e-05,
#   "val/det/bbox_l1": 0.0369981708470732,
#   "val/det/giou": 0.8224384739995003,
#   "val/det/dn": 0.0,
#   "val/det/total": 2.0230245292186737,
#   "val/det/positives": 85.65
# }
# [epoch_summary] epoch=10 phase=full_finetune train_total=5.0261 train_det=2.0527 train_lane=2.6916 val_det=2.0230 val_lane_scaled=2.6942 val_lane_unweighted=1.7419 val_lane_exist_acc=0.5578 val_lane_f1=0.7094 val_lane_best_f1=0.7242 best_thr=0.22 val_lane_precision=0.5577 val_lane_recall=1.0000 val_lane_point_mae=0.4103 val_matched_line_iou=0.0831 val_clrkd_f1=0.0202 val_map50=0.0046 best_score=-2.9641 elapsed_s=55.1 peak_mem_mb=5996
# Wrote /content/drive/MyDrive/EcoCAR/training_runs/exp04_rmt_gca_lane_matching_joint_short10.tar
# Training artifacts inside tar: best.pt, last.pt, metrics.json, config_snapshot.yaml
# [run_streaming] return_code=0
# 0

# %% [markdown]
# ## What to watch during training
#
# - `val/lane_point_mae`: lower is better. This is the main geometry signal for the current Exp2 debugging.
# - `val/lane_exist_acc`: checks whether lane existence is learned. High existence with flat MAE means geometry is still weak.
# - `val/det_loss`: lower is better for vehicle detection.
# - `train/mtl/lambda_lane_runtime` and `train/mtl/lambda_lane_epoch`: show the lane weight used in the joint loss.
# - `gate/p3_lane_mean`, `gate/p4_lane_mean`, `gate/p5_lane_mean`: only in detail/GCA runs; these show how strongly the lane branch uses task-specific features per scale.
