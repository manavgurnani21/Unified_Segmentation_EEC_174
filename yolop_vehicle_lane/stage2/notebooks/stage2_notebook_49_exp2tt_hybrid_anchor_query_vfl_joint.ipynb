# %% [markdown]
# # Stage 2 Notebook 49 - Exp2TT HybridPriorQueryHead (anchor stage 1 + K=12 query stage 2 with VFL)
#
# **The architectural breakthrough.** NB47 (K=64 query head + Hungarian + VFL) was the FIRST experiment in 10 attempts to break the cls collapse: pos-neg gap reached 0.099 (vs 0.01 historical), val_lane_f1 hit 0.246 (vs 0.0 prior), val_lane_best_f1 hit 0.344 (vs 0.05 prior). But its geometry was weak (matched_iou=0.27 vs anchor's 0.54 in NB48) because K=64 free-form queries can't cover lane space as densely as 192 geometrically-initialized priors.
#
# Meanwhile NB48 (anchor + VFL + full 70K data) hit project geometry record (matched_iou=0.544, oracle_f1=0.467) but its cls stayed at the dynamic-k matching collapse (gap=0.015).
#
# **The two heads have orthogonal strengths.** Exp2TT combines them via the existing `HybridPriorQueryHead`:
#
# - **Stage 1**: 192 anchor priors with dynamic-k matching, supervised by `stage1_aux_loss_weight=1.0`. Inherits NB48's geometry (matched_iou=0.54).
# - **Stage 2**: K=12 learned queries that cross-attend to stage 1's per-prior features AND the spatial feature map. Hungarian 1-to-1 matching + VFL. Inherits NB47's clean cls signal.
# - Inference uses stage 2's cls scores to rank, with stage 2's curves (which started from stage 1's geometry-rich feature pool) for the geometry.
#
# Reference: this is the `HybridPriorQueryHead` from NB22 (Exp2Q). NB22 failed because stage 1 had no direct supervision back then; we now have `stage1_aux_loss_weight` infrastructure (added for Exp2T) so stage 1 trains exactly like NB48's anchor head.
#
# Reference: combines DETR-style query supervision with anchor-style geometric priors, conceptually similar to Deformable DETR's reference points or DAB-DETR's anchor queries.

# %% [markdown]
# ### Run mode
#
# 1. `DEBUG_MODE = True` smoke first.
# 2. `DEBUG_MODE = False` for 20 epochs at limit=3000.
# 3. AMP keeps wall-clock ~ 30 minutes for 20 epochs at 3000 samples.
# 4. Independent of all prior NBs.

# %%
import os, sys, subprocess, textwrap
from google.colab import drive
os.environ['PYTHONUNBUFFERED'] = '1'
drive.mount('/content/drive')

REPO_ROOT = '/content/drive/MyDrive/EcoCAR/yolop_vehicle_lane'
if not os.path.isdir(REPO_ROOT):
    raise FileNotFoundError(f'Missing project root: {REPO_ROOT}')
os.chdir(REPO_ROOT)
if REPO_ROOT not in sys.path:
    sys.path.insert(0, REPO_ROOT)

subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', 'pyyaml', 'scipy', 'opencv-python-headless', 'tqdm', 'matplotlib'])
print('repo:', REPO_ROOT)

from stage2.scripts.notebook_utils import run_streaming
LOG_DIR = '/content/drive/MyDrive/EcoCAR/training_runs/notebook_logs'
os.makedirs(LOG_DIR, exist_ok=True)
# Out:
# Mounted at /content/drive
# repo: /content/drive/MyDrive/EcoCAR/yolop_vehicle_lane

# %%
from pathlib import Path
import os, sys

CONFIG = 'stage2/configs/exp44_rmt_gca_hybrid_anchor_query_vfl_joint.yaml'
LOG_FILE = os.path.join(LOG_DIR, f'{Path(CONFIG).stem}_smoke.log')
run_streaming([sys.executable, '-u', 'stage2/scripts/smoke_test_joint_models.py', CONFIG], log_path=LOG_FILE)
# Out:
# ================================================================================
# [run_streaming] command: /usr/bin/python3 -u stage2/scripts/smoke_test_joint_models.py stage2/configs/exp44_rmt_gca_hybrid_anchor_query_vfl_joint.yaml
# [run_streaming] log file: /content/drive/MyDrive/EcoCAR/training_runs/notebook_logs/exp44_rmt_gca_hybrid_anchor_query_vfl_joint_smoke.log
# ================================================================================
# OK exp44_rmt_gca_hybrid_anchor_query_vfl_joint.yaml
#   lane_shape=(1, 12, 72, 2) det_shape=(1, 4, 4)
#   lane_loss=5.3640 det_loss=3.2163 grad_cos=-0.0896 lambda_lane=0.0500
#   gate_stats={'gate/det_mean': 0.5001767873764038, 'gate/lane_mean': 0.5004153847694397, 'gate/det_sat_low': 0.0, 'gate/det_sat_high': 0.0, 'gate/lane_sat_low': 0.0, 'gate/lane_sat_high': 0.0}
# [run_streaming] return_code=0
# 0

# %%
from pathlib import Path
import os, sys

CONFIG = 'stage2/configs/exp44_rmt_gca_hybrid_anchor_query_vfl_joint.yaml'
CURVE_TAR = '/content/drive/MyDrive/EcoCAR/datasets/bdd100k_clrkd_curve.tar'
CURVE_ROOT = '/content/bdd100k_clrkd_curve'

DEBUG_MODE = False

if DEBUG_MODE:
    RUN_TAG = 'debug'
    EPOCHS = 2
    BATCH_SIZE = 4
    LIMIT_TRAIN = 512
    LIMIT_VAL = 256
    PRINT_EVERY = 5
else:
    RUN_TAG = 'short20'
    EPOCHS = 20
    BATCH_SIZE = 8
    LIMIT_TRAIN = 3000
    LIMIT_VAL = 1000
    PRINT_EVERY = 50

run_stem = Path(CONFIG).stem + '_' + RUN_TAG
WORK_DIR = f'/content/{run_stem}'
OUTPUT_TAR = f'/content/drive/MyDrive/EcoCAR/training_runs/{run_stem}.tar'
LOG_FILE = os.path.join(LOG_DIR, f'{run_stem}_train.log')

cmd = [
    sys.executable, '-u', 'stage2/scripts/train_joint_model_experiment.py',
    '--config', CONFIG,
    '--curve-tar', CURVE_TAR,
    '--curve-root', CURVE_ROOT,
    '--work-dir', WORK_DIR,
    '--output-tar', OUTPUT_TAR,
    '--epochs', str(EPOCHS),
    '--batch-size', str(BATCH_SIZE),
    '--limit-val', str(LIMIT_VAL),
    '--force-extract',
    '--print-every', str(PRINT_EVERY),
]
if LIMIT_TRAIN is not None:
    cmd.extend(['--limit-train', str(LIMIT_TRAIN)])

print('DEBUG_MODE:', DEBUG_MODE, flush=True)
print('LIMIT_TRAIN:', LIMIT_TRAIN, flush=True)
print('About to run:', ' '.join(cmd), flush=True)
print('Output tar:', OUTPUT_TAR, flush=True)
print('Visible log file:', LOG_FILE, flush=True)
run_streaming(cmd, log_path=LOG_FILE)
# Out:
# DEBUG_MODE: False
# LIMIT_TRAIN: 3000
# About to run: /usr/bin/python3 -u stage2/scripts/train_joint_model_experiment.py --config stage2/configs/exp44_rmt_gca_hybrid_anchor_query_vfl_joint.yaml --curve-tar /content/drive/MyDrive/EcoCAR/datasets/bdd100k_clrkd_curve.tar --curve-root /content/bdd100k_clrkd_curve --work-dir /content/exp44_rmt_gca_hybrid_anchor_query_vfl_joint_short20 --output-tar /content/drive/MyDrive/EcoCAR/training_runs/exp44_rmt_gca_hybrid_anchor_query_vfl_joint_short20.tar --epochs 20 --batch-size 8 --limit-val 1000 --force-extract --print-every 50 --limit-train 3000
# Output tar: /content/drive/MyDrive/EcoCAR/training_runs/exp44_rmt_gca_hybrid_anchor_query_vfl_joint_short20.tar
# Visible log file: /content/drive/MyDrive/EcoCAR/training_runs/notebook_logs/exp44_rmt_gca_hybrid_anchor_query_vfl_joint_short20_train.log
# ================================================================================
# [run_streaming] command: /usr/bin/python3 -u stage2/scripts/train_joint_model_experiment.py --config stage2/configs/exp44_rmt_gca_hybrid_anchor_query_vfl_joint.yaml --curve-tar /content/drive/MyDrive/EcoCAR/datasets/bdd100k_clrkd_curve.tar --curve-root /content/bdd100k_clrkd_curve --work-dir /content/exp44_rmt_gca_hybrid_anchor_query_vfl_joint_short20 --output-tar /content/drive/MyDrive/EcoCAR/training_runs/exp44_rmt_gca_hybrid_anchor_query_vfl_joint_short20.tar --epochs 20 --batch-size 8 --limit-val 1000 --force-extract --print-every 50 --limit-train 3000
# [run_streaming] log file: /content/drive/MyDrive/EcoCAR/training_runs/notebook_logs/exp44_rmt_gca_hybrid_anchor_query_vfl_joint_short20_train.log
# ================================================================================
# ==== Stage 2 Joint Training Preflight ====
# run_name=exp44_rmt_gca_hybrid_anchor_query_vfl_joint
# config=stage2/configs/exp44_rmt_gca_hybrid_anchor_query_vfl_joint.yaml
# curve_tar=/content/drive/MyDrive/EcoCAR/datasets/bdd100k_clrkd_curve.tar
# curve_root=/content/bdd100k_clrkd_curve
# work_dir=/content/exp44_rmt_gca_hybrid_anchor_query_vfl_joint_short20
# output_tar=/content/drive/MyDrive/EcoCAR/training_runs/exp44_rmt_gca_hybrid_anchor_query_vfl_joint_short20.tar
# backbone=exp2b_rmt_gca detection_head=detr lane_head=CLRKD-style curve head
# epochs=20 batch_size=8 print_every=50 limit_train=3000 limit_val=1000
# loss=lambda_mode:fixed lambda_lane:1.0 use_uncertainty:True
# Extracting dataset tar: /content/drive/MyDrive/EcoCAR/datasets/bdd100k_clrkd_curve.tar -> /content/bdd100k_clrkd_curve
# [run_streaming] still running; no child output yet. This usually means the first dataloader/model step is still working.
# device=cuda
# gpu=NVIDIA RTX PRO 6000 Blackwell Server Edition
# [dataset] split=train samples=3000 nonempty_det_labels=2977 label_dir=/content/bdd100k_clrkd_curve/labels/train
# [dataset] split=val samples=1000 nonempty_det_labels=996 label_dir=/content/bdd100k_clrkd_curve/labels/val
# [loader] train_batches=375 val_batches=125 workers=2
# [model] class=FusionModel params=10,352,903 trainable_initial=10,352,903
# [model] feature_channels=[128, 128, 128]
# [lane_head] max_lanes=10 num_priors=192 output_all_priors=None use_roi_gather=None roi_refine_layers=None
# [metric_sources] {
#   "rmt_metric_sources": [
#     "/content/drive/MyDrive/EcoCAR/yolop_vehicle_lane/stage2/vendor/RMT-PPAD/ultralytics/models/mtdetr/val.py",
#     "/content/drive/MyDrive/EcoCAR/yolop_vehicle_lane/stage2/vendor/RMT-PPAD/ultralytics/utils/metrics.py",
#     "/content/drive/MyDrive/EcoCAR/yolop_vehicle_lane/stage2/vendor/RMT-PPAD/ultralytics/models/rtdetr/val.py"
#   ],
#   "clrkd_metric_sources": [
#     "/content/drive/MyDrive/EcoCAR/yolop_vehicle_lane/stage2/vendor/CLRKDNet/clrkd/datasets/bdd100k_curve.py",
#     "/content/drive/MyDrive/EcoCAR/yolop_vehicle_lane/stage2/vendor/CLRKDNet/clrkd/models/utils/dynamic_assign.py"
#   ],
#   "rmt_sources_missing": [],
#   "clrkd_sources_missing": []
# }
# [lr_scheduler] cosine kind=cosine warmup=2 epochs=20 min_lr_factor=0.05
# [amp] kind=bfloat16 enabled=True dtype=torch.bfloat16
# epoch=1 phase=head_warmup batches=375 lane_matching=True geom_scale=1.000
# epoch=1 waiting_for_first_batch...
# epoch=1 step=1/375 total=5.9335 det=4.4874 lane=7.3796 lambda_lane=1.0000 cls=0.3270 reg=0.2547 iou=0.9960 grad_cos=nan speed=0.24step/s eta_min=25.6
# epoch=1 step=50/375 total=4.5441 det=2.4314 lane=6.7300 lambda_lane=1.0000 cls=0.3302 reg=0.2209 iou=0.9265 grad_cos=nan speed=4.88step/s eta_min=1.1
# epoch=1 step=100/375 total=4.3356 det=2.2094 lane=6.6005 lambda_lane=1.0000 cls=0.3492 reg=0.1787 iou=0.9358 grad_cos=nan speed=5.85step/s eta_min=0.8
# epoch=1 step=150/375 total=4.6258 det=2.3150 lane=7.1645 lambda_lane=1.0000 cls=0.3768 reg=0.2670 iou=0.9779 grad_cos=nan speed=6.32step/s eta_min=0.6
# epoch=1 step=200/375 total=4.5084 det=2.3688 lane=6.9434 lambda_lane=1.0000 cls=0.4165 reg=0.1958 iou=0.9009 grad_cos=nan speed=6.61step/s eta_min=0.4
# epoch=1 step=250/375 total=4.1527 det=2.2874 lane=6.3483 lambda_lane=1.0000 cls=0.3604 reg=0.1631 iou=0.9071 grad_cos=nan speed=6.80step/s eta_min=0.3
# epoch=1 step=300/375 total=3.9954 det=2.1199 lane=6.2477 lambda_lane=1.0000 cls=0.3542 reg=0.1819 iou=0.8981 grad_cos=nan speed=6.93step/s eta_min=0.2
# epoch=1 step=350/375 total=4.0626 det=2.1161 lane=6.4583 lambda_lane=1.0000 cls=0.3604 reg=0.1631 iou=0.8887 grad_cos=nan speed=7.05step/s eta_min=0.1
# epoch=1 validation_start batches=40
# epoch=1 validation_done
# {
#   "train/total": 4.310231577555339,
#   "train/phase_id": 1.0,
#   "train/mtl/lambda_lane_epoch": 1.0,
#   "train/lane/geometry_scale": 1.0,
#   "train/lane/cls": 0.3508358271916707,
#   "train/lane/cls_pos": 0.4708048851490021,
#   "train/lane/cls_neg": 0.24278138558069864,
#   "train/lane/reg": 0.19001522521177927,
#   "train/lane/xytl": 0.1864577190876007,
#   "train/lane/line_iou": 0.9205066231091817,
#   "train/lane/mask_aux": 0.5903117877642313,
#   "train/lane/smooth": 0.0041591112477084,
#   "train/lane/distill": 0.0,
#   "train/lane/iou_aux": 0.0,
#   "train/lane/geometry_raw": 1.3011386763254802,
#   "train/lane/geometry_weighted": 2.106531021118164,
#   "train/lane/unweighted_total": 2.242286288579305,
#   "train/lane/weighted_total": 4.4510219821929935,
#   "train/lane/total": 4.4510219821929935,
#   "train/lane/stage1_aux_total": 2.1090990673700967,
#   "train/lane/stage1_aux_cls": 0.053183958386381465,
#   "train/lane/stage1_aux_iou": 0.7968932104110718,
#   "train/lane/stage1_aux_reg": 0.17584577278296154,
#   "train/det/obj": 0.20120772171020507,
#   "train/det/cls": 0.005461404207007339,
#   "train/det/bbox_l1": 0.06057280809680621,
#   "train/det/giou": 0.9005255864461263,
#   "train/det/dn": 0.0,
#   "train/det/total": 2.310584341049194,
#   "train/det/positives": 86.456,
#   "train/mtl/log_var_0": 0.034312095247170264,
#   "train/mtl/weighted_0": 1.1352255266507467,
#   "train/mtl/log_var_1": 0.03987362100529329,
#   "train/mtl/weighted_1": 3.1750036017100016,
#   "train/mtl/total": 4.310229118982951,
#   "train/mtl/gate_reg": 0.002555094401041667,
#   "train/gate/det_mean": 0.49999479166666666,
#   "train/gate/lane_mean": 0.5,
#   "train/gate/det_sat_low": 0.0,
#   "train/gate/det_sat_high": 0.0,
#   "train/gate/lane_sat_low": 0.0,
#   "train/gate/lane_sat_high": 0.0,
#   "epoch": 1.0,
#   "val/lane_loss": 6.434625732898712,
#   "val/lane_loss_scaled": 6.434625732898712,
#   "val/det_loss": 2.138087052106857,
#   "val/lane_exist_acc": 0.46458332911133765,
#   "val/lane_exist_precision": 0.46458332911133765,
#   "val/lane_exist_recall": 0.9999999940395355,
#   "val/lane_exist_f1": 0.6289202734827996,
#   "val/lane_exist_best_f1": 0.659533841907978,
#   "val/lane_exist_best_threshold": 0.44249999709427357,
#   "val/lane_exist_pos_score_mean": 0.6008785709738731,
#   "val/lane_exist_neg_score_mean": 0.5495030745863915,
#   "val/lane_point_mae": 0.3986699551343918,
#   "val/matched_lane_point_mae": 0.3986699551343918,
#   "val/matched_line_iou": 0.09172215145081282,
#   "val/num_gt_lanes": 44.6,
#   "val/num_pred_lanes": 96.0,
#   "val/num_matched_lanes": 44.6,
#   "val/false_positive_lane_slots": 51.4,
#   "val/false_negative_lane_slots": 0.0,
#   "val/lane/clrkd_style_f1": 0.024637485458515584,
#   "val/lane/clrkd_style_precision": 0.01822916683740914,
#   "val/lane/clrkd_style_recall": 0.03932754886336624,
#   "val/lane/clrkd_style_tp": 1.75,
#   "val/lane/clrkd_style_fp": 94.25,
#   "val/lane/clrkd_style_fn": 42.85,
#   "val/lane/decoded_f1": 0.01700785863213241,
#   "val/lane/decoded_precision": 0.01667774859815836,
#   "val/lane/decoded_recall": 0.017777575459331275,
#   "val/lane/decoded_tp": 0.8,
#   "val/lane/decoded_fp": 47.175,
#   "val/lane/decoded_fn": 43.8,
#   "val/lane/decoded_pred_count": 47.975,
#   "val/lane/decoded_avg_score": 0.648573188483715,
#   "val/lane/decoded_top_k_used": 6.0,
#   "val/lane/decoded_oracle_f1": 0.03736874815076589,
#   "val/lane/decoded_oracle_precision": 0.036491578351706265,
#   "val/lane/decoded_oracle_recall": 0.03932754886336624,
#   "val/lane/decoded_oracle_tp": 1.75,
#   "val/lane/decoded_oracle_fp": 46.225,
#   "val/lane/decoded_oracle_fn": 42.85,
#   "val/lane/decoded_oracle_pred_count": 47.975,
#   "val/lane/decoded_oracle_avg_score": 0.10062390891835093,
#   "val/lane/decoded_oracle_top_k_used": 6.0,
#   "val/det/metric_map50": 0.003110932814888656,
#   "val/det/metric_precision50": 0.013343750021886081,
#   "val/det/metric_recall50": 0.12591828349977732,
#   "val/det/metric_num_gt": 85.65,
#   "val/det/metric_num_pred": 800.0,
#   "val/lane/cls": 0.3568107157945633,
#   "val/lane/cls_pos": 0.5219008177518845,
#   "val/lane/cls_neg": 0.21134066991508008,
#   "val/lane/reg": 0.17701972760260104,
#   "val/lane/xytl": 0.155454620718956,
#   "val/lane/line_iou": 0.9082778304815292,
#   "val/lane/mask_aux": 0.5631598442792892,
#   "val/lane/smooth": 0.0027803017292171717,
#   "val/lane/distill": 0.0,
#   "val/lane/iou_aux": 0.0,
#   "val/lane/geometry_raw": 1.2435324877500533,
#   "val/lane/geometry_weighted": 2.060209262371063,
#   "val/lane/unweighted_total": 2.1635030448436736,
#   "val/lane/weighted_total": 4.4074227690696715,
#   "val/lane/total": 4.4074227690696715,
#   "val/lane/stage1_aux_total": 2.0272029846906663,
#   "val/lane/stage1_aux_cls": 0.05305101377889514,
#   "val/lane/stage1_aux_iou": 0.7643896222114563,
#   "val/lane/stage1_aux_reg": 0.16747205890715122,
#   "val/det/obj": 0.19530573561787606,
#   "val/det/cls": 0.0011198854917893186,
#   "val/det/bbox_l1": 0.04478728026151657,
#   "val/det/giou": 0.8588625192642212,
#   "val/det/dn": 0.0,
#   "val/det/total": 2.138087052106857,
#   "val/det/positives": 85.65
# }
# [epoch_summary] epoch=1 phase=head_warmup train_total=4.3102 train_det=2.3106 train_lane=4.4510 val_det=2.1381 val_lane_scaled=6.4346 val_lane_unweighted=2.1635 val_lane_cls=0.3568 val_lane_reg=0.1770 val_lane_line_iou_loss=0.9083 val_lane_mask=0.5632 val_lane_exist_acc=0.4646 val_lane_f1=0.6289 val_lane_best_f1=0.6595 best_thr=0.44 val_lane_precision=0.4646 val_lane_recall=1.0000 val_lane_point_mae=0.3987 val_matched_line_iou=0.0917 pred_lanes=96.0 gt_lanes=44.6 matched_lanes=44.6 fp_slots=51.4 fn_slots=0.0 pos_score=0.6009 neg_score=0.5495 val_clrkd_f1=0.0246 val_decoded_f1=0.0170 val_decoded_p=0.0167 val_decoded_r=0.0178 decoded_pred=48.0 val_oracle_f1=0.0374 val_oracle_p=0.0365 val_oracle_r=0.0393 val_map50=0.0031 best_score=-8.5727 elapsed_s=61.7 peak_mem_mb=10402
# [lr_scheduler] after_epoch=1 param_group_lrs=[2e-05, 0.0004]
# epoch=2 phase=head_warmup batches=375 lane_matching=True geom_scale=1.000
# epoch=2 waiting_for_first_batch...
# epoch=2 step=1/375 total=4.3746 det=2.5243 lane=6.7550 lambda_lane=1.0000 cls=0.3912 reg=0.1919 iou=0.9064 grad_cos=nan speed=1.86step/s eta_min=3.4
# epoch=2 step=50/375 total=4.3255 det=2.4845 lane=6.8149 lambda_lane=1.0000 cls=0.3570 reg=0.1960 iou=0.9491 grad_cos=nan speed=7.15step/s eta_min=0.8
# epoch=2 step=100/375 total=4.0046 det=2.1266 lane=6.5902 lambda_lane=1.0000 cls=0.3714 reg=0.1931 iou=0.9205 grad_cos=nan speed=7.48step/s eta_min=0.6
# epoch=2 step=150/375 total=4.0598 det=2.3484 lane=6.6100 lambda_lane=1.0000 cls=0.3692 reg=0.1750 iou=0.9336 grad_cos=nan speed=7.38step/s eta_min=0.5
# epoch=2 step=200/375 total=3.8982 det=2.1370 lane=6.5665 lambda_lane=1.0000 cls=0.4001 reg=0.1893 iou=0.8998 grad_cos=nan speed=7.45step/s eta_min=0.4
# epoch=2 step=250/375 total=3.6503 det=2.1224 lane=6.1058 lambda_lane=1.0000 cls=0.3565 reg=0.1746 iou=0.8907 grad_cos=nan speed=7.49step/s eta_min=0.3
# epoch=2 step=300/375 total=3.7918 det=2.2413 lane=6.4298 lambda_lane=1.0000 cls=0.3544 reg=0.1854 iou=0.9392 grad_cos=nan speed=7.53step/s eta_min=0.2
# epoch=2 step=350/375 total=3.6935 det=2.2227 lane=6.3157 lambda_lane=1.0000 cls=0.3719 reg=0.1969 iou=0.9104 grad_cos=nan speed=7.53step/s eta_min=0.1
# epoch=2 validation_start batches=40
# epoch=2 validation_done
# {
#   "train/total": 3.8844212074279785,
#   "train/phase_id": 2.0,
#   "train/mtl/lambda_lane_epoch": 1.0,
#   "train/lane/geometry_scale": 1.0,
#   "train/lane/cls": 0.35203192579746245,
#   "train/lane/cls_pos": 0.4835450851122538,
#   "train/lane/cls_neg": 0.2351429158647855,
#   "train/lane/reg": 0.18349320010344186,
#   "train/lane/xytl": 0.14971569746732713,
#   "train/lane/line_iou": 0.9203563877741496,
#   "train/lane/mask_aux": 0.5558786549568177,
#   "train/lane/smooth": 0.002814583403368791,
#   "train/lane/distill": 0.0,
#   "train/lane/iou_aux": 0.0,
#   "train/lane/geometry_raw": 1.256379866917928,
#   "train/lane/geometry_weighted": 2.090988486925761,
#   "train/lane/unweighted_total": 2.164290449778239,
#   "train/lane/weighted_total": 4.407026780446371,
#   "train/lane/total": 4.407026780446371,
#   "train/lane/stage1_aux_total": 2.009331294377645,
#   "train/lane/stage1_aux_cls": 0.05103462965786457,
#   "train/lane/stage1_aux_iou": 0.7634305650393168,
#   "train/lane/stage1_aux_reg": 0.16354305199782054,
#   "train/det/obj": 0.19552152065436046,
#   "train/det/cls": 0.0013190587772987782,
#   "train/det/bbox_l1": 0.05080215535561244,
#   "train/det/giou": 0.8821175616582234,
#   "train/det/dn": 0.0,
#   "train/det/total": 2.2150864788691202,
#   "train/det/positives": 86.456,
#   "train/mtl/log_var_0": 0.13093116426467896,
#   "train/mtl/weighted_0": 1.038170584042867,
#   "train/mtl/log_var_1": 0.1471165378491084,
#   "train/mtl/weighted_1": 2.8462480773925782,
#   "train/mtl/total": 3.8844186617533367,
#   "train/mtl/gate_reg": 0.0025564371744791667,
#   "train/gate/det_mean": 0.5,
#   "train/gate/lane_mean": 0.5,
#   "train/gate/det_sat_low": 0.0,
#   "train/gate/det_sat_high": 0.0,
#   "train/gate/lane_sat_low": 0.0,
#   "train/gate/lane_sat_high": 0.0,
#   "epoch": 2.0,
#   "val/lane_loss": 6.448397600650788,
#   "val/lane_loss_scaled": 6.448397600650788,
#   "val/det_loss": 2.12180295586586,
#   "val/lane_exist_acc": 0.46458332911133765,
#   "val/lane_exist_precision": 0.46458332911133765,
#   "val/lane_exist_recall": 0.9999999940395355,
#   "val/lane_exist_f1": 0.6289202734827996,
#   "val/lane_exist_best_f1": 0.6496079742908478,
#   "val/lane_exist_best_threshold": 0.3312500029802322,
#   "val/lane_exist_pos_score_mean": 0.619573013484478,
#   "val/lane_exist_neg_score_mean": 0.5881743282079697,
#   "val/lane_point_mae": 0.39150369688868525,
#   "val/matched_lane_point_mae": 0.39150369688868525,
#   "val/matched_line_iou": 0.08343505254015326,
#   "val/num_gt_lanes": 44.6,
#   "val/num_pred_lanes": 96.0,
#   "val/num_matched_lanes": 44.6,
#   "val/false_positive_lane_slots": 51.4,
#   "val/false_negative_lane_slots": 0.0,
#   "val/lane/clrkd_style_f1": 0.023838024097494782,
#   "val/lane/clrkd_style_precision": 0.017968750186264516,
#   "val/lane/clrkd_style_recall": 0.03618837730027735,
#   "val/lane/clrkd_style_tp": 1.725,
#   "val/lane/clrkd_style_fp": 94.275,
#   "val/lane/clrkd_style_fn": 42.875,
#   "val/lane/decoded_f1": 0.0185720756649971,
#   "val/lane/decoded_precision": 0.018824554793536664,
#   "val/lane/decoded_recall": 0.018648513546213507,
#   "val/lane/decoded_tp": 0.875,
#   "val/lane/decoded_fp": 45.575,
#   "val/lane/decoded_fn": 43.725,
#   "val/lane/decoded_pred_count": 46.45,
#   "val/lane/decoded_avg_score": 0.6679982721805573,
#   "val/lane/decoded_top_k_used": 6.0,
#   "val/lane/decoded_oracle_f1": 0.03613372496329248,
#   "val/lane/decoded_oracle_precision": 0.03666394213214517,
#   "val/lane/decoded_oracle_recall": 0.03618837730027735,
#   "val/lane/decoded_oracle_tp": 1.725,
#   "val/lane/decoded_oracle_fp": 45.275,
#   "val/lane/decoded_oracle_fn": 42.875,
#   "val/lane/decoded_oracle_pred_count": 47.0,
#   "val/lane/decoded_oracle_avg_score": 0.0933074199128896,
#   "val/lane/decoded_oracle_top_k_used": 6.0,
#   "val/det/metric_map50": 0.003957793247536756,
#   "val/det/metric_precision50": 0.014239849511068315,
#   "val/det/metric_recall50": 0.13347806110978128,
#   "val/det/metric_num_gt": 85.65,
#   "val/det/metric_num_pred": 788.225,
#   "val/lane/cls": 0.36444436833262445,
#   "val/lane/cls_pos": 0.4885154336690903,
#   "val/lane/cls_neg": 0.25469979718327523,
#   "val/lane/reg": 0.17330780662596226,
#   "val/lane/xytl": 0.14164990913122893,
#   "val/lane/line_iou": 0.9165649354457855,
#   "val/lane/mask_aux": 0.5594998121261596,
#   "val/lane/smooth": 0.002343098499113694,
#   "val/lane/distill": 0.0,
#   "val/lane/iou_aux": 0.0,
#   "val/lane/geometry_raw": 1.233865749835968,
#   "val/lane/geometry_weighted": 2.0695463955402373,
#   "val/lane/unweighted_total": 2.157809942960739,
#   "val/lane/weighted_total": 4.451268029212952,
#   "val/lane/total": 4.451268029212952,
#   "val/lane/stage1_aux_total": 1.9971296221017838,
#   "val/lane/stage1_aux_cls": 0.05246349619701505,
#   "val/lane/stage1_aux_iou": 0.7604485213756561,
#   "val/lane/stage1_aux_reg": 0.15398527309298515,
#   "val/det/obj": 0.19302444979548455,
#   "val/det/cls": 0.0008490144115057774,
#   "val/det/bbox_l1": 0.0463061491958797,
#   "val/det/giou": 0.8481993705034256,
#   "val/det/dn": 0.0,
#   "val/det/total": 2.12180295586586,
#   "val/det/positives": 85.65
# }
# [epoch_summary] epoch=2 phase=head_warmup train_total=3.8844 train_det=2.2151 train_lane=4.4070 val_det=2.1218 val_lane_scaled=6.4484 val_lane_unweighted=2.1578 val_lane_cls=0.3644 val_lane_reg=0.1733 val_lane_line_iou_loss=0.9166 val_lane_mask=0.5595 val_lane_exist_acc=0.4646 val_lane_f1=0.6289 val_lane_best_f1=0.6496 best_thr=0.33 val_lane_precision=0.4646 val_lane_recall=1.0000 val_lane_point_mae=0.3915 val_matched_line_iou=0.0834 pred_lanes=96.0 gt_lanes=44.6 matched_lanes=44.6 fp_slots=51.4 fn_slots=0.0 pos_score=0.6196 neg_score=0.5882 val_clrkd_f1=0.0238 val_decoded_f1=0.0186 val_decoded_p=0.0188 val_decoded_r=0.0186 decoded_pred=46.5 val_oracle_f1=0.0361 val_oracle_p=0.0367 val_oracle_r=0.0362 val_map50=0.0040 best_score=-8.5702 elapsed_s=56.8 peak_mem_mb=10402
# [lr_scheduler] after_epoch=2 param_group_lrs=[1.9870432382325864e-05, 0.0003974086476465173]
# epoch=3 phase=full_finetune batches=375 lane_matching=True geom_scale=1.000
# epoch=3 waiting_for_first_batch...
# epoch=3 step=1/375 total=3.8767 det=2.4069 lane=6.6332 lambda_lane=1.0000 cls=0.3737 reg=0.1599 iou=0.9260 grad_cos=-0.1138 speed=0.11step/s eta_min=59.4
# epoch=3 step=50/375 total=3.6714 det=2.0627 lane=6.5807 lambda_lane=1.0000 cls=0.3685 reg=0.1687 iou=0.9139 grad_cos=0.0584 speed=3.15step/s eta_min=1.7
# epoch=3 step=100/375 total=3.5332 det=2.1009 lane=6.2910 lambda_lane=1.0000 cls=0.3561 reg=0.1773 iou=0.8688 grad_cos=-0.0056 speed=4.53step/s eta_min=1.0
# epoch=3 step=150/375 total=3.4281 det=1.9590 lane=6.2618 lambda_lane=1.0000 cls=0.3504 reg=0.1779 iou=0.8790 grad_cos=-0.0100 speed=5.24step/s eta_min=0.7
# epoch=3 step=200/375 total=3.4801 det=2.2138 lane=6.2280 lambda_lane=1.0000 cls=0.3568 reg=0.1622 iou=0.9147 grad_cos=0.0215 speed=5.70step/s eta_min=0.5
# epoch=3 step=250/375 total=3.5180 det=2.1758 lane=6.4633 lambda_lane=1.0000 cls=0.3759 reg=0.1758 iou=0.9150 grad_cos=-0.1502 speed=6.00step/s eta_min=0.3
# epoch=3 step=300/375 total=3.3237 det=2.2581 lane=5.9406 lambda_lane=1.0000 cls=0.2968 reg=0.1616 iou=0.9341 grad_cos=0.0701 speed=6.23step/s eta_min=0.2
# epoch=3 step=350/375 total=3.3367 det=1.9935 lane=6.3406 lambda_lane=1.0000 cls=0.3656 reg=0.1616 iou=0.9139 grad_cos=-0.0459 speed=6.36step/s eta_min=0.1
# epoch=3 grad_cosine_epoch_mean=-0.0219 probes=8
# epoch=3 validation_start batches=40
# epoch=3 validation_done
# {
#   "train/total": 3.5340665397644044,
#   "train/grad_cosine": -0.00046810691927870116,
#   "train/phase_id": 3.0,
#   "train/mtl/lambda_lane_epoch": 1.0,
#   "train/lane/geometry_scale": 1.0,
#   "train/lane/cls": 0.3684280649026235,
#   "train/lane/cls_pos": 0.4933835135300954,
#   "train/lane/cls_neg": 0.26033847137292226,
#   "train/lane/reg": 0.17148273817698162,
#   "train/lane/xytl": 0.1385555809934934,
#   "train/lane/line_iou": 0.9117661315600077,
#   "train/lane/mask_aux": 0.5479111798604329,
#   "train/lane/smooth": 0.0023196741801997027,
#   "train/lane/distill": 0.0,
#   "train/lane/iou_aux": 0.0,
#   "train/lane/geometry_raw": 1.2241241229375204,
#   "train/lane/geometry_weighted": 2.0571386655171713,
#   "train/lane/unweighted_total": 2.14046337445577,
#   "train/lane/weighted_total": 4.447190185546875,
#   "train/lane/total": 4.447190185546875,
#   "train/lane/stage1_aux_total": 2.0003013588587444,
#   "train/lane/stage1_aux_cls": 0.05204453201095263,
#   "train/lane/stage1_aux_iou": 0.7636927501360575,
#   "train/lane/stage1_aux_reg": 0.15299734795093536,
#   "train/det/obj": 0.19613943847020468,
#   "train/det/cls": 0.0006693431553430855,
#   "train/det/bbox_l1": 0.04229700669646263,
#   "train/det/giou": 0.8487262063026428,
#   "train/det/dn": 0.0,
#   "train/det/total": 2.10574622631073,
#   "train/det/positives": 86.456,
#   "train/mtl/log_var_0": 0.24075524803002676,
#   "train/mtl/weighted_0": 0.9486062890688578,
#   "train/mtl/log_var_1": 0.277124725818634,
#   "train/mtl/weighted_1": 2.585457689921061,
#   "train/mtl/total": 3.5340639870961508,
#   "train/mtl/gate_reg": 0.0025347493489583334,
#   "train/gate/det_mean": 0.5,
#   "train/gate/lane_mean": 0.5,
#   "train/gate/det_sat_low": 0.0,
#   "train/gate/det_sat_high": 0.0,
#   "train/gate/lane_sat_low": 0.0,
#   "train/gate/lane_sat_high": 0.0,
#   "epoch": 3.0,
#   "train/grad_cosine_epoch_mean": -0.021942511841189116,
#   "train/grad_cosine_probe_count": 8.0,
#   "val/lane_loss": 6.359123730659485,
#   "val/lane_loss_scaled": 6.359123730659485,
#   "val/det_loss": 2.087528222799301,
#   "val/lane_exist_acc": 0.46458332911133765,
#   "val/lane_exist_precision": 0.46458332911133765,
#   "val/lane_exist_recall": 0.9999999940395355,
#   "val/lane_exist_f1": 0.6289202734827996,
#   "val/lane_exist_best_f1": 0.6425468623638153,
#   "val/lane_exist_best_threshold": 0.3512500050477684,
#   "val/lane_exist_pos_score_mean": 0.6008880957961082,
#   "val/lane_exist_neg_score_mean": 0.5904531955718995,
#   "val/lane_point_mae": 0.38444041833281517,
#   "val/matched_lane_point_mae": 0.38444041833281517,
#   "val/matched_line_iou": 0.08912220234051346,
#   "val/num_gt_lanes": 44.6,
#   "val/num_pred_lanes": 96.0,
#   "val/num_matched_lanes": 44.6,
#   "val/false_positive_lane_slots": 51.4,
#   "val/false_negative_lane_slots": 0.0,
#   "val/lane/clrkd_style_f1": 0.02077512782998383,
#   "val/lane/clrkd_style_precision": 0.015364583465270698,
#   "val/lane/clrkd_style_recall": 0.03314906074665487,
#   "val/lane/clrkd_style_tp": 1.475,
#   "val/lane/clrkd_style_fp": 94.525,
#   "val/lane/clrkd_style_fn": 43.125,
#   "val/lane/decoded_f1": 0.014352679997682572,
#   "val/lane/decoded_precision": 0.01406250037252903,
#   "val/lane/decoded_recall": 0.015027371793985366,
#   "val/lane/decoded_tp": 0.675,
#   "val/lane/decoded_fp": 47.325,
#   "val/lane/decoded_fn": 43.925,
#   "val/lane/decoded_pred_count": 48.0,
#   "val/lane/decoded_avg_score": 0.6276910543441773,
#   "val/lane/decoded_top_k_used": 6.0,
#   "val/lane/decoded_oracle_f1": 0.03152676774188876,
#   "val/lane/decoded_oracle_precision": 0.030773493042215706,
#   "val/lane/decoded_oracle_recall": 0.03314906074665487,
#   "val/lane/decoded_oracle_tp": 1.475,
#   "val/lane/decoded_oracle_fp": 46.35,
#   "val/lane/decoded_oracle_fn": 43.125,
#   "val/lane/decoded_oracle_pred_count": 47.825,
#   "val/lane/decoded_oracle_avg_score": 0.09186365967616439,
#   "val/lane/decoded_oracle_top_k_used": 6.0,
#   "val/det/metric_map50": 0.0034416668771882542,
#   "val/det/metric_precision50": 0.014531250053551048,
#   "val/det/metric_recall50": 0.13853145372122527,
#   "val/det/metric_num_gt": 85.65,
#   "val/det/metric_num_pred": 800.0,
#   "val/lane/cls": 0.3679254412651062,
#   "val/lane/cls_pos": 0.5125246733427048,
#   "val/lane/cls_neg": 0.24157712124288083,
#   "val/lane/reg": 0.16991630829870702,
#   "val/lane/xytl": 0.13629294876009226,
#   "val/lane/line_iou": 0.9108777910470962,
#   "val/lane/mask_aux": 0.5481359735131264,
#   "val/lane/smooth": 0.002044621849199757,
#   "val/lane/distill": 0.0,
#   "val/lane/iou_aux": 0.0,
#   "val/lane/geometry_raw": 1.219131651520729,
#   "val/lane/geometry_weighted": 2.0530159771442413,
#   "val/lane/unweighted_total": 2.1351930797100067,
#   "val/lane/weighted_total": 4.440779185295105,
#   "val/lane/total": 4.440779185295105,
#   "val/lane/stage1_aux_total": 1.918344536423683,
#   "val/lane/stage1_aux_cls": 0.051447147876024245,
#   "val/lane/stage1_aux_iou": 0.7259088397026062,
#   "val/lane/stage1_aux_reg": 0.15072968564927577,
#   "val/det/obj": 0.19371782578527927,
#   "val/det/cls": 0.0006150768305815291,
#   "val/det/bbox_l1": 0.041718023084104064,
#   "val/det/giou": 0.8423025980591774,
#   "val/det/dn": 0.0,
#   "val/det/total": 2.087528222799301,
#   "val/det/positives": 85.65
# }
# [epoch_summary] epoch=3 phase=full_finetune train_total=3.5341 train_det=2.1057 train_lane=4.4472 val_det=2.0875 val_lane_scaled=6.3591 val_lane_unweighted=2.1352 val_lane_cls=0.3679 val_lane_reg=0.1699 val_lane_line_iou_loss=0.9109 val_lane_mask=0.5481 val_lane_exist_acc=0.4646 val_lane_f1=0.6289 val_lane_best_f1=0.6425 best_thr=0.35 val_lane_precision=0.4646 val_lane_recall=1.0000 val_lane_point_mae=0.3844 val_matched_line_iou=0.0891 pred_lanes=96.0 gt_lanes=44.6 matched_lanes=44.6 fp_slots=51.4 fn_slots=0.0 pos_score=0.6009 neg_score=0.5905 val_clrkd_f1=0.0208 val_decoded_f1=0.0144 val_decoded_p=0.0141 val_decoded_r=0.0150 decoded_pred=48.0 val_oracle_f1=0.0315 val_oracle_p=0.0308 val_oracle_r=0.0331 val_map50=0.0034 best_score=-8.4467 elapsed_s=65.6 peak_mem_mb=10402
# [lr_scheduler] after_epoch=3 param_group_lrs=[1.948526379615603e-05, 0.00038970527592312057]
# epoch=4 phase=full_finetune batches=375 lane_matching=True geom_scale=1.000
# epoch=4 waiting_for_first_batch...
# epoch=4 step=1/375 total=3.3715 det=2.1145 lane=6.3563 lambda_lane=1.0000 cls=0.3579 reg=0.1627 iou=0.9254 grad_cos=-0.0171 speed=2.08step/s eta_min=3.0
# epoch=4 step=50/375 total=3.0667 det=1.9524 lane=5.7437 lambda_lane=1.0000 cls=0.3029 reg=0.1462 iou=0.8983 grad_cos=0.0252 speed=7.29step/s eta_min=0.7
# epoch=4 step=100/375 total=3.3447 det=2.2552 lane=6.3006 lambda_lane=1.0000 cls=0.3926 reg=0.1562 iou=0.8718 grad_cos=0.0345 speed=7.26step/s eta_min=0.6
# epoch=4 step=150/375 total=3.3375 det=2.0856 lane=6.5448 lambda_lane=1.0000 cls=0.3642 reg=0.1798 iou=0.9514 grad_cos=0.0949 speed=7.26step/s eta_min=0.5
# epoch=4 step=200/375 total=3.1616 det=1.9842 lane=6.2138 lambda_lane=1.0000 cls=0.3618 reg=0.1647 iou=0.9171 grad_cos=-0.0579 speed=7.37step/s eta_min=0.4
# epoch=4 step=250/375 total=3.2078 det=2.1297 lane=6.2766 lambda_lane=1.0000 cls=0.3389 reg=0.1809 iou=0.9208 grad_cos=-0.1102 speed=7.40step/s eta_min=0.3
# epoch=4 step=300/375 total=3.2389 det=2.1794 lane=6.3992 lambda_lane=1.0000 cls=0.3700 reg=0.1747 iou=0.9238 grad_cos=0.0175 speed=7.36step/s eta_min=0.2
# epoch=4 step=350/375 total=3.0304 det=2.0546 lane=5.9654 lambda_lane=1.0000 cls=0.3721 reg=0.1621 iou=0.8842 grad_cos=0.0889 speed=7.41step/s eta_min=0.1
# epoch=4 grad_cosine_epoch_mean=0.0095 probes=8
# epoch=4 validation_start batches=40
# epoch=4 validation_done
# {
#   "train/total": 3.2336183598836263,
#   "train/grad_cosine": 0.00020199015239874522,
#   "train/phase_id": 4.0,
#   "train/mtl/lambda_lane_epoch": 1.0,
#   "train/lane/geometry_scale": 1.0,
#   "train/lane/cls": 0.36662980961799624,
#   "train/lane/cls_pos": 0.5118651180267334,
#   "train/lane/cls_neg": 0.24139994291464487,
#   "train/lane/reg": 0.16941356201966604,
#   "train/lane/xytl": 0.134383675634861,
#   "train/lane/line_iou": 0.9062154870033264,
#   "train/lane/mask_aux": 0.5435128418604532,
#   "train/lane/smooth": 0.00223743578667442,
#   "train/lane/distill": 0.0,
#   "train/lane/iou_aux": 0.0,
#   "train/lane/geometry_raw": 1.2122501605351765,
#   "train/lane/geometry_weighted": 2.0427158708572386,
#   "train/lane/unweighted_total": 2.122392804781596,
#   "train/lane/weighted_total": 4.419377747853597,
#   "train/lane/total": 4.419377747853597,
#   "train/lane/stage1_aux_total": 1.8679268509546916,
#   "train/lane/stage1_aux_cls": 0.05148215700189272,
#   "train/lane/stage1_aux_iou": 0.7016834465662638,
#   "train/lane/stage1_aux_reg": 0.14942741245031357,
#   "train/det/obj": 0.19526619068781534,
#   "train/det/cls": 0.0006172637002697835,
#   "train/det/bbox_l1": 0.042028918569286665,
#   "train/det/giou": 0.8439140995343526,
#   "train/det/dn": 0.0,
#   "train/det/total": 2.0938562444051105,
#   "train/det/positives": 86.456,
#   "train/mtl/log_var_0": 0.33309553305308026,
#   "train/mtl/weighted_0": 0.9172023928960165,
#   "train/mtl/log_var_1": 0.3953066110610962,
#   "train/mtl/weighted_1": 2.3164134318033853,
#   "train/mtl/total": 3.2336158243815105,
#   "train/mtl/gate_reg": 0.002521443684895833,
#   "train/gate/det_mean": 0.5,
#   "train/gate/lane_mean": 0.5,
#   "train/gate/det_sat_low": 0.0,
#   "train/gate/det_sat_high": 0.0,
#   "train/gate/lane_sat_low": 0.0,
#   "train/gate/lane_sat_high": 0.0,
#   "epoch": 4.0,
#   "train/grad_cosine_epoch_mean": 0.009468288393691182,
#   "train/grad_cosine_probe_count": 8.0,
#   "val/lane_loss": 6.3267329931259155,
#   "val/lane_loss_scaled": 6.3267329931259155,
#   "val/det_loss": 2.086342641711235,
#   "val/lane_exist_acc": 0.46458332911133765,
#   "val/lane_exist_precision": 0.46458332911133765,
#   "val/lane_exist_recall": 0.9999999940395355,
#   "val/lane_exist_f1": 0.6289202734827996,
#   "val/lane_exist_best_f1": 0.6350743636488915,
#   "val/lane_exist_best_threshold": 0.23750000223517417,
#   "val/lane_exist_pos_score_mean": 0.5819781944155693,
#   "val/lane_exist_neg_score_mean": 0.5746266022324562,
#   "val/lane_point_mae": 0.3833827838301659,
#   "val/matched_lane_point_mae": 0.3833827838301659,
#   "val/matched_line_iou": 0.10148230167105794,
#   "val/num_gt_lanes": 44.6,
#   "val/num_pred_lanes": 96.0,
#   "val/num_matched_lanes": 44.6,
#   "val/false_positive_lane_slots": 51.4,
#   "val/false_negative_lane_slots": 0.0,
#   "val/lane/clrkd_style_f1": 0.029154026042670013,
#   "val/lane/clrkd_style_precision": 0.021614583721384407,
#   "val/lane/clrkd_style_recall": 0.04572220593690872,
#   "val/lane/clrkd_style_tp": 2.075,
#   "val/lane/clrkd_style_fp": 93.925,
#   "val/lane/clrkd_style_fn": 42.525,
#   "val/lane/decoded_f1": 0.028922184882685543,
#   "val/lane/decoded_precision": 0.028147163754329085,
#   "val/lane/decoded_recall": 0.03019469860009849,
#   "val/lane/decoded_tp": 1.35,
#   "val/lane/decoded_fp": 46.625,
#   "val/lane/decoded_fn": 43.25,
#   "val/lane/decoded_pred_count": 47.975,
#   "val/lane/decoded_avg_score": 0.6059707552194595,
#   "val/lane/decoded_top_k_used": 6.0,
#   "val/lane/decoded_oracle_f1": 0.04425133536569774,
#   "val/lane/decoded_oracle_precision": 0.04355149595066905,
#   "val/lane/decoded_oracle_recall": 0.04572220593690872,
#   "val/lane/decoded_oracle_tp": 2.075,
#   "val/lane/decoded_oracle_fp": 45.575,
#   "val/lane/decoded_oracle_fn": 42.525,
#   "val/lane/decoded_oracle_pred_count": 47.65,
#   "val/lane/decoded_oracle_avg_score": 0.1022644316777587,
#   "val/lane/decoded_oracle_top_k_used": 6.0,
#   "val/det/metric_map50": 0.003189737198408693,
#   "val/det/metric_precision50": 0.01484375,
#   "val/det/metric_recall50": 0.141900644171983,
#   "val/det/metric_num_gt": 85.65,
#   "val/det/metric_num_pred": 800.0,
#   "val/lane/cls": 0.3681517854332924,
#   "val/lane/cls_pos": 0.543070237338543,
#   "val/lane/cls_neg": 0.2158154085278511,
#   "val/lane/reg": 0.16958541944622993,
#   "val/lane/xytl": 0.13293215148150922,
#   "val/lane/line_iou": 0.898517681658268,
#   "val/lane/mask_aux": 0.5442620292305946,
#   "val/lane/smooth": 0.0019375349278561772,
#   "val/lane/distill": 0.0,
#   "val/lane/iou_aux": 0.0,
#   "val/lane/geometry_raw": 1.2029727846384048,
#   "val/lane/geometry_weighted": 2.0272211998701097,
#   "val/lane/unweighted_total": 2.115386611223221,
#   "val/lane/weighted_total": 4.412242150306701,
#   "val/lane/total": 4.412242150306701,
#   "val/lane/stage1_aux_total": 1.914490818977356,
#   "val/lane/stage1_aux_cls": 0.05193905523046851,
#   "val/lane/stage1_aux_iou": 0.7236773431301117,
#   "val/lane/stage1_aux_reg": 0.14938235078006984,
#   "val/det/obj": 0.19704468175768852,
#   "val/det/cls": 0.0005626404526992701,
#   "val/det/bbox_l1": 0.04181458801031113,
#   "val/det/giou": 0.839831194281578,
#   "val/det/dn": 0.0,
#   "val/det/total": 2.086342641711235,
#   "val/det/positives": 85.65
# }
# [epoch_summary] epoch=4 phase=full_finetune train_total=3.2336 train_det=2.0939 train_lane=4.4194 val_det=2.0863 val_lane_scaled=6.3267 val_lane_unweighted=2.1154 val_lane_cls=0.3682 val_lane_reg=0.1696 val_lane_line_iou_loss=0.8985 val_lane_mask=0.5443 val_lane_exist_acc=0.4646 val_lane_f1=0.6289 val_lane_best_f1=0.6351 best_thr=0.24 val_lane_precision=0.4646 val_lane_recall=1.0000 val_lane_point_mae=0.3834 val_matched_line_iou=0.1015 pred_lanes=96.0 gt_lanes=44.6 matched_lanes=44.6 fp_slots=51.4 fn_slots=0.0 pos_score=0.5820 neg_score=0.5746 val_clrkd_f1=0.0292 val_decoded_f1=0.0289 val_decoded_p=0.0281 val_decoded_r=0.0302 decoded_pred=48.0 val_oracle_f1=0.0443 val_oracle_p=0.0436 val_oracle_r=0.0457 val_map50=0.0032 best_score=-8.4131 elapsed_s=57.7 peak_mem_mb=10402
# [lr_scheduler] after_epoch=4 param_group_lrs=[1.8855000636461646e-05, 0.00037710001272923293]
# epoch=5 phase=full_finetune batches=375 lane_matching=True geom_scale=1.000
# epoch=5 waiting_for_first_batch...
# epoch=5 step=1/375 total=3.0725 det=2.0504 lane=6.1395 lambda_lane=1.0000 cls=0.3507 reg=0.1685 iou=0.8959 grad_cos=-0.0615 speed=2.01step/s eta_min=3.1
# epoch=5 step=50/375 total=3.1490 det=2.1245 lane=6.3728 lambda_lane=1.0000 cls=0.3707 reg=0.1689 iou=0.8955 grad_cos=-0.0962 speed=6.68step/s eta_min=0.8
# epoch=5 step=100/375 total=3.0195 det=1.9041 lane=6.2689 lambda_lane=1.0000 cls=0.3675 reg=0.1666 iou=0.9078 grad_cos=-0.0707 speed=6.98step/s eta_min=0.7
# epoch=5 step=150/375 total=2.9694 det=2.0568 lane=6.0083 lambda_lane=1.0000 cls=0.3413 reg=0.1643 iou=0.8970 grad_cos=-0.0174 speed=7.24step/s eta_min=0.5
# epoch=5 step=200/375 total=3.0711 det=2.0905 lane=6.3757 lambda_lane=1.0000 cls=0.3812 reg=0.1681 iou=0.8667 grad_cos=0.1577 speed=7.41step/s eta_min=0.4
# epoch=5 step=250/375 total=2.8959 det=2.0638 lane=5.8868 lambda_lane=1.0000 cls=0.3648 reg=0.1778 iou=0.8780 grad_cos=0.0297 speed=7.45step/s eta_min=0.3
# epoch=5 step=300/375 total=2.9957 det=2.0326 lane=6.3261 lambda_lane=1.0000 cls=0.3910 reg=0.1718 iou=0.8837 grad_cos=0.0018 speed=7.46step/s eta_min=0.2
# epoch=5 step=350/375 total=2.8507 det=1.8972 lane=6.0429 lambda_lane=1.0000 cls=0.3392 reg=0.1512 iou=0.8835 grad_cos=-0.1344 speed=7.47step/s eta_min=0.1
# epoch=5 grad_cosine_epoch_mean=-0.0239 probes=8
# epoch=5 validation_start batches=40
# epoch=5 validation_done
# {
#   "train/total": 3.0412874190012613,
#   "train/grad_cosine": -0.0005093747156982621,
#   "train/phase_id": 5.0,
#   "train/mtl/lambda_lane_epoch": 1.0,
#   "train/lane/geometry_scale": 1.0,
#   "train/lane/cls": 0.3658352547486623,
#   "train/lane/cls_pos": 0.516681525627772,
#   "train/lane/cls_neg": 0.23542083088556925,
#   "train/lane/reg": 0.16853709050019583,
#   "train/lane/xytl": 0.13058415538072585,
#   "train/lane/line_iou": 0.9022728571891785,
#   "train/lane/mask_aux": 0.5385354552268982,
#   "train/lane/smooth": 0.0021951926415786148,
#   "train/lane/distill": 0.0,
#   "train/lane/iou_aux": 0.0,
#   "train/lane/geometry_raw": 1.2035893004735312,
#   "train/lane/geometry_weighted": 2.0330168294906614,
#   "train/lane/unweighted_total": 2.10796000512441,
#   "train/lane/weighted_total": 4.400728573481242,
#   "train/lane/total": 4.400728573481242,
#   "train/lane/stage1_aux_total": 1.848562328974406,
#   "train/lane/stage1_aux_cls": 0.051703570420543354,
#   "train/lane/stage1_aux_iou": 0.6920692580540975,
#   "train/lane/stage1_aux_reg": 0.14837578864892323,
#   "train/det/obj": 0.19537144585450492,
#   "train/det/cls": 0.000569008760775129,
#   "train/det/bbox_l1": 0.04229179315268993,
#   "train/det/giou": 0.8446184202829997,
#   "train/det/dn": 0.0,
#   "train/det/total": 2.096636259396871,
#   "train/det/positives": 86.456,
#   "train/mtl/log_var_0": 0.4146168158054352,
#   "train/mtl/weighted_0": 0.9000228610038757,
#   "train/mtl/log_var_1": 0.503663097858429,
#   "train/mtl/weighted_1": 2.1412620687484742,
#   "train/mtl/total": 3.041284927368164,
#   "train/mtl/gate_reg": 0.0024893391927083334,
#   "train/gate/det_mean": 0.49999479166666666,
#   "train/gate/lane_mean": 0.5,
#   "train/gate/det_sat_low": 0.0,
#   "train/gate/det_sat_high": 0.0,
#   "train/gate/lane_sat_low": 0.0,
#   "train/gate/lane_sat_high": 0.0,
#   "epoch": 5.0,
#   "train/grad_cosine_epoch_mean": -0.023876939798356034,
#   "train/grad_cosine_probe_count": 8.0,
#   "val/lane_loss": 6.289540684223175,
#   "val/lane_loss_scaled": 6.289540684223175,
#   "val/det_loss": 2.085123524069786,
#   "val/lane_exist_acc": 0.46458332911133765,
#   "val/lane_exist_precision": 0.46458332911133765,
#   "val/lane_exist_recall": 0.9999999940395355,
#   "val/lane_exist_f1": 0.6289202734827996,
#   "val/lane_exist_best_f1": 0.6486811980605125,
#   "val/lane_exist_best_threshold": 0.41875000614672897,
#   "val/lane_exist_pos_score_mean": 0.6248270556330681,
#   "val/lane_exist_neg_score_mean": 0.5967259585857392,
#   "val/lane_point_mae": 0.38978769183158873,
#   "val/matched_lane_point_mae": 0.38978769183158873,
#   "val/matched_line_iou": 0.09217133382335305,
#   "val/num_gt_lanes": 44.6,
#   "val/num_pred_lanes": 96.0,
#   "val/num_matched_lanes": 44.6,
#   "val/false_positive_lane_slots": 51.4,
#   "val/false_negative_lane_slots": 0.0,
#   "val/lane/clrkd_style_f1": 0.023388333688490092,
#   "val/lane/clrkd_style_precision": 0.017447916814126073,
#   "val/lane/clrkd_style_recall": 0.03630245835520327,
#   "val/lane/clrkd_style_tp": 1.675,
#   "val/lane/clrkd_style_fp": 94.325,
#   "val/lane/clrkd_style_fn": 42.925,
#   "val/lane/decoded_f1": 0.016195538779720665,
#   "val/lane/decoded_precision": 0.016359273856505752,
#   "val/lane/decoded_recall": 0.016322409640997647,
#   "val/lane/decoded_tp": 0.775,
#   "val/lane/decoded_fp": 46.825,
#   "val/lane/decoded_fn": 43.825,
#   "val/lane/decoded_pred_count": 47.6,
#   "val/lane/decoded_avg_score": 0.6636172726750373,
#   "val/lane/decoded_top_k_used": 6.0,
#   "val/lane/decoded_oracle_f1": 0.03536316333338618,
#   "val/lane/decoded_oracle_precision": 0.035085665481165054,
#   "val/lane/decoded_oracle_recall": 0.03630245835520327,
#   "val/lane/decoded_oracle_tp": 1.675,
#   "val/lane/decoded_oracle_fp": 46.125,
#   "val/lane/decoded_oracle_fn": 42.925,
#   "val/lane/decoded_oracle_pred_count": 47.8,
#   "val/lane/decoded_oracle_avg_score": 0.09490615287795663,
#   "val/lane/decoded_oracle_top_k_used": 6.0,
#   "val/det/metric_map50": 0.0030226223039790056,
#   "val/det/metric_precision50": 0.014718749967869371,
#   "val/det/metric_recall50": 0.13999839182943105,
#   "val/det/metric_num_gt": 85.65,
#   "val/det/metric_num_pred": 800.0,
#   "val/lane/cls": 0.3592346109449863,
#   "val/lane/cls_pos": 0.4749255463480949,
#   "val/lane/cls_neg": 0.2576079547405243,
#   "val/lane/reg": 0.17261086739599704,
#   "val/lane/xytl": 0.1306342024356127,
#   "val/lane/line_iou": 0.9078286617994309,
#   "val/lane/mask_aux": 0.5415868118405343,
#   "val/lane/smooth": 0.0019053113646805286,
#   "val/lane/distill": 0.0,
#   "val/lane/iou_aux": 0.0,
#   "val/lane/geometry_raw": 1.212979033589363,
#   "val/lane/geometry_weighted": 2.0490125000476835,
#   "val/lane/unweighted_total": 2.1138004839420317,
#   "val/lane/weighted_total": 4.386772418022156,
#   "val/lane/total": 4.386772418022156,
#   "val/lane/stage1_aux_total": 1.9027682811021804,
#   "val/lane/stage1_aux_cls": 0.051961669232696295,
#   "val/lane/stage1_aux_iou": 0.7175334975123405,
#   "val/lane/stage1_aux_reg": 0.14936606362462043,
#   "val/det/obj": 0.19557075798511506,
#   "val/det/cls": 0.0004989988512534183,
#   "val/det/bbox_l1": 0.04211127227172255,
#   "val/det/giou": 0.8392487019300461,
#   "val/det/dn": 0.0,
#   "val/det/total": 2.085123524069786,
#   "val/det/positives": 85.65
# }
# [epoch_summary] epoch=5 phase=full_finetune train_total=3.0413 train_det=2.0966 train_lane=4.4007 val_det=2.0851 val_lane_scaled=6.2895 val_lane_unweighted=2.1138 val_lane_cls=0.3592 val_lane_reg=0.1726 val_lane_line_iou_loss=0.9078 val_lane_mask=0.5416 val_lane_exist_acc=0.4646 val_lane_f1=0.6289 val_lane_best_f1=0.6487 best_thr=0.42 val_lane_precision=0.4646 val_lane_recall=1.0000 val_lane_point_mae=0.3898 val_matched_line_iou=0.0922 pred_lanes=96.0 gt_lanes=44.6 matched_lanes=44.6 fp_slots=51.4 fn_slots=0.0 pos_score=0.6248 neg_score=0.5967 val_clrkd_f1=0.0234 val_decoded_f1=0.0162 val_decoded_p=0.0164 val_decoded_r=0.0163 decoded_pred=47.6 val_oracle_f1=0.0354 val_oracle_p=0.0351 val_oracle_r=0.0363 val_map50=0.0030 best_score=-8.3747 elapsed_s=57.4 peak_mem_mb=10402
# [lr_scheduler] after_epoch=5 param_group_lrs=[1.7996834839265743e-05, 0.0003599366967853148]
# epoch=6 phase=full_finetune batches=375 lane_matching=True geom_scale=1.000
# epoch=6 waiting_for_first_batch...
# epoch=6 step=1/375 total=3.0136 det=2.0948 lane=6.4243 lambda_lane=1.0000 cls=0.3858 reg=0.1644 iou=0.8794 grad_cos=0.0595 speed=1.62step/s eta_min=3.9
# epoch=6 step=50/375 total=2.9769 det=2.2526 lane=6.1844 lambda_lane=1.0000 cls=0.3559 reg=0.1753 iou=0.8927 grad_cos=-0.1232 speed=7.00step/s eta_min=0.8
# epoch=6 step=100/375 total=2.7894 det=1.8317 lane=6.0480 lambda_lane=1.0000 cls=0.3422 reg=0.1674 iou=0.8542 grad_cos=-0.1072 speed=7.23step/s eta_min=0.6
# epoch=6 step=150/375 total=2.8332 det=1.6803 lane=6.4342 lambda_lane=1.0000 cls=0.3922 reg=0.1737 iou=0.9244 grad_cos=0.0207 speed=7.20step/s eta_min=0.5
# epoch=6 step=200/375 total=2.7722 det=1.8979 lane=6.0253 lambda_lane=1.0000 cls=0.3341 reg=0.1650 iou=0.8894 grad_cos=0.0411 speed=7.35step/s eta_min=0.4
# epoch=6 step=250/375 total=2.9612 det=2.6834 lane=5.8936 lambda_lane=1.0000 cls=0.3402 reg=0.1850 iou=0.8727 grad_cos=0.0136 speed=7.40step/s eta_min=0.3
# epoch=6 step=300/375 total=2.8957 det=2.2372 lane=6.2161 lambda_lane=1.0000 cls=0.3707 reg=0.1747 iou=0.8860 grad_cos=-0.0017 speed=7.43step/s eta_min=0.2
# epoch=6 step=350/375 total=2.7794 det=2.0222 lane=6.0784 lambda_lane=1.0000 cls=0.3675 reg=0.1590 iou=0.8949 grad_cos=0.0689 speed=7.45step/s eta_min=0.1
# epoch=6 grad_cosine_epoch_mean=-0.0035 probes=8
# epoch=6 validation_start batches=40
# epoch=6 validation_done
# {
#   "train/total": 2.8951230436960858,
#   "train/grad_cosine": -7.562853023409844e-05,
#   "train/phase_id": 6.0,
#   "train/mtl/lambda_lane_epoch": 1.0,
#   "train/lane/geometry_scale": 1.0,
#   "train/lane/cls": 0.362483007589976,
#   "train/lane/cls_pos": 0.5056990942160289,
#   "train/lane/cls_neg": 0.23843179941177367,
#   "train/lane/reg": 0.17090201687812806,
#   "train/lane/xytl": 0.1277455751299858,
#   "train/lane/line_iou": 0.9005526687304178,
#   "train/lane/mask_aux": 0.5318744354248047,
#   "train/lane/smooth": 0.002175934742515286,
#   "train/lane/distill": 0.0,
#   "train/lane/iou_aux": 0.0,
#   "train/lane/geometry_raw": 1.2013761924107869,
#   "train/lane/geometry_weighted": 2.0318456780115763,
#   "train/lane/unweighted_total": 2.095733641306559,
#   "train/lane/weighted_total": 4.376135164896647,
#   "train/lane/total": 4.376135164896647,
#   "train/lane/stage1_aux_total": 1.850440233230591,
#   "train/lane/stage1_aux_cls": 0.05143787575761477,
#   "train/lane/stage1_aux_iou": 0.6933459424972535,
#   "train/lane/stage1_aux_reg": 0.14909821438789367,
#   "train/det/obj": 0.19510702697436014,
#   "train/det/cls": 0.0004679214399851238,
#   "train/det/bbox_l1": 0.04266429569820563,
#   "train/det/giou": 0.846738676071167,
#   "train/det/dn": 0.0,
#   "train/det/total": 2.102373778025309,
#   "train/det/positives": 86.456,
#   "train/mtl/log_var_0": 0.4852216165860494,
#   "train/mtl/weighted_0": 0.889824009736379,
#   "train/mtl/log_var_1": 0.6036913290023803,
#   "train/mtl/weighted_1": 2.0052965602874755,
#   "train/mtl/total": 2.895120569864909,
#   "train/mtl/gate_reg": 0.002479736328125,
#   "train/gate/det_mean": 0.499921875,
#   "train/gate/lane_mean": 0.5,
#   "train/gate/det_sat_low": 0.0,
#   "train/gate/det_sat_high": 0.0,
#   "train/gate/lane_sat_low": 0.0,
#   "train/gate/lane_sat_high": 0.0,
#   "epoch": 6.0,
#   "train/grad_cosine_epoch_mean": -0.003545087354723364,
#   "train/grad_cosine_probe_count": 8.0,
#   "val/lane_loss": 6.205180621147155,
#   "val/lane_loss_scaled": 6.205180621147155,
#   "val/det_loss": 2.0869077175855635,
#   "val/lane_exist_acc": 0.46458332911133765,
#   "val/lane_exist_precision": 0.46458332911133765,
#   "val/lane_exist_recall": 0.9999999940395355,
#   "val/lane_exist_f1": 0.6289202734827996,
#   "val/lane_exist_best_f1": 0.6581163838505745,
#   "val/lane_exist_best_threshold": 0.5012500056996941,
#   "val/lane_exist_pos_score_mean": 0.6087802946567535,
#   "val/lane_exist_neg_score_mean": 0.5780777126550675,
#   "val/lane_point_mae": 0.38424659296870234,
#   "val/matched_lane_point_mae": 0.38424659296870234,
#   "val/matched_line_iou": 0.10324597153812647,
#   "val/num_gt_lanes": 44.6,
#   "val/num_pred_lanes": 96.0,
#   "val/num_matched_lanes": 44.6,
#   "val/false_positive_lane_slots": 51.4,
#   "val/false_negative_lane_slots": 0.0,
#   "val/lane/clrkd_style_f1": 0.026179288839921357,
#   "val/lane/clrkd_style_precision": 0.01927083367481828,
#   "val/lane/clrkd_style_recall": 0.042265834659337996,
#   "val/lane/clrkd_style_tp": 1.85,
#   "val/lane/clrkd_style_fp": 94.15,
#   "val/lane/clrkd_style_fn": 42.75,
#   "val/lane/decoded_f1": 0.016167179821059106,
#   "val/lane/decoded_precision": 0.015680408151820303,
#   "val/lane/decoded_recall": 0.01704426873475313,
#   "val/lane/decoded_tp": 0.75,
#   "val/lane/decoded_fp": 47.125,
#   "val/lane/decoded_fn": 43.85,
#   "val/lane/decoded_pred_count": 47.875,
#   "val/lane/decoded_avg_score": 0.6455215975642205,
#   "val/lane/decoded_top_k_used": 6.0,
#   "val/lane/decoded_oracle_f1": 0.039839801285415886,
#   "val/lane/decoded_oracle_precision": 0.03863031966611743,
#   "val/lane/decoded_oracle_recall": 0.042265834659337996,
#   "val/lane/decoded_oracle_tp": 1.85,
#   "val/lane/decoded_oracle_fp": 46.05,
#   "val/lane/decoded_oracle_fn": 42.75,
#   "val/lane/decoded_oracle_pred_count": 47.9,
#   "val/lane/decoded_oracle_avg_score": 0.10421691434457898,
#   "val/lane/decoded_oracle_top_k_used": 6.0,
#   "val/det/metric_map50": 0.003966004909307231,
#   "val/det/metric_precision50": 0.014485452754888684,
#   "val/det/metric_recall50": 0.13677328396588564,
#   "val/det/metric_num_gt": 85.65,
#   "val/det/metric_num_pred": 798.975,
#   "val/lane/cls": 0.35667312517762184,
#   "val/lane/cls_pos": 0.5006164774298668,
#   "val/lane/cls_neg": 0.23057488054037095,
#   "val/lane/reg": 0.1700182817876339,
#   "val/lane/xytl": 0.12875593099743127,
#   "val/lane/line_iou": 0.8967540234327316,
#   "val/lane/mask_aux": 0.5268016181886196,
#   "val/lane/smooth": 0.0021400195080786945,
#   "val/lane/distill": 0.0,
#   "val/lane/iou_aux": 0.0,
#   "val/lane/geometry_raw": 1.1976682662963867,
#   "val/lane/geometry_weighted": 2.0233881890773775,
#   "val/lane/unweighted_total": 2.0811429917812347,
#   "val/lane/weighted_total": 4.333555471897125,
#   "val/lane/total": 4.333555471897125,
#   "val/lane/stage1_aux_total": 1.8716251850128174,
#   "val/lane/stage1_aux_cls": 0.051561349630355836,
#   "val/lane/stage1_aux_iou": 0.7038106098771095,
#   "val/lane/stage1_aux_reg": 0.14886846467852594,
#   "val/det/obj": 0.1939211841672659,
#   "val/det/cls": 0.0004994491886463947,
#   "val/det/bbox_l1": 0.04303450919687748,
#   "val/det/giou": 0.8386572778224946,
#   "val/det/dn": 0.0,
#   "val/det/total": 2.0869077175855635,
#   "val/det/positives": 85.65
# }
# ...
# [lr_scheduler] after_epoch=18 param_group_lrs=[1.5147362038439711e-06, 3.0294724076879423e-05]
# epoch=19 phase=full_finetune batches=375 lane_matching=True geom_scale=1.000
# epoch=19 waiting_for_first_batch...
# epoch=19 step=1/375 total=2.3468 det=1.9016 lane=6.1625 lambda_lane=1.0000 cls=0.3872 reg=0.1599 iou=0.8892 grad_cos=0.0225 speed=1.70step/s eta_min=3.7
# epoch=19 step=50/375 total=2.2353 det=1.7490 lane=5.6649 lambda_lane=1.0000 cls=0.3202 reg=0.1675 iou=0.8701 grad_cos=0.0796 speed=6.99step/s eta_min=0.8
# epoch=19 step=100/375 total=2.3670 det=2.1856 lane=5.8439 lambda_lane=1.0000 cls=0.3560 reg=0.1698 iou=0.8692 grad_cos=-0.1121 speed=7.14step/s eta_min=0.6
# epoch=19 step=150/375 total=2.4325 det=2.2815 lane=6.1320 lambda_lane=1.0000 cls=0.3723 reg=0.1624 iou=0.8789 grad_cos=-0.0870 speed=7.18step/s eta_min=0.5
# epoch=19 step=200/375 total=2.3382 det=2.1131 lane=5.7738 lambda_lane=1.0000 cls=0.3303 reg=0.1628 iou=0.8964 grad_cos=0.0954 speed=7.29step/s eta_min=0.4
# epoch=19 step=250/375 total=2.4037 det=2.0630 lane=6.3006 lambda_lane=1.0000 cls=0.3955 reg=0.1691 iou=0.8759 grad_cos=0.0049 speed=7.31step/s eta_min=0.3
# epoch=19 step=300/375 total=2.3708 det=2.1090 lane=6.0071 lambda_lane=1.0000 cls=0.3804 reg=0.1698 iou=0.8563 grad_cos=-0.3128 speed=7.39step/s eta_min=0.2
# epoch=19 step=350/375 total=2.4207 det=2.2815 lane=6.0655 lambda_lane=1.0000 cls=0.3803 reg=0.1727 iou=0.8823 grad_cos=-0.2075 speed=7.45step/s eta_min=0.1
# epoch=19 grad_cosine_epoch_mean=-0.0646 probes=8
# epoch=19 validation_start batches=40
# epoch=19 validation_done
# {
#   "train/total": 2.3536724459330243,
#   "train/grad_cosine": -0.0013786789104342462,
#   "train/phase_id": 19.0,
#   "train/mtl/lambda_lane_epoch": 1.0,
#   "train/lane/geometry_scale": 1.0,
#   "train/lane/cls": 0.36072012344996135,
#   "train/lane/cls_pos": 0.5004617935021718,
#   "train/lane/cls_neg": 0.2395907698472341,
#   "train/lane/reg": 0.16734942177931467,
#   "train/lane/xytl": 0.11935422158241273,
#   "train/lane/line_iou": 0.8821443219184876,
#   "train/lane/mask_aux": 0.48502459263801573,
#   "train/lane/smooth": 0.0011376560699815552,
#   "train/lane/distill": 0.0,
#   "train/lane/iou_aux": 0.0,
#   "train/lane/geometry_raw": 1.169985619544983,
#   "train/lane/geometry_weighted": 1.9890356791814168,
#   "train/lane/unweighted_total": 2.0157303304672243,
#   "train/lane/weighted_total": 4.27766090965271,
#   "train/lane/total": 4.27766090965271,
#   "train/lane/stage1_aux_total": 1.6868328034083049,
#   "train/lane/stage1_aux_cls": 0.05179573591550191,
#   "train/lane/stage1_aux_iou": 0.614342263062795,
#   "train/lane/stage1_aux_reg": 0.1449733726978302,
#   "train/det/obj": 0.19492661388715107,
#   "train/det/cls": 9.41906249014816e-05,
#   "train/det/bbox_l1": 0.03995764189958572,
#   "train/det/giou": 0.8324612243970235,
#   "train/det/dn": 0.0,
#   "train/det/total": 2.059731461207072,
#   "train/det/positives": 86.456,
#   "train/mtl/log_var_0": 0.7268806578318278,
#   "train/mtl/weighted_0": 0.8612931370735168,
#   "train/mtl/log_var_1": 1.2150088698069255,
#   "train/mtl/weighted_1": 1.4923768027623494,
#   "train/mtl/total": 2.353669937769572,
#   "train/mtl/gate_reg": 0.002502644856770833,
#   "train/gate/det_mean": 0.49876041666666665,
#   "train/gate/lane_mean": 0.5,
#   "train/gate/det_sat_low": 0.0,
#   "train/gate/det_sat_high": 0.0,
#   "train/gate/lane_sat_low": 0.0,
#   "train/gate/lane_sat_high": 0.0,
#   "epoch": 19.0,
#   "train/grad_cosine_epoch_mean": -0.06462557392660528,
#   "train/grad_cosine_probe_count": 8.0,
#   "val/lane_loss": 5.969396221637726,
#   "val/lane_loss_scaled": 5.969396221637726,
#   "val/det_loss": 2.0476952850818635,
#   "val/lane_exist_acc": 0.46458332911133765,
#   "val/lane_exist_precision": 0.46458332911133765,
#   "val/lane_exist_recall": 0.9999999940395355,
#   "val/lane_exist_f1": 0.6289202734827996,
#   "val/lane_exist_best_f1": 0.6493016302585601,
#   "val/lane_exist_best_threshold": 0.38125000409781934,
#   "val/lane_exist_pos_score_mean": 0.6058878421783447,
#   "val/lane_exist_neg_score_mean": 0.5764894396066665,
#   "val/lane_point_mae": 0.38081571608781817,
#   "val/matched_lane_point_mae": 0.38081571608781817,
#   "val/matched_line_iou": 0.11818118924275041,
#   "val/num_gt_lanes": 44.6,
#   "val/num_pred_lanes": 96.0,
#   "val/num_matched_lanes": 44.6,
#   "val/false_positive_lane_slots": 51.4,
#   "val/false_negative_lane_slots": 0.0,
#   "val/lane/clrkd_style_f1": 0.04496444347314536,
#   "val/lane/clrkd_style_precision": 0.03307291690725833,
#   "val/lane/clrkd_style_recall": 0.07231128695420921,
#   "val/lane/clrkd_style_tp": 3.175,
#   "val/lane/clrkd_style_fp": 92.825,
#   "val/lane/clrkd_style_fn": 41.425,
#   "val/lane/decoded_f1": 0.027025795867666604,
#   "val/lane/decoded_precision": 0.02604166720993817,
#   "val/lane/decoded_recall": 0.028979655541479587,
#   "val/lane/decoded_tp": 1.25,
#   "val/lane/decoded_fp": 46.75,
#   "val/lane/decoded_fn": 43.35,
#   "val/lane/decoded_pred_count": 48.0,
#   "val/lane/decoded_avg_score": 0.6380020752549171,
#   "val/lane/decoded_top_k_used": 6.0,
#   "val/lane/decoded_oracle_f1": 0.0683356212452054,
#   "val/lane/decoded_oracle_precision": 0.06614583381451666,
#   "val/lane/decoded_oracle_recall": 0.07231128695420921,
#   "val/lane/decoded_oracle_tp": 3.175,
#   "val/lane/decoded_oracle_fp": 44.825,
#   "val/lane/decoded_oracle_fn": 41.425,
#   "val/lane/decoded_oracle_pred_count": 48.0,
#   "val/lane/decoded_oracle_avg_score": 0.11612769048660994,
#   "val/lane/decoded_oracle_top_k_used": 6.0,
#   "val/det/metric_map50": 0.0036937268945621327,
#   "val/det/metric_precision50": 0.015220126998610795,
#   "val/det/metric_recall50": 0.1429030353203416,
#   "val/det/metric_num_gt": 85.65,
#   "val/det/metric_num_pred": 794.6,
#   "val/lane/cls": 0.35712422505021096,
#   "val/lane/cls_pos": 0.5061480715870857,
#   "val/lane/cls_neg": 0.22655824497342109,
#   "val/lane/reg": 0.1684983991086483,
#   "val/lane/xytl": 0.11982178911566735,
#   "val/lane/line_iou": 0.8818188145756721,
#   "val/lane/mask_aux": 0.48976671770215036,
#   "val/lane/smooth": 0.0009109081016504206,
#   "val/lane/distill": 0.0,
#   "val/lane/iou_aux": 0.0,
#   "val/lane/geometry_raw": 1.171049916744232,
#   "val/lane/geometry_weighted": 1.9898456305265426,
#   "val/lane/unweighted_total": 2.017940863966942,
#   "val/lane/weighted_total": 4.265233421325684,
#   "val/lane/total": 4.265233421325684,
#   "val/lane/stage1_aux_total": 1.704162809252739,
#   "val/lane/stage1_aux_cls": 0.05158076789230108,
#   "val/lane/stage1_aux_iou": 0.6235515817999839,
#   "val/lane/stage1_aux_reg": 0.14513097926974297,
#   "val/det/obj": 0.19534881487488748,
#   "val/det/cls": 0.00010159481362279621,
#   "val/det/bbox_l1": 0.0403935357928276,
#   "val/det/giou": 0.8251386031508445,
#   "val/det/dn": 0.0,
#   "val/det/total": 2.0476952850818635,
#   "val/det/positives": 85.65
# }
# [epoch_summary] epoch=19 phase=full_finetune train_total=2.3537 train_det=2.0597 train_lane=4.2777 val_det=2.0477 val_lane_scaled=5.9694 val_lane_unweighted=2.0179 val_lane_cls=0.3571 val_lane_reg=0.1685 val_lane_line_iou_loss=0.8818 val_lane_mask=0.4898 val_lane_exist_acc=0.4646 val_lane_f1=0.6289 val_lane_best_f1=0.6493 best_thr=0.38 val_lane_precision=0.4646 val_lane_recall=1.0000 val_lane_point_mae=0.3808 val_matched_line_iou=0.1182 pred_lanes=96.0 gt_lanes=44.6 matched_lanes=44.6 fp_slots=51.4 fn_slots=0.0 pos_score=0.6059 neg_score=0.5765 val_clrkd_f1=0.0450 val_decoded_f1=0.0270 val_decoded_p=0.0260 val_decoded_r=0.0290 decoded_pred=48.0 val_oracle_f1=0.0683 val_oracle_p=0.0661 val_oracle_r=0.0723 val_map50=0.0037 best_score=-8.0171 elapsed_s=57.3 peak_mem_mb=10402
# [lr_scheduler] after_epoch=19 param_group_lrs=[1.1295676176741382e-06, 2.259135235348276e-05]
# epoch=20 phase=full_finetune batches=375 lane_matching=True geom_scale=1.000
# epoch=20 waiting_for_first_batch...
# epoch=20 step=1/375 total=2.3040 det=1.9094 lane=5.8863 lambda_lane=1.0000 cls=0.3495 reg=0.1676 iou=0.8976 grad_cos=0.0059 speed=1.95step/s eta_min=3.2
# epoch=20 step=50/375 total=2.3560 det=2.1722 lane=5.8106 lambda_lane=1.0000 cls=0.3415 reg=0.1584 iou=0.8800 grad_cos=-0.0862 speed=7.15step/s eta_min=0.8
# epoch=20 step=100/375 total=2.3699 det=2.0659 lane=6.0812 lambda_lane=1.0000 cls=0.3761 reg=0.1800 iou=0.8944 grad_cos=0.0493 speed=7.36step/s eta_min=0.6
# epoch=20 step=150/375 total=2.3029 det=2.0076 lane=5.7247 lambda_lane=1.0000 cls=0.3143 reg=0.1664 iou=0.9117 grad_cos=-0.0005 speed=7.45step/s eta_min=0.5
# epoch=20 step=200/375 total=2.3987 det=2.1649 lane=6.1192 lambda_lane=1.0000 cls=0.3951 reg=0.1734 iou=0.8889 grad_cos=0.0624 speed=7.44step/s eta_min=0.4
# epoch=20 step=250/375 total=2.3457 det=1.9967 lane=6.0381 lambda_lane=1.0000 cls=0.3615 reg=0.1684 iou=0.9089 grad_cos=-0.0875 speed=7.48step/s eta_min=0.3
# epoch=20 step=300/375 total=2.3672 det=2.0770 lane=6.0548 lambda_lane=1.0000 cls=0.3848 reg=0.1607 iou=0.8793 grad_cos=0.0187 speed=7.55step/s eta_min=0.2
# epoch=20 step=350/375 total=2.3962 det=2.1523 lane=6.1310 lambda_lane=1.0000 cls=0.3919 reg=0.1572 iou=0.8611 grad_cos=-0.0381 speed=7.54step/s eta_min=0.1
# epoch=20 grad_cosine_epoch_mean=-0.0095 probes=8
# epoch=20 validation_start batches=40
# epoch=20 validation_done
# {
#   "train/total": 2.3468663291931153,
#   "train/grad_cosine": -0.00020240570651367307,
#   "train/phase_id": 20.0,
#   "train/mtl/lambda_lane_epoch": 1.0,
#   "train/lane/geometry_scale": 1.0,
#   "train/lane/cls": 0.3594139445622762,
#   "train/lane/cls_pos": 0.4980411026477814,
#   "train/lane/cls_neg": 0.23899679827690123,
#   "train/lane/reg": 0.16714217170079548,
#   "train/lane/xytl": 0.11906817046801249,
#   "train/lane/line_iou": 0.8791897247632344,
#   "train/lane/mask_aux": 0.48541131258010867,
#   "train/lane/smooth": 0.0011087598002826175,
#   "train/lane/distill": 0.0,
#   "train/lane/iou_aux": 0.0,
#   "train/lane/geometry_raw": 1.1665088272094726,
#   "train/lane/geometry_weighted": 1.982819133758545,
#   "train/lane/unweighted_total": 2.0113340876897174,
#   "train/lane/weighted_total": 4.2653001721700035,
#   "train/lane/total": 4.2653001721700035,
#   "train/lane/stage1_aux_total": 1.6871878369649251,
#   "train/lane/stage1_aux_cls": 0.05162256213525931,
#   "train/lane/stage1_aux_iou": 0.6150347951253256,
#   "train/lane/stage1_aux_reg": 0.14498837119340896,
#   "train/det/obj": 0.19423445526758829,
#   "train/det/cls": 9.0091232220099e-05,
#   "train/det/bbox_l1": 0.040062358463803925,
#   "train/det/giou": 0.8286069928805033,
#   "train/det/dn": 0.0,
#   "train/det/total": 2.0518503297170003,
#   "train/det/positives": 86.456,
#   "train/mtl/log_var_0": 0.72628693040212,
#   "train/mtl/weighted_0": 0.8593859529495239,
#   "train/mtl/log_var_1": 1.2231932233174643,
#   "train/mtl/weighted_1": 1.487477869351705,
#   "train/mtl/total": 2.3468638203938803,
#   "train/mtl/gate_reg": 0.0025063069661458333,
#   "train/gate/det_mean": 0.4987916666666667,
#   "train/gate/lane_mean": 0.5,
#   "train/gate/det_sat_low": 0.0,
#   "train/gate/det_sat_high": 0.0,
#   "train/gate/lane_sat_low": 0.0,
#   "train/gate/lane_sat_high": 0.0,
#   "epoch": 20.0,
#   "train/grad_cosine_epoch_mean": -0.009487767492828425,
#   "train/grad_cosine_probe_count": 8.0,
#   "val/lane_loss": 5.945754599571228,
#   "val/lane_loss_scaled": 5.945754599571228,
#   "val/det_loss": 2.0401367127895353,
#   "val/lane_exist_acc": 0.46458332911133765,
#   "val/lane_exist_precision": 0.46458332911133765,
#   "val/lane_exist_recall": 0.9999999940395355,
#   "val/lane_exist_f1": 0.6289202734827996,
#   "val/lane_exist_best_f1": 0.6566332012414933,
#   "val/lane_exist_best_threshold": 0.44500000700354575,
#   "val/lane_exist_pos_score_mean": 0.6327910080552102,
#   "val/lane_exist_neg_score_mean": 0.5979651376605034,
#   "val/lane_point_mae": 0.3814722992479801,
#   "val/matched_lane_point_mae": 0.3814722992479801,
#   "val/matched_line_iou": 0.11720262533053756,
#   "val/num_gt_lanes": 44.6,
#   "val/num_pred_lanes": 96.0,
#   "val/num_matched_lanes": 44.6,
#   "val/false_positive_lane_slots": 51.4,
#   "val/false_negative_lane_slots": 0.0,
#   "val/lane/clrkd_style_f1": 0.040542149706743656,
#   "val/lane/clrkd_style_precision": 0.029947917093522847,
#   "val/lane/clrkd_style_recall": 0.0643038208130747,
#   "val/lane/clrkd_style_tp": 2.875,
#   "val/lane/clrkd_style_fp": 93.125,
#   "val/lane/clrkd_style_fn": 41.725,
#   "val/lane/decoded_f1": 0.014501619338989257,
#   "val/lane/decoded_precision": 0.014062500325962901,
#   "val/lane/decoded_recall": 0.015328185586258768,
#   "val/lane/decoded_tp": 0.675,
#   "val/lane/decoded_fp": 47.325,
#   "val/lane/decoded_fn": 43.925,
#   "val/lane/decoded_pred_count": 48.0,
#   "val/lane/decoded_avg_score": 0.6721813797950744,
#   "val/lane/decoded_top_k_used": 6.0,
#   "val/lane/decoded_oracle_f1": 0.061450380040332674,
#   "val/lane/decoded_oracle_precision": 0.05989583418704569,
#   "val/lane/decoded_oracle_recall": 0.0643038208130747,
#   "val/lane/decoded_oracle_tp": 2.875,
#   "val/lane/decoded_oracle_fp": 45.125,
#   "val/lane/decoded_oracle_fn": 41.725,
#   "val/lane/decoded_oracle_pred_count": 48.0,
#   "val/lane/decoded_oracle_avg_score": 0.1161277818493545,
#   "val/lane/decoded_oracle_top_k_used": 6.0,
#   "val/det/metric_map50": 0.004138119259732775,
#   "val/det/metric_precision50": 0.016061616479419172,
#   "val/det/metric_recall50": 0.14920592810958624,
#   "val/det/metric_num_gt": 85.65,
#   "val/det/metric_num_pred": 791.675,
#   "val/lane/cls": 0.3559351898729801,
#   "val/lane/cls_pos": 0.463024578243494,
#   "val/lane/cls_neg": 0.26160999201238155,
#   "val/lane/reg": 0.16880796067416667,
#   "val/lane/xytl": 0.11787489149719477,
#   "val/lane/line_iou": 0.8827973738312721,
#   "val/lane/mask_aux": 0.4883921004831791,
#   "val/lane/smooth": 0.0008859213834512047,
#   "val/lane/distill": 0.0,
#   "val/lane/iou_aux": 0.0,
#   "val/lane/geometry_raw": 1.1703661590814591,
#   "val/lane/geometry_weighted": 1.9917835861444473,
#   "val/lane/unweighted_total": 2.0146934032440185,
#   "val/lane/weighted_total": 4.2598516821861265,
#   "val/lane/total": 4.2598516821861265,
#   "val/lane/stage1_aux_total": 1.685902926325798,
#   "val/lane/stage1_aux_cls": 0.05189464297145605,
#   "val/lane/stage1_aux_iou": 0.6137158796191216,
#   "val/lane/stage1_aux_reg": 0.14492508079856634,
#   "val/det/obj": 0.19504206515848638,
#   "val/det/cls": 8.616248651378555e-05,
#   "val/det/bbox_l1": 0.03940490614622831,
#   "val/det/giou": 0.823991970717907,
#   "val/det/dn": 0.0,
#   "val/det/total": 2.0401367127895353,
#   "val/det/positives": 85.65
# }
# [epoch_summary] epoch=20 phase=full_finetune train_total=2.3469 train_det=2.0519 train_lane=4.2653 val_det=2.0401 val_lane_scaled=5.9458 val_lane_unweighted=2.0147 val_lane_cls=0.3559 val_lane_reg=0.1688 val_lane_line_iou_loss=0.8828 val_lane_mask=0.4884 val_lane_exist_acc=0.4646 val_lane_f1=0.6289 val_lane_best_f1=0.6566 best_thr=0.45 val_lane_precision=0.4646 val_lane_recall=1.0000 val_lane_point_mae=0.3815 val_matched_line_iou=0.1172 pred_lanes=96.0 gt_lanes=44.6 matched_lanes=44.6 fp_slots=51.4 fn_slots=0.0 pos_score=0.6328 neg_score=0.5980 val_clrkd_f1=0.0405 val_decoded_f1=0.0145 val_decoded_p=0.0141 val_decoded_r=0.0153 decoded_pred=48.0 val_oracle_f1=0.0615 val_oracle_p=0.0599 val_oracle_r=0.0643 val_map50=0.0041 best_score=-7.9859 elapsed_s=57.0 peak_mem_mb=10402
# [lr_scheduler] after_epoch=20 param_group_lrs=[1.0000000000000002e-06, 2e-05]
# Wrote /content/drive/MyDrive/EcoCAR/training_runs/exp44_rmt_gca_hybrid_anchor_query_vfl_joint_short20.tar
# Training artifacts inside tar: best.pt, last.pt, metrics.json, config_snapshot.yaml
# [run_streaming] return_code=0
# 0

# %% [markdown]
# ## What to watch in Exp2TT training
#
# Reference NB47 (K=64 query alone): pos-neg gap=0.099, val_lane_f1=0.246, matched_iou=0.27, decoded_f1=0.019.
# Reference NB48 (anchor + full data): pos-neg gap=0.015, val_lane_f1=0.07, matched_iou=0.544, decoded_f1=0.05.
#
# Pass criteria at epoch 20:
# - **`val/matched_line_iou >= 0.45`** -- inherit NB48-style geometry from stage 1 (with limit=3000, expect slightly below 0.544; 0.45 is a reasonable lower bound).
# - **`pos_score - neg_score >= 0.10`** on stage 2 -- inherit NB47-style cls discrimination via Hungarian.
# - **`val/lane_f1 >= 0.20` and `val/lane_best_f1 >= 0.30`** -- decisive evidence the cls is now ranking real lanes.
# - **`val/lane/decoded_f1 >= 0.10`** -- 2x NB48's 0.05 because cls is finally discriminative.
# - `lane/stage1_aux_total` should DECREASE monotonically -- confirms stage 1 is being supervised.
#
# Failure signals:
# - matched_iou < 0.30: hybrid stage 2 distorts geometry. Set `stage1_aux_loss_weight=2.0`, `aux_stage_loss_weight=0.0`.
# - pos-neg gap < 0.05: K=12 queries are too few; switch to K=24 in a follow-up.
# - val_det >> 2.5: hybrid head adds enough capacity that joint conflict resurges. Drop lambda_lane to 0.7.
