# %% [markdown]
# # Stage 2 - train CLRKDNet-fused RMT-PPAD lane model

# %% [markdown]
# This is the controlled fusion experiment. Detection stays RMT-PPAD. The dense lane decoder is replaced by a CLRKDNet-inspired feature aggregation decoder.

# %%
from pathlib import Path
PROJECT_ROOT = Path("/content/drive/MyDrive/EcoCAR/yolop_vehicle_lane")
DATASET_ROOT = Path("/content/bdd100k_vehicle5")
# %cd {PROJECT_ROOT}
# !python stage2/scripts/02_sanity_check_stage2.py --project-root {PROJECT_ROOT} --dataset-root {DATASET_ROOT} --model rmt_ppad_clrkd_fused_lane.yaml

# %%
from pathlib import Path
PROJECT_ROOT = Path("/content/drive/MyDrive/EcoCAR/yolop_vehicle_lane")
# %cd {PROJECT_ROOT}
# !python stage2/scripts/03_train_rmt_ppad_clrkd_fused_lane.py \
  --project-root {PROJECT_ROOT} \
  --epochs 250 \
  --batch 16 \
  --lr0 0.0001 \
  --workers 8 \
  --device 0 \
  --val-period 1 \
  --save-period 1
