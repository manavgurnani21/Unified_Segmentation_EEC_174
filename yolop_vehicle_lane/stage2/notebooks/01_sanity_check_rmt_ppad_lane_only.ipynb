# %% [markdown]
# # Stage 2 - sanity check RMT-PPAD lane-only model

# %% [markdown]
# This checks the patched RMT-PPAD model config and prints which segmentation decoder is active.

# %%
from pathlib import Path
from google.colab import drive
drive.mount('/content/drive')

PROJECT_ROOT = Path("/content/drive/MyDrive/EcoCAR/yolop_vehicle_lane")
DATASET_ROOT = Path("/content/bdd100k_vehicle5")
# %cd {PROJECT_ROOT}
# !python stage2/scripts/02_sanity_check_stage2.py --project-root {PROJECT_ROOT} --dataset-root {DATASET_ROOT} --model rmt_ppad_lane_only.yaml
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/EcoCAR/yolop_vehicle_lane
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# /content/drive/MyDrive/EcoCAR/yolop_vehicle_lane/stage2/vendor/RMT-PPAD/ultralytics/models/mtdetr/train.py:98: SyntaxWarning: "is" with 'str' literal. Did you mean "=="?
#   if task is 'detection':
# WARNING ⚠️ no model scale passed. Assuming scale='l'.
# model_yaml: /content/drive/MyDrive/EcoCAR/yolop_vehicle_lane/stage2/configs/rmt_ppad_lane_only.yaml
# model_class: MTDETRModel
# decoder: MTDETRDecoder
# seg_decoder: rmt
# seg_head: TransformerSegmentationDecoder
# train_images: 0
# train_labels: 0
# train_lane_masks: 0
# val_images: 0
# val_labels: 0
# val_lane_masks: 0
