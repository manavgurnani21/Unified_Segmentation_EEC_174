# %% [markdown]
# # 00 — DualPath Pipeline: Vehicle Detection + Geometric Lane Prediction
#
# **Architecture: DualPathNet**
# - Shared ResNet-50 + FPN backbone
# - RT-DETR-inspired transformer detection decoder (vehicle-only)
# - MapTR-inspired query-based lane decoder (structured polylines, NOT masks)
# - Optional weak cross-branch attention
#
# **Dataset consumed from notebook02 package**
# - Detection: YOLO-format labels, vehicle classes only
# - Lanes: structured targets parsed from raw BDD100K JSON via `paths_config.yaml`
# - Current training does **not** require external segmentation-map files; seg paths are recorded only for optional future use
#
# **Key design choices:**
# - Weakly-coupled dual-path reduces negative transfer between tasks
# - Lane prediction is geometric (ordered point sequences), not raster masks
# - Architecture is future-ready for temporal lane memory (StreamMapNet-style)

# %% [markdown]
# ## 1 — Environment Setup

# %%
# !pip install -q torch torchvision torchmetrics pyyaml scipy opencv-python matplotlib tqdm
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 24.4 MB/s eta 0:00:00

# %%
import torch
import os, sys

if torch.cuda.is_available():
    gpu = torch.cuda.get_device_name(0)
    mem = torch.cuda.get_device_properties(0).total_memory / 1e9
    print(f"GPU: {gpu} ({mem:.1f} GB)")
else:
    print("WARNING: No GPU — training will be slow")
# Out:
# GPU: NVIDIA RTX PRO 6000 Blackwell Server Edition (102.0 GB)

# %%
from google.colab import drive
drive.mount('/content/drive')

# ── Fixed Drive paths (preserved from old pipeline) ──
ECOCAR_ROOT = "/content/drive/MyDrive/EcoCAR"
DATASET_NAME = "bdd100k_vehicle5"
DATASET_DRIVE = os.path.join(ECOCAR_ROOT, "datasets", DATASET_NAME)
DATASET_TAR = os.path.join(ECOCAR_ROOT, "datasets", f"{DATASET_NAME}.tar")
WEIGHTS_DIR = os.path.join(ECOCAR_ROOT, "weights")
TRAINING_RUNS = os.path.join(ECOCAR_ROOT, "training_runs")

# ── Project code ──
PROJECT_DIR = os.path.join(ECOCAR_ROOT, "DETR_GeoLane_pipeline")
if not os.path.isdir(PROJECT_DIR):
    # Fallback: clone from repo
    # !git clone https://github.com/ChenSiyun1234/EcoCAR-Perception-Pipeline-BDD100K.git /content/repo 2>/dev/null || true
    PROJECT_DIR = "/content/repo/DETR_GeoLane_pipeline"

sys.path.insert(0, PROJECT_DIR)
print(f"Project: {PROJECT_DIR}")
print(f"Dataset drive dir: {DATASET_DRIVE}")
print(f"Dataset tar: {DATASET_TAR}")
# Out:
# Mounted at /content/drive
# Project: /content/drive/MyDrive/EcoCAR/DETR_GeoLane_pipeline
# Dataset drive dir: /content/drive/MyDrive/EcoCAR/datasets/bdd100k_vehicle5
# Dataset tar: /content/drive/MyDrive/EcoCAR/datasets/bdd100k_vehicle5.tar

# %% [markdown]
# ## 2 — Dataset Inspection
#
# Reuses the existing BDD100K YOLO-format dataset from the old pipeline.
# Detection labels are `.txt` files; lane targets are parsed from raw BDD100K JSON.

# %%
from src.runtime_paths import ensure_local_dataset_from_drive

LOCAL_DS = ensure_local_dataset_from_drive(
    dataset_name=DATASET_NAME,
    ecocar_root=ECOCAR_ROOT,
)
print(f"Notebook-local dataset root: {LOCAL_DS}")

# Count
for split in ["train", "val"]:
    img_dir = os.path.join(LOCAL_DS, "images", split)
    lbl_dir = os.path.join(LOCAL_DS, "labels", split)
    n_img = len(os.listdir(img_dir)) if os.path.isdir(img_dir) else 0
    n_lbl = len(os.listdir(lbl_dir)) if os.path.isdir(lbl_dir) else 0
    print(f"  {split}: {n_img} images, {n_lbl} labels")

# %%
# ── Detection class distribution + label schema check ──
from collections import Counter
from src.dataset import infer_label_schema
from src.config import VEHICLE_CLASSES

lbl_dir = os.path.join(LOCAL_DS, 'labels', 'train')
schema = infer_label_schema(lbl_dir, use_expanded_classes=False)
print(f'Detected label schema: {schema}')

if schema == 'bdd_original':
    class_map = {2:0, 3:1, 4:2, 6:3, 7:4}
else:
    class_map = {0:0, 1:1, 2:2, 3:3, 4:4}

class_counts = Counter()
total_files = 0
for f in os.listdir(lbl_dir):
    if not f.endswith('.txt'):
        continue
    total_files += 1
    with open(os.path.join(lbl_dir, f)) as fh:
        for line in fh:
            parts = line.strip().split()
            if len(parts) < 5:
                continue
            cls_id = int(float(parts[0]))
            if cls_id in class_map:
                class_counts[class_map[cls_id]] += 1

print(f'Vehicle detection class distribution ({total_files} files):')
for i, name in enumerate(VEHICLE_CLASSES):
    print(f'  {name:<12}: {class_counts.get(i, 0):>8,}')
print(f'  Total vehicles: {sum(class_counts.values()):>8,}')
# Out:
# Detected label schema: vehicle_remapped
# Vehicle detection class distribution (70000 files):
#   car         :  713,917
#   truck       :   30,003
#   bus         :   11,684
#   motorcycle  :    3,002
#   bicycle     :    7,225
#   Total vehicles:  765,831

# %% [markdown]
# ## 3 — Lane Annotation Parsing
#
# Parse raw BDD100K poly2d annotations into structured lane targets.
# Each lane becomes a fixed-length ordered point sequence (72 points).

# %%
from src.config import find_lane_labels, PATHS_CONFIG, DOWNLOADS_DIR, RAW_DATASET_ROOT, ensure_bdd_labels_unzipped, get_lane_label_candidates

train_lane_json, train_tried = find_lane_labels("train", return_tried=True)
val_lane_json, val_tried = find_lane_labels("val", return_tried=True)

print(f"paths_config.yaml: {PATHS_CONFIG}")
print(f"Downloads dir:      {DOWNLOADS_DIR}")
print(f"Raw extract dir:    {RAW_DATASET_ROOT}")
print(f"Train lane labels: {train_lane_json or 'NOT FOUND'}")
print(f"Val lane labels:   {val_lane_json or 'NOT FOUND'}")

if train_lane_json is None:
    print()
    print("="*60)
    print("Lane labels not found using downloads-aware search.")
    print("Tried candidates like:")
    for p in train_tried[-12:]:
        print(" ", p)
    print("="*60)
# Out:
# paths_config.yaml: /content/drive/MyDrive/EcoCAR/paths_config.yaml
# Downloads dir:      /content/drive/MyDrive/EcoCAR/downloads
# Raw extract dir:    /content/bdd100k_raw
# Train lane labels: /content/bdd100k_raw/100k/train
# Val lane labels:   /content/bdd100k_raw/100k/val

# %%
# Debug cell: inspect labels zip / extracted tree / JSON structure
import os, json
from pathlib import Path
from src.config import DOWNLOADS_DIR, RAW_DATASET_ROOT, ensure_bdd_labels_unzipped, get_lane_label_candidates

raw_root, tried_zips = ensure_bdd_labels_unzipped(force=False)
print("zip candidates tried:")
for p in tried_zips:
    print(" ", p)
print("raw_root:", raw_root)

for split in ["train", "val"]:
    print(f"\n[{split}] candidates:")
    cands = get_lane_label_candidates(split)
    for p in cands:
        print(" ", p, "EXISTS" if os.path.isfile(p) else "")

chosen = None
for p in get_lane_label_candidates("train"):
    if os.path.isfile(p):
        chosen = p
        break

print("\nchosen train json:", chosen)
if chosen:
    with open(chosen, "r") as f:
        data = json.load(f)
    print("top-level type:", type(data), "len:", len(data))
    if len(data):
        print("frame keys:", list(data[0].keys()))
        labels = data[0].get("labels", [])
        print("labels type:", type(labels), "len:", len(labels))
        if labels:
            print("first label keys:", list(labels[0].keys()))
            print("first category:", labels[0].get("category"))
            print("has poly2d:", "poly2d" in labels[0])
            if "poly2d" in labels[0] and labels[0]["poly2d"]:
                print("poly2d[0] keys:", list(labels[0]["poly2d"][0].keys()))
# Out:
# zip candidates tried:
#   /content/drive/MyDrive/EcoCAR/downloads/bdd100k_labels.zip
# raw_root: /content/bdd100k_raw
#
# [train] candidates:
#   /content/bdd100k_raw/100k/train
#   /content/bdd100k_raw/bdd100k/100k/train
#   /content/bdd100k_raw/bdd100k/labels/bdd100k_labels_images_train.json
#   /content/bdd100k_raw/labels/bdd100k_labels_images_train.json
#   /content/bdd100k_raw/bdd100k/labels/lane/polygons/lane_train.json
#   /content/bdd100k_raw/labels/lane/polygons/lane_train.json
#
# [val] candidates:
#   /content/bdd100k_raw/100k/val
#   /content/bdd100k_raw/bdd100k/100k/val
#   /content/bdd100k_raw/bdd100k/labels/bdd100k_labels_images_val.json
#   /content/bdd100k_raw/labels/bdd100k_labels_images_val.json
#   /content/bdd100k_raw/bdd100k/labels/lane/polygons/lane_val.json
#   /content/bdd100k_raw/labels/lane/polygons/lane_val.json
#
# chosen train json: None

# %%
# Preview lane annotations over the real image and print raw points
if train_lane_json:
    import os, cv2, matplotlib.pyplot as plt
    from src.lane_targets import LaneLabelCache
    cache = LaneLabelCache(train_lane_json, max_lanes=10, num_points=72)
    print(f'Frames with lane annotations: {len(cache)}')
    shown = 0
    for name in list(cache._cache.keys()):
        targets = cache.get(name)
        n_lanes = int(targets['existence'].sum())
        if n_lanes <= 0:
            continue
        img_path = os.path.join(LOCAL_DS, 'images', 'train', name)
        img = cv2.imread(img_path)
        if img is None:
            print('image missing for', name, 'path=', img_path)
            continue
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        h, w = img.shape[:2]
        print(f'\nSample: {name} | lanes={n_lanes} | image={img_path} | shape={img.shape}')
        fig, ax = plt.subplots(figsize=(14, 6))
        ax.imshow(img)
        for li in range(n_lanes):
            pts = targets['points'][li].copy()
            vis = targets['visibility'][li] > 0
            pts[:, 0] *= w
            pts[:, 1] *= h
            print(f'lane {li} raw first 8 pts:', pts[:8].tolist())
            print(f'lane {li} visible count:', int(vis.sum()))
            ax.plot(pts[vis, 0], pts[vis, 1], '-', linewidth=2)
            ax.scatter(pts[vis, 0], pts[vis, 1], s=8)
        ax.set_title(f'Lane overlay: {name}')
        ax.set_xlim(0, w)
        ax.set_ylim(h, 0)
        plt.show()
        shown += 1
        if shown >= 2:
            break
# Out:
# Loading lane labels from per-image directory /content/bdd100k_raw/100k/train ...
#   Cached lane labels for 65813 frames from directory
#   Debug sample: {'name': '0000f77c-6257be58.jpg', 'n_labels': 3, 'existence_sum': 3.0, 'first_category': 'lane/road curb', 'first_vertices_head': [[503.674413, 373.137193], [357.797732, 374.672737]], 'first_types': 'LL', 'dense_points_head': [[503.674413, 373.137193], [357.797732, 374.672737]], 'dense_len': 2}
# Frames with lane annotations: 65813
#
# Sample: 0000f77c-6257be58.jpg | lanes=3 | image=/content/bdd100k_vehicle5/images/train/0000f77c-6257be58.jpg | shape=(720, 1280, 3)
# lane 0 raw first 8 pts: [[905.9869384765625, 371.6016540527344], [911.177490234375, 371.6665344238281], [916.3681030273438, 371.7314147949219], [921.5587158203125, 371.79632568359375], [926.7492065429688, 371.86114501953125], [931.9397583007812, 371.9260559082031], [937.13037109375, 371.9909362792969], [942.3209228515625, 372.0558166503906]]
# lane 0 visible count: 72
# lane 1 raw first 8 pts: [[0.0, 368.5305480957031], [0.8869476318359375, 368.57379150390625], [1.773895263671875, 368.6170654296875], [2.6608428955078125, 368.6603088378906], [3.54779052734375, 368.7035827636719], [4.4347381591796875, 368.746826171875], [5.321685791015625, 368.79010009765625], [6.2086334228515625, 368.8333435058594]]
# lane 1 visible count: 72
# lane 2 raw first 8 pts: [[503.6744384765625, 373.13720703125], [501.61981201171875, 373.1588439941406], [499.565185546875, 373.1804504394531], [497.5106201171875, 373.20208740234375], [495.45599365234375, 373.2237243652344], [493.40142822265625, 373.245361328125], [491.3468017578125, 373.2669677734375], [489.292236328125, 373.28857421875]]
# lane 2 visible count: 72
# Sample: 0000f77c-62c2a288.jpg | lanes=8 | image=/content/bdd100k_vehicle5/images/train/0000f77c-62c2a288.jpg | shape=(720, 1280, 3)
# lane 0 raw first 8 pts: [[829.844482421875, 367.2745361328125], [831.23828125, 373.8771057128906], [834.4080200195312, 379.7471008300781], [838.2501220703125, 385.2728576660156], [842.9342651367188, 390.1303405761719], [847.66552734375, 394.9371337890625], [852.8527221679688, 399.2533264160156], [858.0399169921875, 403.5694885253906]]
# lane 0 visible count: 72
# lane 1 raw first 8 pts: [[827.640380859375, 363.9683532714844], [823.17724609375, 367.64349365234375], [822.1347045898438, 373.1483459472656], [824.0411987304688, 378.49749755859375], [826.8682250976562, 383.4962463378906], [830.4110107421875, 388.06512451171875], [834.15234375, 392.45977783203125], [838.2210693359375, 396.5673522949219]]
# lane 1 visible count: 72
# lane 2 raw first 8 pts: [[817.721923828125, 363.9683532714844], [817.5079956054688, 369.4423522949219], [817.9837646484375, 374.8260803222656], [819.5997314453125, 380.0605163574219], [821.8494262695312, 385.015869140625], [824.62060546875, 389.741455078125], [827.6546630859375, 394.2850341796875], [831.1029663085938, 398.54180908203125]]
# lane 2 visible count: 72
# lane 3 raw first 8 pts: [[795.680908203125, 345.2332458496094], [788.9403686523438, 346.449951171875], [782.1997680664062, 347.6666564941406], [775.459228515625, 348.8833312988281], [768.7286987304688, 350.148193359375], [762.0660400390625, 351.7371520996094], [755.4034423828125, 353.3261413574219], [748.7407836914062, 354.91510009765625]]
# lane 3 visible count: 72
# lane 4 raw first 8 pts: [[792.3748168945312, 350.7435607910156], [785.9603881835938, 352.1219177246094], [779.5459594726562, 353.5002746582031], [773.131591796875, 354.8786315917969], [766.7590942382812, 356.4326477050781], [760.4144287109375, 358.1025390625], [754.0697021484375, 359.7724304199219], [747.7411499023438, 361.49896240234375]]
# lane 4 visible count: 72
# lane 5 raw first 8 pts: [[722.945556640625, 351.84564208984375], [712.600341796875, 353.18316650390625], [702.2551879882812, 354.52069091796875], [691.909912109375, 355.85821533203125], [681.5736083984375, 357.2596740722656], [671.255126953125, 358.78961181640625], [660.9366455078125, 360.3195495605469], [650.6181640625, 361.8494873046875]]
# lane 5 visible count: 72
# lane 6 raw first 8 pts: [[889.355224609375, 332.0084533691406], [877.0648803710938, 332.7906188964844], [864.7744750976562, 333.57275390625], [852.484130859375, 334.35491943359375], [840.1966552734375, 335.1795959472656], [827.9163208007812, 336.105712890625], [815.6359252929688, 337.0318298339844], [803.3555908203125, 337.9579162597656]]
# lane 6 visible count: 72
# lane 7 raw first 8 pts: [[674.4552612304688, 352.94769287109375], [665.3148193359375, 354.0074768066406], [656.1743774414062, 355.0672607421875], [647.033935546875, 356.12701416015625], [637.8950805664062, 357.20074462890625], [628.7598876953125, 358.3053894042969], [619.624755859375, 359.4100646972656], [610.4896240234375, 360.5147399902344]]
# lane 7 visible count: 72

# %% [markdown]
# ## 4 — Configuration

# %%
from src.config import Config

cfg = Config(
    run_name='dualpath_v3_research_stage',
    dataset_root=LOCAL_DS,
    img_size=640,
    batch_size=8,
    num_workers=8,
    backbone='resnet50',
    pretrained=True,
    det_num_queries=100,
    det_dec_layers=3,
    lane_num_queries=8,
    lane_dec_layers=3,
    lane_points=64,
    use_task_adapters=True,
    adapter_hidden_ratio=0.5,
    cross_attn=True,
    cross_attn_start_epoch=8,
    epochs=50,
    lr=1e-4,
    patience=15,
    label_schema='auto',
    auto_resume=False,
    val_interval=5,
    max_val_batches=250,
    det_only_epochs=3,
    det_task_warmup_weight=1.0,
    lane_task_warmup_weight=0.20,
    task_warmup_epochs=10,
    lane_overlap_weight=1.5,
    lane_raster_h=64,
    lane_raster_w=96,
    lane_raster_thickness=0.025,
)

cfg.save(os.path.join(cfg.save_dir, 'config.yaml'))
print(f'Config saved to {cfg.save_dir}')
print(f'  Backbone: {cfg.backbone}')
print(f'  Label schema: {cfg.label_schema}')
print(f'  Task adapters: {cfg.use_task_adapters}')
print(f'  Cross-attn start epoch: {cfg.cross_attn_start_epoch}')
print(f'  Det-only epochs: {cfg.det_only_epochs}')
print(f'  Val interval: {cfg.val_interval}, max val batches: {cfg.max_val_batches}')
# Out:
# Config saved to /content/drive/MyDrive/EcoCAR/training_runs/dualpath_v1
#   Backbone: resnet50
#   Label schema: auto
#   Det queries: 100
#   Lane queries: 10 x 72 points
#   Cross-attn: True
#   Auto resume: True
#   Validation interval: every 2 epoch(s)
#   Task warmup: det=1.0, lane=0.35 for 8 epochs
#   Lane raster: 128x72, thickness=0.03

# %% [markdown]
# ## 5 — Build Model

# %%
from src.model import build_model

model = build_model(cfg)
model.print_summary()
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:00<00:00, 336MB/s]
# DualPathNet summary:
#   Backbone+FPN :   26,196,544
#   Det encoder  :      789,760
#   Det decoder  :    3,681,059
#   Lane encoder :      789,760
#   Lane decoder :    3,734,336
#   Cross-attn   :      527,360
#   Total        :   35,718,819
#   Det queries=100, Lane queries=10, Lane points=72

# %%
# Sanity check forward pass
dummy = torch.randn(2, 3, cfg.img_size, cfg.img_size)
if torch.cuda.is_available():
    dummy = dummy.cuda()
    model = model.cuda()

with torch.no_grad():
    out = model(dummy)

for k, v in out.items():
    if isinstance(v, torch.Tensor):
        print(f"  {k}: {v.shape}")

model = model.cpu()
torch.cuda.empty_cache()
# Out:
#   det_pred_logits: torch.Size([2, 100, 6])
#   det_pred_boxes: torch.Size([2, 100, 4])
#   det_query_features: torch.Size([2, 100, 256])
#   lane_exist_logits: torch.Size([2, 10, 1])
#   lane_pred_points: torch.Size([2, 10, 72, 2])
#   lane_vis_logits: torch.Size([2, 10, 72])
#   lane_type_logits: torch.Size([2, 10, 7])
#   lane_query_features: torch.Size([2, 10, 256])

# %% [markdown]
# ## 6 — Dataset & DataLoader

# %%
from src.dataset import build_dataloaders

train_loader, val_loader = build_dataloaders(
    cfg,
    train_lane_json=train_lane_json,
    val_lane_json=val_lane_json,
)

print(f"Train: {len(train_loader.dataset)} samples, {len(train_loader)} batches")
print(f"Val:   {len(val_loader.dataset)} samples, {len(val_loader)} batches")
# Out:
# Loading lane labels from per-image directory /content/bdd100k_raw/100k/train ...
#   Cached lane labels for 65813 frames from directory
#   Debug sample: {'name': '0000f77c-6257be58.jpg', 'n_labels': 3, 'existence_sum': 3.0, 'first_category': 'lane/road curb', 'first_vertices_head': [[503.674413, 373.137193], [357.797732, 374.672737]], 'first_types': 'LL', 'dense_points_head': [[503.674413, 373.137193], [357.797732, 374.672737]], 'dense_len': 2}
# Loading lane labels from per-image directory /content/bdd100k_raw/100k/val ...
#   Cached lane labels for 9425 frames from directory
#   Debug sample: {'name': 'b1c66a42-6f7d68ca.jpg', 'n_labels': 13, 'existence_sum': 10.0, 'first_category': 'lane/single yellow', 'first_vertices_head': [[540.443883, 385.603214], [363.625829, 572.410989]], 'first_types': 'LL', 'dense_points_head': [[540.443883, 385.603214], [363.625829, 572.410989]], 'dense_len': 2}
#   Dataset: 70000 images from /content/bdd100k_vehicle5/images/train
#   Detection label schema: vehicle_remapped
#   Sampled detection class counts -> 0:5066, 1:222, 2:90, 3:13, 4:53
#   Dataset: 10000 images from /content/bdd100k_vehicle5/images/val
#   Detection label schema: vehicle_remapped
#   Sampled detection class counts -> 0:5180, 1:215, 2:92, 3:20, 4:40
# Train: 70000 samples, 8750 batches
# Val:   10000 samples, 1250 batches

# %%
# Visualize a batch
import matplotlib.pyplot as plt
import numpy as np

batch = next(iter(train_loader))
print(f"Images: {batch['images'].shape}")
print(f"Det targets: {batch['det_targets'].shape}")
print(f"Lane existence: {batch['lane_existence'].shape}")
print(f"Lane points: {batch['lane_points'].shape}")
print(f"Has lanes: {batch['has_lanes']}")

fig, axes = plt.subplots(1, 4, figsize=(20, 5))
for i in range(min(4, batch['images'].shape[0])):
    img = batch['images'][i].permute(1, 2, 0).numpy()
    img = np.clip(img, 0, 1)
    axes[i].imshow(img)
    axes[i].set_title(f"Image {i}")
    axes[i].axis('off')
plt.tight_layout()
plt.show()
# Out:
# Images: torch.Size([8, 3, 640, 640])
# Det targets: torch.Size([93, 6])
# Lane existence: torch.Size([8, 10])
# Lane points: torch.Size([8, 10, 72, 2])
# Has lanes: tensor([1., 1., 1., 0., 1., 1., 1., 1.])

# %% [markdown]
# ## 7 — Training
#
# Trains the DualPathNet with:
# - AdamW optimizer (backbone LR x0.1)
# - Cosine LR schedule with warmup
# - Hungarian matching for both detection and lane tasks
# - Metric-driven checkpointing (best det, best lane, best joint)

# %%
from src.trainer import Trainer

trainer = Trainer(cfg, model, train_loader, val_loader)
print(f'Training for {cfg.epochs} epochs')
print(f'Save dir: {cfg.save_dir}')
if trainer.start_epoch > 0:
    print(f'Resuming from epoch {trainer.start_epoch + 1}')
# Out:
# Training for 50 epochs
# Save dir: /content/drive/MyDrive/EcoCAR/training_runs/dualpath_v1

# %%
import traceback

try:
    history = trainer.train()
except Exception as e:
    print(f"\nTraining stopped: {e}")
    traceback.print_exc(limit=5)
    history = trainer.history

print(f"\nLogged {len(history)} epochs.")
# Out:
# =================================================================
#   DualPathNet Training: 50 epochs
#   Classes: car, truck, bus, motorcycle, bicycle
#   Save: /content/drive/MyDrive/EcoCAR/training_runs/dualpath_v1
# =================================================================
# Epoch   1/50 | loss=8.022 | val=6.912 | mAP50=0.0% | lane mIoU=17.8% | lane overlapF1=30.2% | 2703s
# Epoch   2/50 | loss=6.572 | val=6.003 | mAP50=0.2% | lane mIoU=26.3% | lane overlapF1=41.6% | 2718s
# Epoch   3/50 | loss=5.937 | val=skip | mAP50=0.2% | lane mIoU=26.3% | lane overlapF1=41.6% | 2275s
# Epoch   4/50 | loss=5.525 | val=5.273 | mAP50=1.6% | lane mIoU=30.7% | lane overlapF1=46.9% | 2721s
#
# Training stopped: matrix contains invalid numeric entries
#
# Logged 4 epochs.
# Traceback (most recent call last):
#   File "/tmp/ipykernel_5275/1945387188.py", line 4, in <cell line: 0>
#     history = trainer.train()
#               ^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/EcoCAR/DETR_GeoLane_pipeline/src/trainer.py", line 232, in train
#     train_metrics = self.train_epoch(epoch)
#                     ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/drive/MyDrive/EcoCAR/DETR_GeoLane_pipeline/src/trainer.py", line 141, in train_epoch
#     loss, info = self.criterion(outputs, batch_gpu)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: matrix contains invalid numeric entries

# %% [markdown]
# ## 8 — Training Curves

# %%
import matplotlib.pyplot as plt

if history and len(history) > 0:
    epochs = range(1, len(history) + 1)
    train_loss = [h.get("train_loss", 0) for h in history]
    val_loss = [h.get("val_loss", 0) for h in history]
    det_map = [h.get("det_map50", 0) * 100 for h in history]
    lane_miou = [h.get("lane_miou", 0) * 100 for h in history]
    lane_overlap_f1 = [h.get("lane_overlap_f1", 0) * 100 for h in history]

    fig, axes = plt.subplots(1, 3, figsize=(18, 5))

    axes[0].plot(epochs, train_loss, label="Train", linewidth=2.5)
    axes[0].plot(epochs, val_loss, label="Val", linewidth=2.5)
    axes[0].set_title("Loss")
    axes[0].set_xlabel("Epoch")
    axes[0].legend()

    axes[1].plot(epochs, det_map, linewidth=2.5)
    axes[1].set_title("Detection mAP@50 (%)")
    axes[1].set_xlabel("Epoch")

    axes[2].plot(epochs, lane_miou, label="Lane mIoU", linewidth=2.5)
    axes[2].plot(epochs, lane_overlap_f1, label="Lane overlap F1", linewidth=2.5, alpha=0.85)
    axes[2].set_title("Lane overlap metrics (%)")
    axes[2].set_xlabel("Epoch")
    axes[2].legend()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## 9 — Qualitative Inference

# %%
import cv2
import random
from src.visualize import draw_all

model.eval()
if torch.cuda.is_available():
    model = model.cuda()

val_dir = os.path.join(LOCAL_DS, "images", "val")
all_images = sorted(os.listdir(val_dir))
random.seed(42)
sample_images = random.sample(all_images, min(6, len(all_images)))

fig, axes = plt.subplots(2, 3, figsize=(18, 12))
for i, fname in enumerate(sample_images):
    img_bgr = cv2.imread(os.path.join(val_dir, fname))
    img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
    img_resized = cv2.resize(img_rgb, (cfg.img_size, cfg.img_size))

    tensor = torch.from_numpy(img_resized.astype(np.float32) / 255.0).permute(2, 0, 1)
    tensor = tensor.unsqueeze(0).to(next(model.parameters()).device)

    with torch.no_grad(), torch.amp.autocast("cuda", enabled=cfg.amp):
        outputs = model(tensor)

    vis = draw_all(img_resized, outputs, conf_thresh=0.3, lane_thresh=0.5)

    ax = axes[i // 3, i % 3]
    ax.imshow(vis)
    ax.set_title(fname)
    ax.axis('off')

plt.suptitle("DualPathNet Inference", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 10 — Export Best Weights

# %%
import shutil

best_src = os.path.join(cfg.save_dir, "weights", "best_joint.pt")
best_dst = os.path.join(WEIGHTS_DIR, f"{cfg.run_name}_best.pt")

os.makedirs(WEIGHTS_DIR, exist_ok=True)

if os.path.isfile(best_src):
    shutil.copy2(best_src, best_dst)
    print(f"Best weights copied to: {best_dst}")
else:
    last_src = os.path.join(cfg.save_dir, "weights", "last.pt")
    if os.path.isfile(last_src):
        last_dst = os.path.join(WEIGHTS_DIR, f"{cfg.run_name}_last.pt")
        shutil.copy2(last_src, last_dst)
        print(f"Last weights copied to: {last_dst}")

print("\n" + "="*55)
print("  TRAINING COMPLETE")
print("="*55)
print(f"  Run:        {cfg.run_name}")
print(f"  Epochs:     {len(history)}")
print(f"  Best det:   {trainer.best_scores['det']*100:.2f}%")
print(f"  Best lane:  {trainer.best_scores['lane']*100:.2f}%")
print(f"  Best joint: {trainer.best_scores['joint']:.4f}")
print(f"  Weights:    {WEIGHTS_DIR}")
print("="*55)
# Out:
# Best weights copied to: /content/drive/MyDrive/EcoCAR/weights/dualpath_v1_best.pt
#
# =======================================================
#   TRAINING COMPLETE
# =======================================================
#   Run:        dualpath_v1
#   Epochs:     4
#   Best det:   1.57%
#   Best lane:  30.65%
#   Best joint: 0.1320
#   Weights:    /content/drive/MyDrive/EcoCAR/weights
# =======================================================
